# %%
import pandas as pd
import numpy as np
import requests as req
from bs4 import BeautifulSoup
import math
from tqdm import tqdm

# %%
import pandas as pd
import requests as req
from bs4 import BeautifulSoup

def link_to_csv_detailed(df_original, hackathon_name):
    """
    Scrape detailed project information and combine with original DataFrame
    
    Args:
        df_original: Original DataFrame with columns: hackathon_name, project_name, project_link, winner
        hackathon_name: Name of the hackathon for output file naming
    """
    count = 0
    detailed_data = []

    for index, row in df_original.iterrows():
        url = row['project_link']
        project_name = row['project_name']
        
        try:
            response = req.get(url)
            response.raise_for_status()  # Raise an exception for bad status codes
            soup = BeautifulSoup(response.text, "html.parser")
            soup = soup.find("div", class_="large-9 columns")
            
            # Initialize section columns with dynamic "What's next" section
            sections = {
                "Inspiration": "",
                "What it does": "",
                "How we built it": "",
                "Challenges we ran into": "",
                "Accomplishments that we're proud of": "",
                "What we learned": "",
                "What's next": ""  # Will be filled dynamically
            }

            # Extract content for each section
            h2 = soup.find_all("h2")
            length_h2 = len(h2)
             #if less than 5 then put all the <p> tag on the inspiration section
            
            # Check if we have the standard project description sections
            standard_sections = ["Inspiration", "What it does", "How we built it", "Challenges we ran into", 
                                "Accomplishments that we're proud of", "What we learned"]
            has_standard_sections = any(header.get_text(strip=True) in standard_sections for header in h2)
            
            if not has_standard_sections:
                # No standard sections found, put all p tags in inspiration section
                all_p_tags = soup.find_all("p")
                inspiration_content = []
                for p in all_p_tags:
                    inspiration_content.append(p.get_text(strip=True))
                sections["Inspiration"] = " ".join(inspiration_content)
            else:
                # Normal processing when standard sections are found
                for header in soup.find_all("h2"):
                    section_name = header.get_text(strip=True)
                    
                    # Handle the dynamic "What's next" section
                    if section_name.startswith("What's next"):
                        sections["What's next"] = extract_section_content(header)
                    elif section_name in sections:
                        sections[section_name] = extract_section_content(header)

            # Built With
            built_with = []
            built_with_section = soup.find("div", id="built-with")
            if built_with_section:
                for tech in built_with_section.find_all("span", class_="cp-tag"):
                    built_with.append(tech.get_text(strip=True))

            # GitHub / external links
            links_list = []
            links_section = soup.find("ul", {"data-role": "software-urls"})
            if links_section:
                for a in links_section.find_all("a", href=True):
                    links_list.append(a["href"])

            # Combine original data with scraped details
            detailed_row = {
                # Original columns
                "hackathon_name": row['hackathon_name'],
                "project_name": row['project_name'],
                "project_link": row['project_link'],
                "winner": row['winner'],
                # New detailed columns
                "inspiration": sections["Inspiration"],
                "what_it_does": sections["What it does"],
                "how_we_built_it": sections["How we built it"],
                "challenges": sections["Challenges we ran into"],
                "accomplishments": sections["Accomplishments that we're proud of"],
                "what_we_learned": sections["What we learned"],
                "next_steps": sections["What's next"],
                "built_with": ", ".join(built_with),
                "external_links": ", ".join(links_list)
            }
            
            detailed_data.append(detailed_row)
            print(f"✅ Processed: {project_name} ({count + 1}/{len(df_original)})")
            
        except Exception as e:
            print(f"❌ Error processing {project_name}: {str(e)}")
            # Add row with original data and empty detailed fields
            detailed_row = {
                "hackathon_name": row['hackathon_name'],
                "project_name": row['project_name'],
                "project_link": row['project_link'],
                "winner": row['winner'],
                "inspiration": "",
                "what_it_does": "",
                "how_we_built_it": "",
                "challenges": "",
                "accomplishments": "",
                "what_we_learned": "",
                "next_steps": "",
                "built_with": "",
                "external_links": ""
            }
            detailed_data.append(detailed_row)
        
        count += 1

    # Save to CSV
    df_out = pd.DataFrame(detailed_data)
    output_filename = f"{hackathon_name}_detailed.csv"
    df_out.to_csv(output_filename, index=False)
    print(f"✅ Saved {len(detailed_data)} detailed projects from {hackathon_name} to {output_filename}")
    
    return df_out

def extract_section_content(header):
    """Helper function to extract content from a section"""
    content = []
    sibling = header.find_next_sibling()
    while sibling and sibling.name != "h2":
        if sibling.name == "p":
            content.append(sibling.get_text(strip=True))
        sibling = sibling.find_next_sibling()
    return " ".join(content)

def extract_section_content_with_tracking(header):
    """Helper function to extract content from a section and track which p tags were used"""
    content = []
    p_tags_used = []
    sibling = header.find_next_sibling()
    while sibling and sibling.name != "h2":
        if sibling.name == "p":
            content.append(sibling.get_text(strip=True))
            p_tags_used.append(sibling)
        sibling = sibling.find_next_sibling()
    return " ".join(content), p_tags_used

# Example usage:
# df_original = pd.read_csv("your_original_file.csv")
# df_detailed = link_to_csv_detailed(df_original, "Auburn Hacks 2024")

# %%
# Read the CSV
df_original = pd.read_csv("all_hackathons_merged.csv")

df_detailed = link_to_csv_detailed(df_original, "all_detailed.csv")
df_detailed
# Out:
# ✅ Processed: Resumate (1/1071)
# ✅ Processed: Courage The Not-so Cowardly Rover (2/1071)
# ✅ Processed: Planetarium (3/1071)
# ✅ Processed: Orbital Sandbox (4/1071)
# ✅ Processed: OrbitQuest (5/1071)
# ✅ Processed: Pseduo (6/1071)
# ✅ Processed: Auburn Quest (7/1071)
# ✅ Processed: Starfall (8/1071)
# ✅ Processed: planet simulation (9/1071)
# ✅ Processed: Constellation Achievements (10/1071)
# ✅ Processed: SpacePal (11/1071)
# ✅ Processed: HAL 9000 Desktop Buddy (12/1071)
# ✅ Processed: Andromeda (13/1071)
# ✅ Processed: Sound Safari (14/1071)
# ✅ Processed: Demo (15/1071)
# ✅ Processed: Solar Flare Prediction (16/1071)
# ✅ Processed: Spaceify (17/1071)
# ✅ Processed: Space smarts (18/1071)
# ✅ Processed: OnePress (19/1071)
# ✅ Processed: Mars Meteo (20/1071)
# ✅ Processed: AstroPedia (21/1071)
# ✅ Processed: Event Horizon (22/1071)
# ✅ Processed: Spaced Out (23/1071)
# ✅ Processed: AlienAtlas (24/1071)
# ✅ Processed: Nebula Navigators (25/1071)
# ✅ Processed: Starbite (26/1071)
# ✅ Processed: Playlist Planet (27/1071)
# ✅ Processed: Planet Patrol (28/1071)
# ✅ Processed: Cosmic Colonies (29/1071)
# ✅ Processed: WeAuburn (30/1071)
# ✅ Processed: Marshall's Space Return (31/1071)
# ✅ Processed: Second Chapter (32/1071)
# ✅ Processed: SwarmAid (33/1071)
# ✅ Processed: 2NDs (34/1071)
# ✅ Processed: Green Gale (35/1071)
# ✅ Processed: SwarmSense: Connected Intelligence for Connected Vehicles (36/1071)
# ✅ Processed: SaveCircle (37/1071)
# ✅ Processed: DevLingo (38/1071)
# ✅ Processed: Hocus Focus (39/1071)
# ✅ Processed: CrashCam (40/1071)
# ✅ Processed: WattX (41/1071)
# ✅ Processed: PayUp (42/1071)
# ✅ Processed: Interactive Media Challenge: Deepfake Detection for Images (43/1071)
# ✅ Processed: YOFY^T (44/1071)
# ✅ Processed: IntelliSchedule (45/1071)
# ✅ Processed: Finance Buddy (46/1071)
# ✅ Processed: CUT THE CARBON (47/1071)
# ✅ Processed: Tic Tac Toe (48/1071)
# ✅ Processed: VeriVote (49/1071)
# ✅ Processed: lightWEB (50/1071)
# ✅ Processed: Recognition (51/1071)
# ✅ Processed: Sigmund's Quest (52/1071)
# ✅ Processed: Lucros (53/1071)
# ✅ Processed: ProFormAI (54/1071)
# ✅ Processed: E'm-pathy (55/1071)
# ✅ Processed: TrunkMonkey (56/1071)
# ✅ Processed: Risky Business (57/1071)
# ✅ Processed: TutorVerse (58/1071)
# ✅ Processed: Motive (59/1071)
# ✅ Processed: UMCU (60/1071)
# ✅ Processed: RecruitMatic (61/1071)
# ✅ Processed: Travel Agent (62/1071)
# ✅ Processed: AI Nutrition Planner (63/1071)
# ✅ Processed: Pick2Plan (64/1071)
# ✅ Processed: Stock Feedback AI (65/1071)
# ✅ Processed: Scam Protect (66/1071)
# ✅ Processed: Doctor Green – Your AI guide to recycling (67/1071)
# ✅ Processed: Talk Tech (68/1071)
# ✅ Processed: G.U.A.R.D. (69/1071)
# ✅ Processed: NutriCML (70/1071)
# ✅ Processed: EnvoQuest (71/1071)
# ✅ Processed: LiFi (72/1071)
# ✅ Processed: RideWatch (73/1071)
# ✅ Processed: Drive-I (74/1071)
# ✅ Processed: EyePi (75/1071)
# ✅ Processed: AI assisted Telemedicine KIOSK (76/1071)
# ✅ Processed: BlurBeGone (77/1071)
# ✅ Processed: techRamsay (78/1071)
# ✅ Processed: PySurfers (79/1071)
# ✅ Processed: FinQuest (80/1071)
# ✅ Processed: Major Match (81/1071)
# ✅ Processed: AIdvising (82/1071)
# ✅ Processed: TalkTuahCar (83/1071)
# ✅ Processed: NaviGree (84/1071)
# ✅ Processed: MementoAI (85/1071)
# ✅ Processed: EcoTrip (86/1071)
# ✅ Processed: EyeSign (87/1071)
# ✅ Processed: Amazon Co2 Product Calculator Extension (88/1071)
# ✅ Processed: Code Kids (89/1071)
# ✅ Processed: Byte by Byte (90/1071)
# ✅ Processed: Road Report (91/1071)
# ✅ Processed: SmartTrader V4 (92/1071)
# ✅ Processed: Hand Gesture Car Racing (93/1071)
# ✅ Processed: PetPulse (94/1071)
# ✅ Processed: JudgedByAI (95/1071)
# ✅ Processed: Mnemosyne (96/1071)
# ✅ Processed: Reef Guard (97/1071)
# ✅ Processed: Ojibwe Dictionary (98/1071)
# ✅ Processed: Snap&Serve (99/1071)
# ✅ Processed: Sustain-ify (100/1071)
# ✅ Processed: Garuda (101/1071)
# ✅ Processed: Diabeteasy (102/1071)
# ✅ Processed: Flexy (And I Know It) (103/1071)
# ✅ Processed: U-Plan (104/1071)
# ✅ Processed: OpenLegislation (105/1071)
# ✅ Processed: TheftWatch (106/1071)
# ✅ Processed: Invaders (107/1071)
# ✅ Processed: Open Context (108/1071)
# ✅ Processed: citewise (109/1071)
# ✅ Processed: Embeddit (110/1071)
# ✅ Processed: Clean Sweep (111/1071)
# ✅ Processed: FootPrint Mayhem (112/1071)
# ✅ Processed: TradeREC (113/1071)
# ✅ Processed: CognitiveKeyboard (114/1071)
# ✅ Processed: Althea (115/1071)
# ✅ Processed: SimplySign (116/1071)
# ✅ Processed: T-Error (117/1071)
# ✅ Processed: MediGuide (118/1071)
# ✅ Processed: Harvard Burger (119/1071)
# ✅ Processed: ParkPoint（Parking no worries） (120/1071)
# ✅ Processed: Theraplane (121/1071)
# ✅ Processed: Teleport (122/1071)
# ✅ Processed: Traffix (123/1071)
# ✅ Processed: SkyScale (124/1071)
# ✅ Processed: AI in Quality Engineering (125/1071)
# ✅ Processed: WellBite (126/1071)
# ✅ Processed: CiviClick (127/1071)
# ✅ Processed: Local.ly (128/1071)
# ✅ Processed: Priceflix (129/1071)
# ✅ Processed: Autodine (130/1071)
# ✅ Processed: #FairSight (131/1071)
# ✅ Processed: Twilight (132/1071)
# ✅ Processed: CareSync (133/1071)
# ✅ Processed: HackrMap (134/1071)
# ✅ Processed: re$ipe (135/1071)
# ✅ Processed: SafeSpace (136/1071)
# ✅ Processed: EZ-PT (137/1071)
# ✅ Processed: docGen (138/1071)
# ✅ Processed: Attenbot (139/1071)
# ✅ Processed: Moodivation (140/1071)
# ✅ Processed: MoleculeIQ (141/1071)
# ✅ Processed: Albatross (142/1071)
# ✅ Processed: Proximity (143/1071)
# ✅ Processed: PrepCheck (144/1071)
# ✅ Processed: EcoCoin (145/1071)
# ✅ Processed: Parkara (146/1071)
# ✅ Processed: Vizzi (147/1071)
# ✅ Processed: Stylete.app (148/1071)
# ✅ Processed: VitalPath (149/1071)
# ✅ Processed: MiRTH (150/1071)
# ✅ Processed: RareCare (151/1071)
# ✅ Processed: Envest (152/1071)
# ✅ Processed: Infinite Roads (153/1071)
# ✅ Processed: mindshort (154/1071)
# ✅ Processed: Luna Tech (155/1071)
# ✅ Processed: HackEnzyme (156/1071)
# ✅ Processed: Aria (157/1071)
# ✅ Processed: Query on Reality (158/1071)
# ✅ Processed: I CARE 4 DOCTORS (159/1071)
# ✅ Processed: DocScribe (160/1071)
# ✅ Processed: BurnGPT (161/1071)
# ✅ Processed: HelpSignal (162/1071)
# ✅ Processed: Queue-1-1 (163/1071)
# ✅ Processed: CogniSpeak (164/1071)
# ✅ Processed: WHEN??? (165/1071)
# ✅ Processed: Doctor Doctor (166/1071)
# ✅ Processed: DecentraHealth (167/1071)
# ✅ Processed: Resumify (168/1071)
# ✅ Processed: QuickDeets (169/1071)
# ✅ Processed: MediTrack (170/1071)
# ✅ Processed: Beacon (171/1071)
# ✅ Processed: ReliefToYuah (172/1071)
# ✅ Processed: Sleep Soon (173/1071)
# ✅ Processed: BioSync (174/1071)
# ✅ Processed: SlideProf (175/1071)
# ✅ Processed: UniRoute (176/1071)
# ✅ Processed: Smart Traffic Light Simulation (177/1071)
# ✅ Processed: AIDERS: AI-powered Detection and Emergency Response System (178/1071)
# ✅ Processed: AthenaPrep (179/1071)
# ✅ Processed: Signify (180/1071)
# ✅ Processed: Vota: One vote, one voice (181/1071)
# ✅ Processed: Lucidity (182/1071)
# ✅ Processed: EcoKitty (183/1071)
# ✅ Processed: Eventure (184/1071)
# ✅ Processed: CopayHero GPT (185/1071)
# ✅ Processed: EduCare (186/1071)
# ✅ Processed: PAWPAW - the Privacy Analyzer with Personality and Whimsy (187/1071)
# ✅ Processed: SafeRoute | Safety Prioritized in Google Maps (188/1071)
# ✅ Processed: DermaDrill (189/1071)
# ✅ Processed: Just Hurry! (190/1071)
# ✅ Processed: Realytics (191/1071)
# ✅ Processed: Unify (192/1071)
# ✅ Processed: elo-fi (193/1071)
# ✅ Processed: ChaosNet (194/1071)
# ✅ Processed: Call Me Maybe (195/1071)
# ✅ Processed: mood (196/1071)
# ✅ Processed: RideCast (197/1071)
# ✅ Processed: CrisisCompanion (198/1071)
# ✅ Processed: HavenLink (199/1071)
# ✅ Processed: Teaching Assassin (200/1071)
# ✅ Processed: Buzzly-AI (201/1071)
# ✅ Processed: TechedIn (202/1071)
# ✅ Processed: Health Guardian (203/1071)
# ✅ Processed: VeriPharma (204/1071)
# ✅ Processed: SOS (205/1071)
# ✅ Processed: FoodBridge (206/1071)
# ✅ Processed: moodeng (207/1071)
# ✅ Processed: Educrate (208/1071)
# ✅ Processed: Gladiator Go (209/1071)
# ✅ Processed: PatientVault (210/1071)
# ✅ Processed: EcoCompute (211/1071)
# ✅ Processed: Grapevine (212/1071)
# ✅ Processed: TrueCritic (213/1071)
# ✅ Processed: Traffic Eye (214/1071)
# ✅ Processed: Mood Map (215/1071)
# ✅ Processed: Muscle Intelligence (216/1071)
# ✅ Processed: Beat the Receipt (217/1071)
# ✅ Processed: UrbanEye (218/1071)
# ✅ Processed: Climately: Your Weather Calendar (219/1071)
# ✅ Processed: City Vibes (220/1071)
# ✅ Processed: Unikeyboard (221/1071)
# ✅ Processed: Kormo Mela (222/1071)
# ✅ Processed: steersafe (223/1071)
# ✅ Processed: Vigilo (224/1071)
# ✅ Processed: Hospital Inventory Manager (2) (225/1071)
# ✅ Processed: BinIT Right (226/1071)
# ✅ Processed: CareCost (227/1071)
# ✅ Processed: ConnectHealth (228/1071)
# ✅ Processed: Trashure Hunt (229/1071)
# ✅ Processed: Optimized Trash Disposal System (230/1071)
# ✅ Processed: WanderWays (231/1071)
# ✅ Processed: Eye In The Sky (232/1071)
# ✅ Processed: Recycletron (233/1071)
# ✅ Processed: FNAF VR (234/1071)
# ✅ Processed: Med-O-Matic (235/1071)
# ✅ Processed: POCKET-HELPER (236/1071)
# ✅ Processed: HookBook (237/1071)
# ✅ Processed: Mental Health App (238/1071)
# ✅ Processed: Fish Outta Water (239/1071)
# ✅ Processed: friday (240/1071)
# ✅ Processed: DocDoc Goose (241/1071)
# ✅ Processed: SafeStep (242/1071)
# ✅ Processed: EirAI (243/1071)
# ✅ Processed: Git Lucky (244/1071)
# ✅ Processed: MindClash (245/1071)
# ✅ Processed: The Note Distillery (246/1071)
# ✅ Processed: Monster Muscles (247/1071)
# ✅ Processed: Get Big, Man (248/1071)
# ✅ Processed: TARS (249/1071)
# ✅ Processed: Dream Dragon (250/1071)
# ✅ Processed: Souperb (251/1071)
# ✅ Processed: medIQ (252/1071)
# ✅ Processed: FoodSafe (253/1071)
# ✅ Processed: PeTAI (254/1071)
# ✅ Processed: Let's Eat! (255/1071)
# ✅ Processed: CreditNexus (256/1071)
# ✅ Processed: Renmo (257/1071)
# ✅ Processed: Decora (258/1071)
# ✅ Processed: DUZK (259/1071)
# ✅ Processed: spot-a-song (260/1071)
# ✅ Processed: bldr (261/1071)
# ✅ Processed: Hack Draw (262/1071)
# ✅ Processed: RustBucket (263/1071)
# ✅ Processed: Fireball Clicker (264/1071)
# ✅ Processed: Road to Recovery (265/1071)
# ✅ Processed: Merlin - Your personal wizard assistant (266/1071)
# ✅ Processed: Medi ErrSaver (267/1071)
# ✅ Processed: The Phog Log (268/1071)
# ✅ Processed: CarGoo 2 (269/1071)
# ✅ Processed: GrocerGPT (270/1071)
# ✅ Processed: Calculator for Miller Unit Values (271/1071)
# ✅ Processed: OWL - Observational Watch Log (272/1071)
# ✅ Processed: GuideBuddy - Interactive Speech Medicare Assistant (273/1071)
# ✅ Processed: NetCode (274/1071)
# ✅ Processed: muscle maker (275/1071)
# ✅ Processed: Sigma Nurse (276/1071)
# ✅ Processed: CashCraft (277/1071)
# ✅ Processed: Attendr (278/1071)
# ✅ Processed: TeroSecureMD (279/1071)
# ✅ Processed: Mr. J (280/1071)
# ✅ Processed: SideKick AI (281/1071)
# ✅ Processed: DepressoBot (282/1071)
# ✅ Processed: Galdoran (283/1071)
# ✅ Processed: GoodMoodFood (284/1071)
# ✅ Processed: ThriveTogether (285/1071)
# ✅ Processed: Dopamine Tracker: Reward System Detox App (286/1071)
# ✅ Processed: Claria (287/1071)
# ✅ Processed: Workout Warriors (288/1071)
# ✅ Processed: Rate My Roommate (289/1071)
# ✅ Processed: IBD Tracker (290/1071)
# ✅ Processed: Flanner - AI meal planner (291/1071)
# ✅ Processed: Hardware Shenanigans - CRT Restoration (292/1071)
# ✅ Processed: ObsCurity (293/1071)
# ✅ Processed: peerGig (294/1071)
# ✅ Processed: ReLode (295/1071)
# ✅ Processed: Polar Lizard (296/1071)
# ✅ Processed: Moodi (297/1071)
# ✅ Processed: AI Driven Text-Based RPG Discord Bot (298/1071)
# ✅ Processed: LinguaSwap (299/1071)
# ✅ Processed: Recall (300/1071)
# ✅ Processed: Price Aware+ (301/1071)
# ✅ Processed: MOOD-AI (302/1071)
# ✅ Processed: EZRead (303/1071)
# ✅ Processed: Gnomtastic Gnomular Quest: Those Who Gnome (304/1071)
# ✅ Processed: Goose Guide (305/1071)
# ✅ Processed: MyFolio (306/1071)
# ✅ Processed: BloodLens (307/1071)
# ✅ Processed: Budget Meal Maker (308/1071)
# ✅ Processed: Hack it Up (309/1071)
# ✅ Processed: Git Guru (310/1071)
# ✅ Processed: Stravive (311/1071)
# ✅ Processed: CineME: Personalized Film Trivia (312/1071)
# ✅ Processed: Recipe Arsenal (313/1071)
# ✅ Processed: JARVIS (314/1071)
# ✅ Processed: TrustRipple (315/1071)
# ✅ Processed: Jarvis (316/1071)
# ✅ Processed: The Queens Gamble (317/1071)
# ✅ Processed: HealthWise (318/1071)
# ✅ Processed: PillowPath (319/1071)
# ✅ Processed: Aptly (320/1071)
# ✅ Processed: Marcotics Marcollectibles (321/1071)
# ✅ Processed: Schedule Builder (322/1071)
# ✅ Processed: Repo Runner (323/1071)
# ✅ Processed: TransparentCare (324/1071)
# ✅ Processed: FitTrack (325/1071)
# ✅ Processed: nAIvAIgAItor (326/1071)
# ✅ Processed: Rusty Zelda (327/1071)
# ✅ Processed: Poker? (328/1071)
# ✅ Processed: CalorieCounter (329/1071)
# ✅ Processed: Cyber Office Chronicles (330/1071)
# ✅ Processed: Flood Escape (331/1071)
# ✅ Processed: Bee tamagotchi (332/1071)
# ✅ Processed: Media Oracle (333/1071)
# ✅ Processed: PocketZen WebXR (334/1071)
# ✅ Processed: FormulaBot (335/1071)
# ✅ Processed: MedTrack (336/1071)
# ✅ Processed: Unplugged (337/1071)
# ✅ Processed: Car Thang (338/1071)
# ✅ Processed: fairLends (339/1071)
# ✅ Processed: LocalVoice (340/1071)
# ✅ Processed: Magic Missiles (341/1071)
# ✅ Processed: Give Me Some Space! (342/1071)
# ✅ Processed: EchoAlert (343/1071)
# ✅ Processed: FLUNC - Financial Literacy at UNC (344/1071)
# ✅ Processed: Aurora (345/1071)
# ✅ Processed: Pragma (346/1071)
# ✅ Processed: AI-powered Investment Portfolio Creator (347/1071)
# ✅ Processed: UnityConnect (348/1071)
# ✅ Processed: Smart Kitchen (349/1071)
# ✅ Processed: Carolina Radio (350/1071)
# ✅ Processed: SpotME.tech (351/1071)
# ✅ Processed: Cat-egorize (352/1071)
# ✅ Processed: ClearView (353/1071)
# ✅ Processed: PerCent (354/1071)
# ✅ Processed: Desing Your Dream Home (355/1071)
# ✅ Processed: Rendezvous (356/1071)
# ✅ Processed: Linear (357/1071)
# ✅ Processed: Heels & Meals (358/1071)
# ✅ Processed: FinWise AI (359/1071)
# ✅ Processed: MoonWallet (360/1071)
# ✅ Processed: HACKNC Initial D Inspired Racing Game (361/1071)
# ✅ Processed: School Safety NYC (362/1071)
# ✅ Processed: Rams-Rocket (363/1071)
# ✅ Processed: RubberDucky (364/1071)
# ✅ Processed: CD (365/1071)
# ✅ Processed: SPay (366/1071)
# ✅ Processed: SnapSuggest (367/1071)
# ✅ Processed: Local Pioneer (368/1071)
# ✅ Processed: Nail it with Lowe's! (369/1071)
# ✅ Processed: HeelEats App (370/1071)
# ✅ Processed: ShapeShift Prosthetics (371/1071)
# ✅ Processed: Glutten (372/1071)
# ✅ Processed: Lifeline (373/1071)
# ✅ Processed: Professor X: Virtual Mental Health Support (374/1071)
# ✅ Processed: SpaceDuck (375/1071)
# ✅ Processed: Apple Planet (376/1071)
# ✅ Processed: Tar Heel Trade (377/1071)
# ✅ Processed: Project Secure (378/1071)
# ✅ Processed: EconomicSpaceGame (379/1071)
# ✅ Processed: HandShake (380/1071)
# ✅ Processed: ReadyNow Hurricane Readiness (381/1071)
# ✅ Processed: EasyBreathe (382/1071)
# ✅ Processed: Astral Journey (383/1071)
# ✅ Processed: StarDaze (384/1071)
# ✅ Processed: FindMe (385/1071)
# ✅ Processed: AccountaBuddy (386/1071)
# ✅ Processed: StudyHeels (387/1071)
# ✅ Processed: Satellyte (388/1071)
# ✅ Processed: DripCheck (389/1071)
# ✅ Processed: Spacecraft Override (390/1071)
# ✅ Processed: Tar Travel (391/1071)
# ✅ Processed: The Dormganizer (392/1071)
# ✅ Processed: One (393/1071)
# ✅ Processed: Asteroid Field (394/1071)
# ✅ Processed: Orbital Simulation and the N-Body Problem (395/1071)
# ✅ Processed: Tar Heel Tutor (396/1071)
# ✅ Processed: FlatMate (397/1071)
# ✅ Processed: Mood Music (398/1071)
# ✅ Processed: ConnectMax (399/1071)
# ✅ Processed: Dungeon Escape Game (400/1071)
# ✅ Processed: Tasktronaut (401/1071)
# ✅ Processed: Time Value Vault (402/1071)
# ✅ Processed: StonkQuest (403/1071)
# ✅ Processed: Bolt (404/1071)
# ✅ Processed: OptiTime (405/1071)
# ✅ Processed: UNC Marketplace (406/1071)
# ✅ Processed: Satellite Image Guesser (407/1071)
# ✅ Processed: Centsible (408/1071)
# ✅ Processed: Fabrik (409/1071)
# ✅ Processed: Rocket Builder (410/1071)
# ✅ Processed: AstroFinance (411/1071)
# ✅ Processed: InnoVenture (412/1071)
# ✅ Processed: CampusCare (413/1071)
# ✅ Processed: Exploring Emotions (414/1071)
# ✅ Processed: What's The Move? (415/1071)
# ✅ Processed: Where The Heel? (416/1071)
# ✅ Processed: Delve The Dungeon (417/1071)
# ✅ Processed: Constellearn (418/1071)
# ✅ Processed: Roycie's Budget Tracker (419/1071)
# ✅ Processed: Astraloq (420/1071)
# ✅ Processed: Floxis (421/1071)
# ✅ Processed: FlowGenie (422/1071)
# ✅ Processed: Nebula (423/1071)
# ✅ Processed: Dress to Invade (424/1071)
# ✅ Processed: Space Donation (425/1071)
# ✅ Processed: I am secretly  not coding (426/1071)
# ✅ Processed: Aligned (427/1071)
# ✅ Processed: Budget Bites (428/1071)
# ✅ Processed: Set online game (429/1071)
# ✅ Processed: 1Finance.ai (430/1071)
# ✅ Processed: Echo Location (431/1071)
# ✅ Processed: The Seeing Eye Vest (432/1071)
# ✅ Processed: Bare Bones D&D (433/1071)
# ✅ Processed: Brailliance (434/1071)
# ✅ Processed: DeepCool (435/1071)
# ✅ Processed: Run For Your Life! (436/1071)
# ✅ Processed: LIFE-line (437/1071)
# ✅ Processed: Carbon E-Mission (438/1071)
# ✅ Processed: B-Box (439/1071)
# ✅ Processed: Sensor Sight Assist (440/1071)
# ✅ Processed: Weight Assisted Linear Kinetic System (WALKS) (441/1071)
# ✅ Processed: RizzBand (442/1071)
# ✅ Processed: Ducktor (443/1071)
# ✅ Processed: The Plant Buddy (444/1071)
# ✅ Processed: PAHS (Portable Automatic Hydroponic System) (445/1071)
# ✅ Processed: SolarHome (446/1071)
# ✅ Processed: The Collision Cap (447/1071)
# ✅ Processed: NeedleKnows (448/1071)
# ✅ Processed: Compost-Mate (449/1071)
# ✅ Processed: Red Light, Green Light (Sunflower Edition) (450/1071)
# ✅ Processed: The Recycling Bin Hat (451/1071)
# ✅ Processed: Grass Buddy (452/1071)
# ✅ Processed: ECCPD (453/1071)
# ✅ Processed: PEMDAS: Personality-Enhanced Matching Dating ASsistant (454/1071)
# ✅ Processed: Go Save Grass (455/1071)
# ✅ Processed: Hear Me Out: A Bruin Espionage (456/1071)
# ✅ Processed: The Helping Cane (457/1071)
# ✅ Processed: bean (458/1071)
# ✅ Processed: GPT M.D. (459/1071)
# ✅ Processed: iThirsty (460/1071)
# ✅ Processed: Boximizer (461/1071)
# ✅ Processed: VisionMate (462/1071)
# ✅ Processed: Collective Cadence (463/1071)
# ✅ Processed: Patient Focused Pill Dispenser (464/1071)
# ✅ Processed: Garvey - the half garden, half robo-pal rover. (465/1071)
# ✅ Processed: Health and Exercise Regulation Buddy - H.E.R.B. (466/1071)
# ✅ Processed: Eye-as: Assisted Sight (467/1071)
# ✅ Processed: Doornamo (468/1071)
# ✅ Processed: Little Free Libgen (469/1071)
# ✅ Processed: Dust Dolphin (470/1071)
# ✅ Processed: ECHO: Enhanced Communication Hearing Oscillator (471/1071)
# ✅ Processed: Lithophane Lightup Fixture (472/1071)
# ✅ Processed: Go Towards the Light (473/1071)
# ✅ Processed: Score Master (474/1071)
# ✅ Processed: Nature Nurturer (475/1071)
# ✅ Processed: Health App (476/1071)
# ✅ Processed: Cheapest Flight Ticket Generation and Booking CLI-BOT (477/1071)
# ✅ Processed: GAUSS - Pinpoint geodata (478/1071)
# ✅ Processed: In Arm's Reach (479/1071)
# ✅ Processed: Block Party (480/1071)
# ✅ Processed: Noir (481/1071)
# ✅ Processed: Team 71 - Bounce Ball (482/1071)
# ✅ Processed: RECOVR (483/1071)
# ✅ Processed: SKYWARD (484/1071)
# ✅ Processed: A "Fire" Training App (485/1071)
# ✅ Processed: Talk to Me (486/1071)
# ✅ Processed: Legacy (487/1071)
# ✅ Processed: Community Canvas (488/1071)
# ✅ Processed: snAIder (489/1071)
# ✅ Processed: GEOQUEST AR (490/1071)
# ✅ Processed: Beesper (491/1071)
# ✅ Processed: Dr. Trust (492/1071)
# ✅ Processed: EduVision (493/1071)
# ✅ Processed: PlantAR (494/1071)
# ✅ Processed: HeaVR (495/1071)
# ✅ Processed: FlexVR Wellness (496/1071)
# ✅ Processed: MemoryMingle (497/1071)
# ✅ Processed: PocketFest (498/1071)
# ✅ Processed: Museum of Future Perfect (499/1071)
# ✅ Processed: Synergy & Survival (500/1071)
# ✅ Processed: XR Wilderness Academy (501/1071)
# ✅ Processed: GAL-XR (502/1071)
# ✅ Processed: Record Reality (503/1071)
# ✅ Processed: Code Hero (504/1071)
# ✅ Processed: Gesture VR (505/1071)
# ✅ Processed: SPHERE (506/1071)
# ✅ Processed: StageFlow (507/1071)
# ✅ Processed: Moji (508/1071)
# ✅ Processed: Ever-present (509/1071)
# ✅ Processed: Traces (510/1071)
# ✅ Processed: PastVista (511/1071)
# ✅ Processed: EmpoweredAR (512/1071)
# ✅ Processed: Mool (513/1071)
# ✅ Processed: Collage MR (514/1071)
# ✅ Processed: WEDGE: Wireless, Ergonomic, Dynamic Gesture Enhancer (515/1071)
# ✅ Processed: Memories of Kumi-Daiko (516/1071)
# ✅ Processed: SubLynk (517/1071)
# ✅ Processed: Fire Drill XR (518/1071)
# ✅ Processed: Ball Lightning (519/1071)
# ✅ Processed: A Day's Blur VR (520/1071)
# ✅ Processed: Destiny (521/1071)
# ✅ Processed: Wave Goodbye (522/1071)
# ✅ Processed: Voyagery (523/1071)
# ✅ Processed: Team #42 - Ancestral Apron (524/1071)
# ✅ Processed: Mushin (525/1071)
# ✅ Processed: GenZen (526/1071)
# ✅ Processed: LivelyLens (527/1071)
# ✅ Processed: StellarScope: Connecting with the Cosmos (528/1071)
# ✅ Processed: SupportXR (529/1071)
# ✅ Processed: Super Smash Trash (530/1071)
# ✅ Processed: Cycle (531/1071)
# ✅ Processed: Mentor Reality (532/1071)
# ✅ Processed: netwARk (533/1071)
# ✅ Processed: Starscape (534/1071)
# ✅ Processed: RealAccess.VR (535/1071)
# ✅ Processed: Unity Enzo (536/1071)
# ✅ Processed: AIRBLOCKS (537/1071)
# ✅ Processed: MindfulStride (538/1071)
# ✅ Processed: EmpathyEase (539/1071)
# ✅ Processed: AgriCommandXR (540/1071)
# ✅ Processed: Steeped in sereniTEA: From Virtuality to Reality (541/1071)
# ✅ Processed: Visclude (542/1071)
# ✅ Processed: Braille XR (543/1071)
# ✅ Processed: DelivAR Angel (544/1071)
# ✅ Processed: SensEasy (545/1071)
# ✅ Processed: Rat in the Hat (546/1071)
# ✅ Processed: Jump On It (547/1071)
# ✅ Processed: Shroom Hunt (548/1071)
# ✅ Processed: Operator (549/1071)
# ✅ Processed: p.e.c.k. (550/1071)
# ✅ Processed: HealMotion (551/1071)
# ✅ Processed: PinPals (552/1071)
# ✅ Processed: ReadyXR (553/1071)
# ✅ Processed: MindToBoard (554/1071)
# ✅ Processed: VerseVerse - Spatial Language Learning (555/1071)
# ✅ Processed: Pando (556/1071)
# ✅ Processed: Virtual Fantasy Productivity Weapon (557/1071)
# ✅ Processed: Swing Coach (558/1071)
# ✅ Processed: 63 Galleria (559/1071)
# ✅ Processed: DELTA REAL/ation - Empowering Migrant Futures (560/1071)
# ✅ Processed: WeSources (561/1071)
# ✅ Processed: MR Fossil (562/1071)
# ✅ Processed: Treasure Trove (563/1071)
# ✅ Processed: Hungry Gaussians (564/1071)
# ✅ Processed: OurBloc (565/1071)
# ✅ Processed: NetConnect (566/1071)
# ✅ Processed: Hacker Quest (567/1071)
# ✅ Processed: Penpals (568/1071)
# ✅ Processed: Happy Balloon Fun Time (569/1071)
# ✅ Processed: ThriveHive (570/1071)
# ✅ Processed: FarMR (571/1071)
# ✅ Processed: the library of beautiful things (572/1071)
# ✅ Processed: Adulting 101 (573/1071)
# ✅ Processed: Memory Lane (574/1071)
# ✅ Processed: Echoes of Silence (575/1071)
# ✅ Processed: 3Datalyze [Team B306, Table 61] (576/1071)
# ✅ Processed: Needlehelp (577/1071)
# ✅ Processed: Memora: Clear Your Mind, Conquer Your Day. (578/1071)
# ✅ Processed: FUNDR (579/1071)
# ✅ Processed: RealityCheck (580/1071)
# ✅ Processed: genarrex (581/1071)
# ✅ Processed: EcoLLM (582/1071)
# ✅ Processed: BassGPT (583/1071)
# ✅ Processed: FinDaddy (584/1071)
# ✅ Processed: RxRecruits (585/1071)
# ✅ Processed: MedVision (586/1071)
# ✅ Processed: ARise AR Flashcards (587/1071)
# ✅ Processed: SightSense (588/1071)
# ✅ Processed: GemiStudi (589/1071)
# ✅ Processed: ClinSync (590/1071)
# ✅ Processed: Rapid.Tech (591/1071)
# ✅ Processed: PomoFlash (592/1071)
# ✅ Processed: Pick playlist (593/1071)
# ✅ Processed: MedSage (594/1071)
# ✅ Processed: Invent-ory (595/1071)
# ✅ Processed: Bankify (596/1071)
# ✅ Processed: Sarcastic Bearcat (597/1071)
# ✅ Processed: Legit Company (598/1071)
# ✅ Processed: Commit (599/1071)
# ✅ Processed: Feng's Way (600/1071)
# ✅ Processed: MolCure (601/1071)
# ✅ Processed: SwiftDrop (602/1071)
# ✅ Processed: Outbreak_Nexus (603/1071)
# ✅ Processed: DoseWise (604/1071)
# ✅ Processed: HireFlow (605/1071)
# ✅ Processed: Team MedScribe (606/1071)
# ✅ Processed: Facebook Marketplace Cleanser (607/1071)
# ✅ Processed: Know-How Hub (608/1071)
# ✅ Processed: BullBear (609/1071)
# ✅ Processed: Forky – Your Open-Source AI Copilot! (610/1071)
# ✅ Processed: Leo's Kitchen (611/1071)
# ✅ Processed: Social Media Content Moderator (612/1071)
# ✅ Processed: Ever-Mind (613/1071)
# ✅ Processed: SustainGenius (614/1071)
# ✅ Processed: Beachies (615/1071)
# ✅ Processed: replies.ai (616/1071)
# ✅ Processed: UniCircle (617/1071)
# ✅ Processed: Bad USB Detector (618/1071)
# ✅ Processed: SatSignal Seeker (619/1071)
# ✅ Processed: Modern Wellness Companion (620/1071)
# ✅ Processed: PhysiCube (621/1071)
# ✅ Processed: Breakfast Bar (622/1071)
# ✅ Processed: ByteBlox (623/1071)
# ✅ Processed: Financial Future (624/1071)
# ✅ Processed: Secure Sight (625/1071)
# ✅ Processed: JobLens (626/1071)
# ✅ Processed: Visual Black Jack Game (627/1071)
# ✅ Processed: Emotional AI Chatbot (628/1071)
# ✅ Processed: Speak Sign (629/1071)
# ✅ Processed: Feather | Ethical Investing, Made Easy (630/1071)
# ✅ Processed: WebAble (631/1071)
# ✅ Processed: SmartTrack AI Health SOlutoin (632/1071)
# ✅ Processed: OptiLine (633/1071)
# ✅ Processed: Click Mr. Whiskers (634/1071)
# ✅ Processed: CPASS: Cincinnati Public Accessibility - System Survey (635/1071)
# ✅ Processed: 8-Bit-Beats (636/1071)
# ✅ Processed: HawkWatch (637/1071)
# ✅ Processed: OmNom (638/1071)
# ✅ Processed: Hearti (639/1071)
# ✅ Processed: Edith (640/1071)
# ✅ Processed: BrailleBot: Make Every Document Accessible! (641/1071)
# ✅ Processed: BlinkAI (642/1071)
# ✅ Processed: Iris (643/1071)
# ✅ Processed: SurviveX (644/1071)
# ✅ Processed: PUSHPA - Pyro UAV System for High-risk Patrol and Alerting (645/1071)
# ✅ Processed: MediLedger (646/1071)
# ✅ Processed: AgentZero (647/1071)
# ✅ Processed: ECGo (648/1071)
# ✅ Processed: Therms - Thermoregulation Wearables with AI-powered Insights (649/1071)
# ✅ Processed: Project AVIA (650/1071)
# ✅ Processed: VisionGuard: smart vision for smarter driving (651/1071)
# ✅ Processed: HiveMind (652/1071)
# ✅ Processed: ERWIN: Enhanced Rock Weathering Impact Navigator (653/1071)
# ✅ Processed: BAS Climate Action Matcher (654/1071)
# ✅ Processed: Lemon (655/1071)
# ✅ Processed: Ranger (656/1071)
# ✅ Processed: WiiWork (657/1071)
# ✅ Processed: Portable Braille (658/1071)
# ✅ Processed: CyberDrive (659/1071)
# ✅ Processed: HorizonX (660/1071)
# ✅ Processed: WingNote (661/1071)
# ✅ Processed: Lumora (662/1071)
# ✅ Processed: Noteworthy: Visualize, Capture, Remember. (663/1071)
# ✅ Processed: FlowPilot: Your Agentic Co-Pilot (664/1071)
# ✅ Processed: ZoneOut (665/1071)
# ✅ Processed: BEF (666/1071)
# ✅ Processed: WatchDog AI (667/1071)
# ✅ Processed: Cipher Shield (668/1071)
# ✅ Processed: The Giving Tree (669/1071)
# ✅ Processed: Moods and Metrics (670/1071)
# ✅ Processed: Vigilante (671/1071)
# ✅ Processed: Superclassroom (672/1071)
# ✅ Processed: Verify (673/1071)
# ✅ Processed: SynapseAI (674/1071)
# ✅ Processed: Conductor AI (675/1071)
# ✅ Processed: CodeInsight (676/1071)
# ✅ Processed: Swarm AI (677/1071)
# ✅ Processed: PULSE.AI (678/1071)
# ✅ Processed: traider (679/1071)
# ✅ Processed: TheraMind (680/1071)
# ✅ Processed: Agent Ricky (681/1071)
# ✅ Processed: Motherly.ai (682/1071)
# ✅ Processed: ProtestLink (683/1071)
# ✅ Processed: CodeForge Pages (684/1071)
# ✅ Processed: theo (685/1071)
# ✅ Processed: <PriorityQueue> (686/1071)
# ✅ Processed: CodeCrack (687/1071)
# ✅ Processed: The Duck You Mean? (688/1071)
# ✅ Processed: EcoBite (689/1071)
# ✅ Processed: Sprout (690/1071)
# ✅ Processed: Caren AI (691/1071)
# ✅ Processed: Navi (692/1071)
# ✅ Processed: Spheroid Tumor Invasion Kinetics (STIK) GUI (693/1071)
# ✅ Processed: Plot (694/1071)
# ✅ Processed: The Anachronist (695/1071)
# ✅ Processed: Mirror (696/1071)
# ✅ Processed: Sherlock (697/1071)
# ✅ Processed: Fable (698/1071)
# ✅ Processed: TreeTrash (699/1071)
# ✅ Processed: Zue Research (700/1071)
# ✅ Processed: Lattice: Orchestrating end-to-end web workflows at scale (701/1071)
# ✅ Processed: Spielberg AI (702/1071)
# ✅ Processed: NeuroPilot: Brainwave Computer Control (703/1071)
# ✅ Processed: Miru (704/1071)
# ✅ Processed: CodeFusion (705/1071)
# ✅ Processed: Supernova (706/1071)
# ✅ Processed: Runway (707/1071)
# ✅ Processed: Trailhead (708/1071)
# ✅ Processed: StoryBridge (709/1071)
# ✅ Processed: ArmI (710/1071)
# ✅ Processed: Tradelingo (711/1071)
# ✅ Processed: VisionMate: the AI agent to help visually impaired people (712/1071)
# ✅ Processed: Mustard Seed (713/1071)
# ✅ Processed: Om: Optimized Meditation (714/1071)
# ✅ Processed: Turwin (715/1071)
# ✅ Processed: SquadPulse: A Military Healthcare Analytics Platform (716/1071)
# ✅ Processed: J.A.R.V.I.S. — Augment Human Connection with Infinite Memory (717/1071)
# ✅ Processed: SnapAR3D (718/1071)
# ✅ Processed: Aegis (719/1071)
# ✅ Processed: ConvoCoach (720/1071)
# ✅ Processed: Chronos Calendar (721/1071)
# ✅ Processed: booksy (722/1071)
# ✅ Processed: Phonix (723/1071)
# ✅ Processed: GenuisAI (724/1071)
# ✅ Processed: Identity AI (725/1071)
# ✅ Processed: Atlas (726/1071)
# ✅ Processed: ChainEscapeLite (727/1071)
# ✅ Processed: Blacksmith (728/1071)
# ✅ Processed: Pyro*AI (729/1071)
# ✅ Processed: TeachAI (730/1071)
# ✅ Processed: Bongaloons (Bongo Cat IRL) (731/1071)
# ✅ Processed: Genetic Disorder Detection via cDNA Frequency Map (732/1071)
# ✅ Processed: Tesla VLM Track (733/1071)
# ✅ Processed: Sync (734/1071)
# ✅ Processed: eHealth (735/1071)
# ✅ Processed: Roomba Nurse (736/1071)
# ✅ Processed: Heart-BEATS (737/1071)
# ✅ Processed: SeedLink (738/1071)
# ✅ Processed: D.E.V.I.S (739/1071)
# ✅ Processed: ArticuAIte (740/1071)
# ✅ Processed: Talk (741/1071)
# ✅ Processed: Grant Scoper (742/1071)
# ✅ Processed: Engage: Real-time AI Agents for Smarter Classrooms (743/1071)
# ✅ Processed: SquadPulse (744/1071)
# ✅ Processed: Tradegentix (745/1071)
# ✅ Processed: Driptionary (746/1071)
# ✅ Processed: Surgentic (747/1071)
# ✅ Processed: Shopybara (748/1071)
# ✅ Processed: MindShift: AI for Bipolar Care (749/1071)
# ✅ Processed: ResearchLens (750/1071)
# ✅ Processed: CogniBoost (751/1071)
# ✅ Processed: ASL Live Translator (752/1071)
# ✅ Processed: Stream (753/1071)
# ✅ Processed: Vuzz (754/1071)
# ✅ Processed: Posthuman (755/1071)
# ✅ Processed: TheraPlushie (756/1071)
# ✅ Processed: Avengers, Assemble! (757/1071)
# ✅ Processed: LeXcel (758/1071)
# ✅ Processed: Sventos (759/1071)
# ✅ Processed: deep reach (760/1071)
# ✅ Processed: WabiSabi (761/1071)
# ✅ Processed: Pitcher (762/1071)
# ✅ Processed: Russel HomeBot (763/1071)
# ✅ Processed: MUSES (764/1071)
# ✅ Processed: VisionMate (765/1071)
# ✅ Processed: NeuroScribe: Brainwaves to speech and image (766/1071)
# ✅ Processed: annaOS (767/1071)
# ✅ Processed: x-rAI (768/1071)
# ✅ Processed: Bob: The Agent Builder (769/1071)
# ✅ Processed: Eco Field (770/1071)
# ✅ Processed: Macro - Swarm of Verifiable Agents for Portfolio Management (771/1071)
# ✅ Processed: Memody (772/1071)
# ✅ Processed: VShop AI (773/1071)
# ✅ Processed: Axon (774/1071)
# ✅ Processed: FlowScope:The Agentic Simulator for Predictive Flow Dynamics (775/1071)
# ✅ Processed: dAIos (776/1071)
# ✅ Processed: QuickQuack: The Ultimate Exam Grading Tool (777/1071)
# ✅ Processed: Green Growth (778/1071)
# ✅ Processed: WatchTower (779/1071)
# ✅ Processed: Theia (780/1071)
# ✅ Processed: EverCare (781/1071)
# ✅ Processed: Clampsai (782/1071)
# ✅ Processed: prototyp3d (783/1071)
# ✅ Processed: KERneL (784/1071)
# ✅ Processed: Haven (785/1071)
# ✅ Processed: QPQP: Flexible Exchange Platform (786/1071)
# ✅ Processed: NeuroParallel.ai (787/1071)
# ✅ Processed: ModifAI (788/1071)
# ✅ Processed: MedMentor (789/1071)
# ✅ Processed: TreeCycle (790/1071)
# ✅ Processed: AfroVision (791/1071)
# ✅ Processed: NutriVision (792/1071)
# ✅ Processed: SoleMate (793/1071)
# ✅ Processed: CARBONLE (794/1071)
# ✅ Processed: CareNest (795/1071)
# ✅ Processed: Teacher.AI (796/1071)
# ✅ Processed: BackSeat_Driver (797/1071)
# ✅ Processed: Truth AI Agent (798/1071)
# ✅ Processed: HeartHack (799/1071)
# ✅ Processed: AeroForge 3D (800/1071)
# ✅ Processed: engagED (801/1071)
# ✅ Processed: gflow: probability data optimization (802/1071)
# ✅ Processed: AERO (803/1071)
# ✅ Processed: Odin (804/1071)
# ✅ Processed: Scrollarly (805/1071)
# ✅ Processed: TalkTuah (806/1071)
# ✅ Processed: CogniSync (807/1071)
# ✅ Processed: Odin AI (808/1071)
# ✅ Processed: IntelliCare (809/1071)
# ✅ Processed: TeslaQA (810/1071)
# ✅ Processed: cafe fra.me (811/1071)
# ✅ Processed: Revi (812/1071)
# ✅ Processed: Zeno (813/1071)
# ✅ Processed: Stable-RL (814/1071)
# ✅ Processed: Mobius (815/1071)
# ✅ Processed: VisionZ+ (816/1071)
# ✅ Processed: Octavius (817/1071)
# ✅ Processed: Bee Well (818/1071)
# ✅ Processed: StoryTime (819/1071)
# ✅ Processed: BuckyUp (820/1071)
# ✅ Processed: LLMaOS (821/1071)
# ✅ Processed: TalkThru (822/1071)
# ✅ Processed: Swiper, No Swiping! (823/1071)
# ✅ Processed: CapyGuardian (824/1071)
# ✅ Processed: focusr ai (825/1071)
# ✅ Processed: Honeycomb (826/1071)
# ✅ Processed: EcoNomNom: Sustainability One Snap at a Time (827/1071)
# ✅ Processed: JARVIS Health (828/1071)
# ✅ Processed: Myst (829/1071)
# ✅ Processed: Morpheus Ray-Bans: Your ASL Teacher (830/1071)
# ✅ Processed: Solana Rivals (831/1071)
# ✅ Processed: LogFlowAI (832/1071)
# ✅ Processed: Snap Chef (833/1071)
# ✅ Processed: Eduverse (834/1071)
# ✅ Processed: Orbit Cola (835/1071)
# ✅ Processed: 3Duroam (836/1071)
# ✅ Processed: Operator Optimization (837/1071)
# ✅ Processed: Wander (838/1071)
# ✅ Processed: AutoLeARn: AR + AI-Based Learning for Personal Car Repairs (839/1071)
# ✅ Processed: Poof! (840/1071)
# ✅ Processed: Rebase (841/1071)
# ✅ Processed: EmberScout: Autonomous Rescue for when Humans can't (842/1071)
# ✅ Processed: ZoomPulse (843/1071)
# ✅ Processed: EarlyBird (844/1071)
# ✅ Processed: SimuCHATlator (845/1071)
# ✅ Processed: VoteSmart (846/1071)
# ✅ Processed: SocratesAI (847/1071)
# ✅ Processed: The Cat (848/1071)
# ✅ Processed: Flow~State (849/1071)
# ✅ Processed: Klaw (850/1071)
# ✅ Processed: terra (851/1071)
# ✅ Processed: Fhirband (852/1071)
# ✅ Processed: Pet Talks (853/1071)
# ✅ Processed: Meredith (854/1071)
# ✅ Processed: CHRONOS - Satellite Powered Disaster Response (855/1071)
# ✅ Processed: Aegis Command (856/1071)
# ✅ Processed: ConnectHer (857/1071)
# ✅ Processed: Campus Food Truck (858/1071)
# ✅ Processed: Super Smash (859/1071)
# ✅ Processed: hydRation (860/1071)
# ✅ Processed: Omnis (861/1071)
# ✅ Processed: Ruminate (862/1071)
# ✅ Processed: Buzzy (863/1071)
# ✅ Processed: FitStreak (864/1071)
# ✅ Processed: Dashify (865/1071)
# ✅ Processed: mechanic (866/1071)
# ✅ Processed: gitRizz.ai (867/1071)
# ✅ Processed: Kaleidoscope (868/1071)
# ✅ Processed: LinguaVista - Language & Cultural Learning Platform (869/1071)
# ✅ Processed: Matcha Vibe (870/1071)
# ✅ Processed: Anim-Education (871/1071)
# ✅ Processed: Verifact (872/1071)
# ✅ Processed: Wellness Dorm (873/1071)
# ✅ Processed: Tower-bot: Towers of Hanoi Solver (874/1071)
# ✅ Processed: Lentil (875/1071)
# ✅ Processed: calvin (876/1071)
# ✅ Processed: Echo (877/1071)
# ✅ Processed: XrayVision (878/1071)
# ✅ Processed: Sign-Speak: No voice unheard (879/1071)
# ✅ Processed: PrescribatronJelqinator (880/1071)
# ✅ Processed: TrivAI (881/1071)
# ✅ Processed: ClassPulse (882/1071)
# ✅ Processed: nomnom! (883/1071)
# ✅ Processed: Eigensurance: AI x Web3 (884/1071)
# ✅ Processed: GHGuessr (885/1071)
# ✅ Processed: PrepTracker (886/1071)
# ✅ Processed: EasyRead (887/1071)
# ✅ Processed: xxx (888/1071)
# ✅ Processed: Slumber Synthesizer (889/1071)
# ✅ Processed: Nirmaan (890/1071)
# ✅ Processed: excelerator (891/1071)
# ✅ Processed: HackTCHA (892/1071)
# ✅ Processed: EigenInsure (893/1071)
# ✅ Processed: DispatchIQ (894/1071)
# ✅ Processed: ProtectEd (895/1071)
# ✅ Processed: Telescope: Spotting AI generated Content from a Mile Away (896/1071)
# ✅ Processed: VisionLink (897/1071)
# ✅ Processed: VTCourseNav (898/1071)
# ✅ Processed: VT Memegen (899/1071)
# ✅ Processed: SecureAI (900/1071)
# ✅ Processed: FishBook (901/1071)
# ✅ Processed: MapAbility (902/1071)
# ✅ Processed: Forge (903/1071)
# ✅ Processed: Subleasing VT (904/1071)
# ✅ Processed: IllumiLens AI (905/1071)
# ✅ Processed: Health PantryCam (906/1071)
# ✅ Processed: First Flight (907/1071)
# ✅ Processed: REFLƎCT ⱯI (908/1071)
# ✅ Processed: Linguify (909/1071)
# ✅ Processed: NestMates (910/1071)
# ✅ Processed: Site Sensei (911/1071)
# ✅ Processed: SeeBoard (912/1071)
# ✅ Processed: AmiGo (913/1071)
# ✅ Processed: InstaPC (914/1071)
# ✅ Processed: Hungry Hokies (915/1071)
# ✅ Processed: SafePath (916/1071)
# ✅ Processed: ConcertPal (917/1071)
# ✅ Processed: WhatTheFilm! (918/1071)
# ✅ Processed: Synchronize (919/1071)
# ✅ Processed: SNET - Secure Internet (920/1071)
# ✅ Processed: NestQuest (921/1071)
# ✅ Processed: Monocle (922/1071)
# ✅ Processed: house.inc (923/1071)
# ✅ Processed: Modern Inventory Management System (MIMS) (924/1071)
# ✅ Processed: PlasticBot (925/1071)
# ✅ Processed: StrumAlign (926/1071)
# ✅ Processed: ClearView AI (927/1071)
# ✅ Processed: PlatePal (928/1071)
# ✅ Processed: HearMail (929/1071)
# ✅ Processed: SchedEz (930/1071)
# ✅ Processed: EagleEye Ai (931/1071)
# ✅ Processed: BetterYou (932/1071)
# ✅ Processed: EyeScreen (933/1071)
# ✅ Processed: Scam't (934/1071)
# ✅ Processed: CHUT (935/1071)
# ✅ Processed: IntelliQuest (936/1071)
# ✅ Processed: Peony (937/1071)
# ✅ Processed: NutriChef (938/1071)
# ✅ Processed: PRAP - Physical recognition activated prosthesis (939/1071)
# ✅ Processed: Food Decisive (940/1071)
# ✅ Processed: Aperta (941/1071)
# ✅ Processed: IntelOps (942/1071)
# ✅ Processed: deQlassified (943/1071)
# ✅ Processed: HokiePokie (944/1071)
# ✅ Processed: CSmasher (945/1071)
# ✅ Processed: Street Smart (946/1071)
# ✅ Processed: HackNet (947/1071)
# ✅ Processed: Cultural Odyssey (948/1071)
# ✅ Processed: SkillSprint (949/1071)
# ✅ Processed: ambuLLMce (950/1071)
# ✅ Processed: Danger Dash (951/1071)
# ✅ Processed: USE IT OR LOSE IT! (952/1071)
# ✅ Processed: Competitive Gains (953/1071)
# ✅ Processed: Produce Pals (954/1071)
# ✅ Processed: Sidequest (955/1071)
# ✅ Processed: Mind Fuel (956/1071)
# ✅ Processed: HomeView (957/1071)
# ✅ Processed: Simplifile (958/1071)
# ✅ Processed: SafeNav (959/1071)
# ✅ Processed: HokieSWAP (960/1071)
# ✅ Processed: LaunchPoint (961/1071)
# ✅ Processed: Locus (962/1071)
# ✅ Processed: HouseMatchGPT (963/1071)
# ✅ Processed: Amplytics (964/1071)
# ✅ Processed: HomeRec (965/1071)
# ✅ Processed: creditJAM (966/1071)
# ✅ Processed: Schedule Eatz (967/1071)
# ✅ Processed: ⚽️ RoboLeague (968/1071)
# ✅ Processed: hokie housing (969/1071)
# ✅ Processed: HeadlinerAI (970/1071)
# ✅ Processed: VoiceNest (971/1071)
# ✅ Processed: SmartSearch (972/1071)
# ✅ Processed: HomeScout AI (973/1071)
# ✅ Processed: Splittle (974/1071)
# ✅ Processed: HomeRun (975/1071)
# ✅ Processed: HokieGPT (976/1071)
# ✅ Processed: HomeAwayU (977/1071)
# ✅ Processed: BikerPro (978/1071)
# ✅ Processed: CultureTap (979/1071)
# ✅ Processed: HokieEATS (980/1071)
# ✅ Processed: Swipe Overflow (981/1071)
# ✅ Processed: RoomUp (982/1071)
# ✅ Processed: Platepost (983/1071)
# ✅ Processed: CookCal (984/1071)
# ✅ Processed: RideHub (985/1071)
# ✅ Processed: Don't Drive Off! (986/1071)
# ✅ Processed: IncidentAI (987/1071)
# ✅ Processed: QUETZL (988/1071)
# ✅ Processed: safeNest (989/1071)
# ✅ Processed: Homiez (990/1071)
# ✅ Processed: Campus Flock (991/1071)
# ✅ Processed: Waitless (992/1071)
# ✅ Processed: AlertAI (993/1071)
# ✅ Processed: Intoxicaution VR (994/1071)
# ✅ Processed: NuHomes.co(m) (995/1071)
# ✅ Processed: gEYEd me (996/1071)
# ✅ Processed: PeerPlates (997/1071)
# ✅ Processed: Calm Compass (998/1071)
# ✅ Processed: ResponseFlow (999/1071)
# ✅ Processed: VeggieSwap (1000/1071)
# ✅ Processed: CrossDash (1001/1071)
# ✅ Processed: Dinologue (1002/1071)
# ✅ Processed: HokieHomes (1003/1071)
# ✅ Processed: Realtor 101 (1004/1071)
# ✅ Processed: Stripe Play (1005/1071)
# ✅ Processed: Aviate.ai (1006/1071)
# ✅ Processed: Goku Homes (1007/1071)
# ✅ Processed: 911 Emergency AI assistant (EmAA) (1008/1071)
# ✅ Processed: UniHub (1009/1071)
# ✅ Processed: Cache It! (1010/1071)
# ✅ Processed: TradeMaster (1011/1071)
# ✅ Processed: forecastai.biz (1012/1071)
# ✅ Processed: Busy or Not? (1013/1071)
# ✅ Processed: GeoNest (1014/1071)
# ✅ Processed: Choo Choo (1015/1071)
# ✅ Processed: RepRight (1016/1071)
# ✅ Processed: Pantry Pilot (1017/1071)
# ✅ Processed: Hearth (1018/1071)
# ✅ Processed: Aurelia (1019/1071)
# ✅ Processed: Smart Parking Availability Tracker (1020/1071)
# ✅ Processed: Canary (1021/1071)
# ✅ Processed: Signiverse (1022/1071)
# ✅ Processed: HokiePool (1023/1071)
# ✅ Processed: Bites (1024/1071)
# ✅ Processed: TinDnDr (1025/1071)
# ✅ Processed: FliporFlop (1026/1071)
# ✅ Processed: Smiles & Stats GPT (1027/1071)
# ✅ Processed: Studymon (1028/1071)
# ✅ Processed: Habit Streaks (1029/1071)
# ✅ Processed: LifeStack (1030/1071)
# ✅ Processed: Emerge (1031/1071)
# ✅ Processed: InHabit (1032/1071)
# ✅ Processed: Lil Munster (1033/1071)
# ✅ Processed: ledgerio (1034/1071)
# ✅ Processed: Sign-Connect (1035/1071)
# ✅ Processed: How's My House (1036/1071)
# ✅ Processed: Haloe (1037/1071)
# ✅ Processed: hokiesWayHome (1038/1071)
# ✅ Processed: Nutricampus (1039/1071)
# ✅ Processed: cabinIt (1040/1071)
# ✅ Processed: Dr.HowAI (1041/1071)
# ✅ Processed: ResumAId (1042/1071)
# ✅ Processed: Recipeasy (1043/1071)
# ✅ Processed: Hokie Productivity Insight (1044/1071)
# ✅ Processed: Ballot Pulse (1045/1071)
# ✅ Processed: BiteFight (1046/1071)
# ✅ Processed: Pure Skin AI (1047/1071)
# ✅ Processed: Market Sprout (1048/1071)
# ✅ Processed: AIRE (1049/1071)
# ✅ Processed: Gobbler Guantlet (1050/1071)
# ✅ Processed: PantryPlanner (1051/1071)
# ✅ Processed: WeatherWatch (1052/1071)
# ✅ Processed: Ticket Racer (1053/1071)
# ✅ Processed: HokieHood (1054/1071)
# ✅ Processed: Hackathon Matcher (1055/1071)
# ✅ Processed: UniRide (1056/1071)
# ✅ Processed: Looking for Study Group (1057/1071)
# ✅ Processed: Rate My Exam (1058/1071)
# ✅ Processed: Meal Gauge (1059/1071)
# ✅ Processed: Homeview (1060/1071)
# ✅ Processed: Apartmate (1061/1071)
# ✅ Processed: SeiyuuSync (1062/1071)
# ✅ Processed: SmartCalendar (1063/1071)
# ✅ Processed: Real Estate Analyzer (1064/1071)
# ✅ Processed: InclusiveBot (1065/1071)
# ✅ Processed: Organic Food FInder (1066/1071)
# ✅ Processed: SquatMap (1067/1071)
# ✅ Processed: OriGaming (1068/1071)
# ✅ Processed: Ask Hokie (1069/1071)
# ✅ Processed: GrocerAi (1070/1071)
# ✅ Processed: internot.blog (1071/1071)
# ✅ Saved 1071 detailed projects from all_detailed.csv to all_detailed.csv_detailed.csv
#          hackathon_name                       project_name  \
# 0     Auburn Hacks 2024                           Resumate
# 1     Auburn Hacks 2024  Courage The Not-so Cowardly Rover
# 2     Auburn Hacks 2024                        Planetarium
# 3     Auburn Hacks 2024                    Orbital Sandbox
# 4     Auburn Hacks 2024                         OrbitQuest
# ...                 ...                                ...
# 1066         VTHacks 12                           SquatMap
# 1067         VTHacks 12                          OriGaming
# 1068         VTHacks 12                          Ask Hokie
# 1069         VTHacks 12                           GrocerAi
# 1070         VTHacks 12                      internot.blog
#
#                                            project_link  winner  \
# 0          https://devpost.com/software/resumate-bwk81m    True
# 1     https://devpost.com/software/courage-the-not-s...    True
# 2       https://devpost.com/software/planetarium-nzc1a7    True
# 3          https://devpost.com/software/orbital-sandbox    True
# 4               https://devpost.com/software/orbitquest    True
# ...                                                 ...     ...
# 1066              https://devpost.com/software/squatmap   False
# 1067             https://devpost.com/software/origaming   False
# 1068       https://devpost.com/software/hokie-plus-plus   False
# 1069              https://devpost.com/software/grocerai   False
# 1070         https://devpost.com/software/internot-blog   False
#
#                                             inspiration  \
# 0     Resumate was inspired by the challenge job see...
# 1     Our inspiration came from the resources NASA p...
# 2     Animated Earth Animated sprite fl studio Clip ...
# 3     Interplanetary space exploration is becoming a...
# 4     The theme this year is space travel. So why no...
# ...                                                 ...
# 1066   Our project, "SquatDown," has goal to assist ...
# 1067  Since high school, we have had an interest in ...
# 1068  Ask HOKIE Problem Statement Technical Framewor...
# 1069
# 1070  Inspired by the concept of the 'dead internet ...
#
#                                            what_it_does  \
# 0     Resumate is a web application that utilizes ad...
# 1     In this Mars Rover educational game, players e...
# 2
# 3     The simulator allows you to fly a spacecraft a...
# 4     OrbitQuesttracks the ISS as it travels around ...
# ...                                                 ...
# 1066
# 1067  0rigAmIng is a "paper-folding simulator" that ...
# 1068
# 1069
# 1070  Internot.blog is a blog website where every po...
#
#                                         how_we_built_it  \
# 0     We built Resumate using Flask for the backend,...
# 1
# 2
# 3     The app was built in the Unity game-engine, wh...
# 4     We usedthree.jsfor the 3-D graphics portion of...
# ...                                                 ...
# 1066
# 1067       We built 0rigAmIng fully in Godot Engine 3D.
# 1068
# 1069
# 1070  We set up and used a locally hosted instance o...
#
#                                              challenges  \
# 0     One of the main challenges was ensuring the AI...
# 1
# 2
# 3     The primary challenge for the design was build...
# 4     One significant challenge we faced was maintai...
# ...                                                 ...
# 1066
# 1067  Where do we even begin? To start, none of us h...
# 1068
# 1069
# 1070  Generating images that don't look like complet...
#
#                                         accomplishments  \
# 0     We're proud of creating a tool that can genuin...
# 1
# 2
# 3     We are very proud of the real-time simulation ...
# 4     We are extremely proud of the appearance of ou...
# ...                                                 ...
# 1066
# 1067  Our first big strides in the project were when...
# 1068
# 1069
# 1070  The system is able to operate entirely autonom...
#
#                                         what_we_learned  \
# 0     Throughout the development of Resumate, we lea...
# 1
# 2
# 3
# 4
# ...                                                 ...
# 1066
# 1067  Well, we learned that hackathons are crazy! Bu...
# 1068
# 1069
# 1070  AI is really good at making up stories about e...
#
#                                              next_steps  \
# 0     Looking ahead, we plan to incorporate more per...
# 1
# 2
# 3     Hopefully, after the completion of AuburnHACKS...
# 4     In the future, we want to implement real-time ...
# ...                                                 ...
# 1066
# 1067
# 1068
# 1069
# 1070  We will let it run and generate new content fo...
#
#                                              built_with  \
# 0                css3, flask, html5, javascript, openai
# 1       blendr, c#, mixtral, nasa, nginx, ollama, unity
# 2                      clipstudiopaint, flstudio, unity
# 3                                             c#, unity
# 4     css, debian, digitalocean, django, git, github...
# ...                                                 ...
# 1066  css, google-maps, html, javascript, node.js, r...
# 1067                                              godot
# 1068    css3, gpt, llm, mlh, mongodb, propelauth, react
# 1069  azure, css, html, javascript, langchain, node....
# 1070  css3, go, html5, hugo, llama3.1, rust, stable-...
#
#                                          external_links
# 0            https://github.com/Michaelgathara/resumate
# 1        https://github.com/abearinatrap/auburnhack2024
# 2
# 3     https://github.com/EirikMulder/HackEpicUnityPr...
# 4     https://orbitquest.co, https://github.com/TheS...
# ...                                                 ...
# 1066        https://github.com/harshalarakala/squatdown
# 1067                 https://github.com/vaaar/OriGaming
# 1068            https://github.com/mahatokunal/askHokie
# 1069  https://www.lesstimeshoppingandmoretimeto.stud...
# 1070  https://internot.blog/, https://github.com/int...
#
# [1071 rows x 13 columns]
