# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("All_projects_with_details.csv")
df
# Out:
#            hackathon_name   project_name  \
# 0     Hack The North 2020     QuaranTime
# 1     Hack The North 2020    FridgeSpace
# 2     Hack The North 2020       helppier
# 3     Hack The North 2020         mashme
# 4     Hack The North 2020   Mall Monitor
# ...                   ...            ...
# 7490     HackRice 14 2024  Degree Map AI
# 7491     HackRice 14 2024    Money Mania
# 7492     HackRice 14 2024   AudioAnalyze
# 7493     HackRice 14 2024      RestoreIO
# 7494     HackRice 14 2024        MedSure
#
#                                            project_link  winner  \
# 0     https://devpost.com/software/boredombuster-hnimzc    True
# 1              https://devpost.com/software/fridgespace    True
# 2          https://devpost.com/software/helppier-k5lbru    True
# 3                   https://devpost.com/software/mashme    True
# 4             https://devpost.com/software/mall-monitor    True
# ...                                                 ...     ...
# 7490     https://devpost.com/software/degree-planner-ai   False
# 7491           https://devpost.com/software/money-mania   False
# 7492   https://devpost.com/software/audioanalyze-muw9zk   False
# 7493            https://devpost.com/software/tbd-ir3qd5   False
# 7494            https://devpost.com/software/tbd-72iomb   False
#
#                                             inspiration  \
# 0     Due to being stuck at home during Quarantine s...
# 1     Based on the observation that most household w...
# 2     Inspired by the newly born solidarity within t...
# 3     We're a team of 'music people' who are in a ba...
# 4     Covid-19 has ravaged the World since early 202...
# ...                                                 ...
# 7490  As current undergraduate students trying to na...
# 7491  Our inspiration for this project was this book...
# 7492  The inspiration behind this project came from ...
# 7493  RestoreIO was created in response to the deman...
# 7494  As young college students, we are often poorly...
#
#                                            what_it_does  \
# 0     QuaranTime is an app where a schedule is gener...
# 1     FridgeSpace allows household users to locate a...
# 2     Helppier's goal is to encourage a new social n...
# 3     mashme allows the user to select two songs, an...
# 4     Mall Monitor allows owners and guests to monit...
# ...                                                 ...
# 7490  Degree Map AI includes a React front-end and a...
# 7491  This game teaches people about personal financ...
# 7492                                                NaN
# 7493                                                NaN
# 7494  Our key features: 1) Simplify the insurance hu...
#
#                                         how_we_built_it  \
# 0     We decided to face a new challenge. Due to the...
# 1     We began by creating designs for our app using...
# 2     In order to build a decentralized network wher...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 7490  We first started by working on the scraper, fr...
# 7491  We built this in Python using PyGame. We split...
# 7492                                                NaN
# 7493                                                NaN
# 7494  Since we wanted to implement a machine learnin...
#
#                                              challenges  \
# 0     There were many challenges that we faced. One ...
# 1     The biggest challenge we had to face was learn...
# 2     While the developers of the team have experien...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 7490  One challenge we faced was figuring out the be...
# 7491  None of us have ever participated in a hackath...
# 7492                                                NaN
# 7493                                                NaN
# 7494                                                NaN
#
#                                         accomplishments  \
# 0     We are proud of the ability to use the Google ...
# 1                                                   NaN
# 2     We are extremely proud to have been able to de...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 7490  We're proud to have successfully connected the...
# 7491  We are proud of the fact we have a finished pr...
# 7492                                                NaN
# 7493                                                NaN
# 7494                                                NaN
#
#                                         what_we_learned  \
# 0     We were able to learn much more than expected ...
# 1     There were many new technologies we learned in...
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 7490  We learned to set up OpenAI's ChatGPT, scrape ...
# 7491  We learned that creating a layout in PyGame is...
# 7492                                                NaN
# 7493                                                NaN
# 7494                                                NaN
#
#                                              next_steps  \
# 0     If we had more time, we would add features suc...
# 1     Future Steps for our team include working with...
# 2                                                   NaN
# 3     ML training for chorus and verse separation! C...
# 4     Actually deploying and consuming the REST API ...
# ...                                                 ...
# 7490  Given the limited amount of time, we were only...
# 7491  Money Mania will have expansions in the invest...
# 7492                                                NaN
# 7493                                                NaN
# 7494                                                NaN
#
#                                              built_with  \
# 0                             dart, flutter, googleapis
# 1     cockroachdb, flask, python, sqlalchemy, swift,...
# 2     azure, blockchain, cockroach.db, css3, express...
# 3     bootstrap, domain.com, flask, google-compute-e...
# 4     angular.js, azure, css, flask, html, javascrip...
# ...                                                 ...
# 7490    c++, javascript, openai, pyflask, python, react
# 7491                                     pygame, python
# 7492  ai, generative, lambda-(for-serverless-process...
# 7493  ai, computer, computervision, love, mediapipe,...
# 7494                   mapbox, python, typescript, vite
#
#                                          external_links
# 0     https://github.com/JackFrostDJ/HTN-App/tree/ma...
# 1               https://github.com/Harin329/FridgeSpace
# 2     https://github.com/aminecs/magic4, https://www...
# 3                                    http://mashme.tech
# 4     https://github.com/RemeAjayi/mall-monitor, htt...
# ...                                                 ...
# 7490          https://github.com/april2546/HackRice2024
# 7491          https://github.com/ashwinrao1/Hackathon24
# 7492      https://github.com/Ayush374/Ai_Audio_Analysis
# 7493  https://github.com/OfficialCodeVoyage/HackRice...
# 7494            https://github.com/leon934/hackrice2425
#
# [7495 rows x 13 columns]

# %%
df.isna().sum()
# Out:
# hackathon_name        0
# project_name          3
# project_link          0
# winner                0
# inspiration         483
# what_it_does       1793
# how_we_built_it    2611
# challenges         2878
# accomplishments    3215
# what_we_learned    3242
# next_steps         2437
# built_with           21
# external_links      924
# dtype: int64

# %%
# Drop rows where both 'inspiration' and 'external_links' are NaN
df = df.dropna(subset=['inspiration'], how='all')

# Reset index after dropping
df = df.reset_index(drop=True)

# %%
df.isna().sum()
# Out:
# hackathon_name        0
# project_name          1
# project_link          0
# winner                0
# inspiration           0
# what_it_does       1496
# how_we_built_it    2321
# challenges         2584
# accomplishments    2895
# what_we_learned    2906
# next_steps         2155
# built_with           15
# external_links      820
# dtype: int64

# %%
# Drop rows where both 'inspiration' and 'external_links' are NaN
df = df.dropna(subset=['external_links'], how='all')

# Reset index after dropping
df = df.reset_index(drop=True)

# %%
df.isna().sum()
# Out:
# hackathon_name        0
# project_name          0
# project_link          0
# winner                0
# inspiration           0
# what_it_does       1284
# how_we_built_it    1993
# challenges         2242
# accomplishments    2511
# what_we_learned    2514
# next_steps         1873
# built_with            6
# external_links        0
# dtype: int64

# %%
df
# Out:
#            hackathon_name   project_name  \
# 0     Hack The North 2020     QuaranTime
# 1     Hack The North 2020    FridgeSpace
# 2     Hack The North 2020       helppier
# 3     Hack The North 2020         mashme
# 4     Hack The North 2020   Mall Monitor
# ...                   ...            ...
# 6187     HackRice 14 2024  Degree Map AI
# 6188     HackRice 14 2024    Money Mania
# 6189     HackRice 14 2024   AudioAnalyze
# 6190     HackRice 14 2024      RestoreIO
# 6191     HackRice 14 2024        MedSure
#
#                                            project_link  winner  \
# 0     https://devpost.com/software/boredombuster-hnimzc    True
# 1              https://devpost.com/software/fridgespace    True
# 2          https://devpost.com/software/helppier-k5lbru    True
# 3                   https://devpost.com/software/mashme    True
# 4             https://devpost.com/software/mall-monitor    True
# ...                                                 ...     ...
# 6187     https://devpost.com/software/degree-planner-ai   False
# 6188           https://devpost.com/software/money-mania   False
# 6189   https://devpost.com/software/audioanalyze-muw9zk   False
# 6190            https://devpost.com/software/tbd-ir3qd5   False
# 6191            https://devpost.com/software/tbd-72iomb   False
#
#                                             inspiration  \
# 0     Due to being stuck at home during Quarantine s...
# 1     Based on the observation that most household w...
# 2     Inspired by the newly born solidarity within t...
# 3     We're a team of 'music people' who are in a ba...
# 4     Covid-19 has ravaged the World since early 202...
# ...                                                 ...
# 6187  As current undergraduate students trying to na...
# 6188  Our inspiration for this project was this book...
# 6189  The inspiration behind this project came from ...
# 6190  RestoreIO was created in response to the deman...
# 6191  As young college students, we are often poorly...
#
#                                            what_it_does  \
# 0     QuaranTime is an app where a schedule is gener...
# 1     FridgeSpace allows household users to locate a...
# 2     Helppier's goal is to encourage a new social n...
# 3     mashme allows the user to select two songs, an...
# 4     Mall Monitor allows owners and guests to monit...
# ...                                                 ...
# 6187  Degree Map AI includes a React front-end and a...
# 6188  This game teaches people about personal financ...
# 6189                                                NaN
# 6190                                                NaN
# 6191  Our key features: 1) Simplify the insurance hu...
#
#                                         how_we_built_it  \
# 0     We decided to face a new challenge. Due to the...
# 1     We began by creating designs for our app using...
# 2     In order to build a decentralized network wher...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6187  We first started by working on the scraper, fr...
# 6188  We built this in Python using PyGame. We split...
# 6189                                                NaN
# 6190                                                NaN
# 6191  Since we wanted to implement a machine learnin...
#
#                                              challenges  \
# 0     There were many challenges that we faced. One ...
# 1     The biggest challenge we had to face was learn...
# 2     While the developers of the team have experien...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6187  One challenge we faced was figuring out the be...
# 6188  None of us have ever participated in a hackath...
# 6189                                                NaN
# 6190                                                NaN
# 6191                                                NaN
#
#                                         accomplishments  \
# 0     We are proud of the ability to use the Google ...
# 1                                                   NaN
# 2     We are extremely proud to have been able to de...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6187  We're proud to have successfully connected the...
# 6188  We are proud of the fact we have a finished pr...
# 6189                                                NaN
# 6190                                                NaN
# 6191                                                NaN
#
#                                         what_we_learned  \
# 0     We were able to learn much more than expected ...
# 1     There were many new technologies we learned in...
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6187  We learned to set up OpenAI's ChatGPT, scrape ...
# 6188  We learned that creating a layout in PyGame is...
# 6189                                                NaN
# 6190                                                NaN
# 6191                                                NaN
#
#                                              next_steps  \
# 0     If we had more time, we would add features suc...
# 1     Future Steps for our team include working with...
# 2                                                   NaN
# 3     ML training for chorus and verse separation! C...
# 4     Actually deploying and consuming the REST API ...
# ...                                                 ...
# 6187  Given the limited amount of time, we were only...
# 6188  Money Mania will have expansions in the invest...
# 6189                                                NaN
# 6190                                                NaN
# 6191                                                NaN
#
#                                              built_with  \
# 0                             dart, flutter, googleapis
# 1     cockroachdb, flask, python, sqlalchemy, swift,...
# 2     azure, blockchain, cockroach.db, css3, express...
# 3     bootstrap, domain.com, flask, google-compute-e...
# 4     angular.js, azure, css, flask, html, javascrip...
# ...                                                 ...
# 6187    c++, javascript, openai, pyflask, python, react
# 6188                                     pygame, python
# 6189  ai, generative, lambda-(for-serverless-process...
# 6190  ai, computer, computervision, love, mediapipe,...
# 6191                   mapbox, python, typescript, vite
#
#                                          external_links
# 0     https://github.com/JackFrostDJ/HTN-App/tree/ma...
# 1               https://github.com/Harin329/FridgeSpace
# 2     https://github.com/aminecs/magic4, https://www...
# 3                                    http://mashme.tech
# 4     https://github.com/RemeAjayi/mall-monitor, htt...
# ...                                                 ...
# 6187          https://github.com/april2546/HackRice2024
# 6188          https://github.com/ashwinrao1/Hackathon24
# 6189      https://github.com/Ayush374/Ai_Audio_Analysis
# 6190  https://github.com/OfficialCodeVoyage/HackRice...
# 6191            https://github.com/leon934/hackrice2425
#
# [6192 rows x 13 columns]

# %%
# Drop rows where both 'inspiration' and 'external_links' are NaN
df = df.dropna(subset=['built_with'], how='all')

# Reset index after dropping
df = df.reset_index(drop=True)
df
# Out:
#            hackathon_name   project_name  \
# 0     Hack The North 2020     QuaranTime
# 1     Hack The North 2020    FridgeSpace
# 2     Hack The North 2020       helppier
# 3     Hack The North 2020         mashme
# 4     Hack The North 2020   Mall Monitor
# ...                   ...            ...
# 6181     HackRice 14 2024  Degree Map AI
# 6182     HackRice 14 2024    Money Mania
# 6183     HackRice 14 2024   AudioAnalyze
# 6184     HackRice 14 2024      RestoreIO
# 6185     HackRice 14 2024        MedSure
#
#                                            project_link  winner  \
# 0     https://devpost.com/software/boredombuster-hnimzc    True
# 1              https://devpost.com/software/fridgespace    True
# 2          https://devpost.com/software/helppier-k5lbru    True
# 3                   https://devpost.com/software/mashme    True
# 4             https://devpost.com/software/mall-monitor    True
# ...                                                 ...     ...
# 6181     https://devpost.com/software/degree-planner-ai   False
# 6182           https://devpost.com/software/money-mania   False
# 6183   https://devpost.com/software/audioanalyze-muw9zk   False
# 6184            https://devpost.com/software/tbd-ir3qd5   False
# 6185            https://devpost.com/software/tbd-72iomb   False
#
#                                             inspiration  \
# 0     Due to being stuck at home during Quarantine s...
# 1     Based on the observation that most household w...
# 2     Inspired by the newly born solidarity within t...
# 3     We're a team of 'music people' who are in a ba...
# 4     Covid-19 has ravaged the World since early 202...
# ...                                                 ...
# 6181  As current undergraduate students trying to na...
# 6182  Our inspiration for this project was this book...
# 6183  The inspiration behind this project came from ...
# 6184  RestoreIO was created in response to the deman...
# 6185  As young college students, we are often poorly...
#
#                                            what_it_does  \
# 0     QuaranTime is an app where a schedule is gener...
# 1     FridgeSpace allows household users to locate a...
# 2     Helppier's goal is to encourage a new social n...
# 3     mashme allows the user to select two songs, an...
# 4     Mall Monitor allows owners and guests to monit...
# ...                                                 ...
# 6181  Degree Map AI includes a React front-end and a...
# 6182  This game teaches people about personal financ...
# 6183                                                NaN
# 6184                                                NaN
# 6185  Our key features: 1) Simplify the insurance hu...
#
#                                         how_we_built_it  \
# 0     We decided to face a new challenge. Due to the...
# 1     We began by creating designs for our app using...
# 2     In order to build a decentralized network wher...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6181  We first started by working on the scraper, fr...
# 6182  We built this in Python using PyGame. We split...
# 6183                                                NaN
# 6184                                                NaN
# 6185  Since we wanted to implement a machine learnin...
#
#                                              challenges  \
# 0     There were many challenges that we faced. One ...
# 1     The biggest challenge we had to face was learn...
# 2     While the developers of the team have experien...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6181  One challenge we faced was figuring out the be...
# 6182  None of us have ever participated in a hackath...
# 6183                                                NaN
# 6184                                                NaN
# 6185                                                NaN
#
#                                         accomplishments  \
# 0     We are proud of the ability to use the Google ...
# 1                                                   NaN
# 2     We are extremely proud to have been able to de...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6181  We're proud to have successfully connected the...
# 6182  We are proud of the fact we have a finished pr...
# 6183                                                NaN
# 6184                                                NaN
# 6185                                                NaN
#
#                                         what_we_learned  \
# 0     We were able to learn much more than expected ...
# 1     There were many new technologies we learned in...
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6181  We learned to set up OpenAI's ChatGPT, scrape ...
# 6182  We learned that creating a layout in PyGame is...
# 6183                                                NaN
# 6184                                                NaN
# 6185                                                NaN
#
#                                              next_steps  \
# 0     If we had more time, we would add features suc...
# 1     Future Steps for our team include working with...
# 2                                                   NaN
# 3     ML training for chorus and verse separation! C...
# 4     Actually deploying and consuming the REST API ...
# ...                                                 ...
# 6181  Given the limited amount of time, we were only...
# 6182  Money Mania will have expansions in the invest...
# 6183                                                NaN
# 6184                                                NaN
# 6185                                                NaN
#
#                                              built_with  \
# 0                             dart, flutter, googleapis
# 1     cockroachdb, flask, python, sqlalchemy, swift,...
# 2     azure, blockchain, cockroach.db, css3, express...
# 3     bootstrap, domain.com, flask, google-compute-e...
# 4     angular.js, azure, css, flask, html, javascrip...
# ...                                                 ...
# 6181    c++, javascript, openai, pyflask, python, react
# 6182                                     pygame, python
# 6183  ai, generative, lambda-(for-serverless-process...
# 6184  ai, computer, computervision, love, mediapipe,...
# 6185                   mapbox, python, typescript, vite
#
#                                          external_links
# 0     https://github.com/JackFrostDJ/HTN-App/tree/ma...
# 1               https://github.com/Harin329/FridgeSpace
# 2     https://github.com/aminecs/magic4, https://www...
# 3                                    http://mashme.tech
# 4     https://github.com/RemeAjayi/mall-monitor, htt...
# ...                                                 ...
# 6181          https://github.com/april2546/HackRice2024
# 6182          https://github.com/ashwinrao1/Hackathon24
# 6183      https://github.com/Ayush374/Ai_Audio_Analysis
# 6184  https://github.com/OfficialCodeVoyage/HackRice...
# 6185            https://github.com/leon934/hackrice2425
#
# [6186 rows x 13 columns]

# %%
df.to_C
