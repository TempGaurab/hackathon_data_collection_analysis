# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("repo_analysis_results.csv")
df
# Out:
#            hackathon_name                          project_name  \
# 0     Hack The North 2020                            QuaranTime
# 1     Hack The North 2020                           FridgeSpace
# 2     Hack The North 2020                              helppier
# 3     Hack The North 2020                          Mall Monitor
# 4     Hack The North 2020  CAST3D - Scanner for Medicinal Casts
# ...                   ...                                   ...
# 5621     HackRice 14 2024                         Degree Map AI
# 5622     HackRice 14 2024                           Money Mania
# 5623     HackRice 14 2024                          AudioAnalyze
# 5624     HackRice 14 2024                             RestoreIO
# 5625     HackRice 14 2024                               MedSure
#
#                                            project_link  winner  \
# 0     https://devpost.com/software/boredombuster-hnimzc    True
# 1              https://devpost.com/software/fridgespace    True
# ...

# %%
df.isna().sum()
# Out:
# hackathon_name         0
# project_name           0
# project_link           0
# winner                 0
# inspiration            0
# what_it_does        1171
# how_we_built_it     1789
# challenges          2010
# accomplishments     2258
# what_we_learned     2265
# next_steps          1708
# built_with             0
# external_links         0
# github_links         178
# github_repo_desc    5410
# dtype: int64

# %%
df.github_repo_desc.nunique()
# Out:
# 216
