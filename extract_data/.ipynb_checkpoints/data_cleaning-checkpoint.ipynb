# %%
import pandas as pd
df = pd.read_csv("all_test_detailed.csv_detailed.csv")
df
# Out:
#         hackathon_name                                 project_name  \
# 0    BiolerMake_X_2023                                      Insight
# 1    BiolerMake_X_2023                                 LectureBoost
# 2    BiolerMake_X_2023                                  Write Right
# 3    BiolerMake_X_2023                                   Soundscape
# 4    BiolerMake_X_2023                                         AirQ
# ..                 ...                                          ...
# 181       Victor Hacks                                       Medico
# 182       Victor Hacks  PosturePal – Your Personal AI Fitness Coach
# 183       Victor Hacks                          LiverCare Solutions
# 184       Victor Hacks                                      flippr.
# 185       Victor Hacks                                  MindTracker
#
#                                           project_link  winner  \
# 0          https://devpost.com/software/insight-m0ew74    True
# ...

# %%
df.columns
# Out:
# Index(['hackathon_name', 'project_name', 'project_link', 'winner',
#        'inspiration', 'what_it_does', 'how_we_built_it', 'challenges',
#        'accomplishments', 'what_we_learned', 'next_steps', 'built_with',
#        'external_links'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# hackathon_name      0
# project_name        0
# project_link        0
# winner              0
# inspiration        13
# what_it_does       32
# how_we_built_it    32
# challenges         43
# accomplishments    49
# what_we_learned    48
# next_steps         50
# built_with          0
# external_links      4
# dtype: int64

# %%
df_cleaned = df.dropna(subset=['inspiration'])
df_cleaned
# Out:
#         hackathon_name                                 project_name  \
# 0    BiolerMake_X_2023                                      Insight
# 1    BiolerMake_X_2023                                 LectureBoost
# 2    BiolerMake_X_2023                                  Write Right
# 3    BiolerMake_X_2023                                   Soundscape
# 4    BiolerMake_X_2023                                         AirQ
# ..                 ...                                          ...
# 181       Victor Hacks                                       Medico
# 182       Victor Hacks  PosturePal – Your Personal AI Fitness Coach
# 183       Victor Hacks                          LiverCare Solutions
# 184       Victor Hacks                                      flippr.
# 185       Victor Hacks                                  MindTracker
#
#                                           project_link  winner  \
# 0          https://devpost.com/software/insight-m0ew74    True
# ...
