# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("all_detail.csv")
df
# Out:
#          hackathon_name                       project_name  \
# 0     Auburn Hacks 2024                           Resumate
# 1     Auburn Hacks 2024  Courage The Not-so Cowardly Rover
# 2     Auburn Hacks 2024                        Planetarium
# 3     Auburn Hacks 2024                    Orbital Sandbox
# 4     Auburn Hacks 2024                         OrbitQuest
# ...                 ...                                ...
# 1066         VTHacks 12                           SquatMap
# 1067         VTHacks 12                          OriGaming
# 1068         VTHacks 12                          Ask Hokie
# 1069         VTHacks 12                           GrocerAi
# 1070         VTHacks 12                      internot.blog
#
#                                            project_link  winner  \
# 0          https://devpost.com/software/resumate-bwk81m    True
# 1     https://devpost.com/software/courage-the-not-s...    True
# ...

# %%
df2 = df

# %%
# List of columns you want to merge
cols_to_merge = [
    "inspiration",
    "what_it_does",
    "how_we_built_it",
    "challenges",
    "accomplishments",
    "what_we_learned",
    "next_steps",
    "built_with"
]

# Merge into a new column
df2["merged_details"] = df2[cols_to_merge].fillna("").agg(" ".join, axis=1)

# Preview
df2
# Out:
#          hackathon_name                       project_name  \
# 0     Auburn Hacks 2024                           Resumate
# 1     Auburn Hacks 2024  Courage The Not-so Cowardly Rover
# 2     Auburn Hacks 2024                        Planetarium
# 3     Auburn Hacks 2024                    Orbital Sandbox
# 4     Auburn Hacks 2024                         OrbitQuest
# ...                 ...                                ...
# 1066         VTHacks 12                           SquatMap
# 1067         VTHacks 12                          OriGaming
# 1068         VTHacks 12                          Ask Hokie
# 1069         VTHacks 12                           GrocerAi
# 1070         VTHacks 12                      internot.blog
#
#                                            project_link  winner  \
# 0          https://devpost.com/software/resumate-bwk81m    True
# 1     https://devpost.com/software/courage-the-not-s...    True
# ...

# %%
df2 = df2 [['hackathon_name' , 'project_name' , 'project_link' , 'winner' , 'merged_details' , 'external_links']]
df2
# Out:
#          hackathon_name                       project_name  \
# 0     Auburn Hacks 2024                           Resumate
# 1     Auburn Hacks 2024  Courage The Not-so Cowardly Rover
# 2     Auburn Hacks 2024                        Planetarium
# 3     Auburn Hacks 2024                    Orbital Sandbox
# 4     Auburn Hacks 2024                         OrbitQuest
# ...                 ...                                ...
# 1066         VTHacks 12                           SquatMap
# 1067         VTHacks 12                          OriGaming
# 1068         VTHacks 12                          Ask Hokie
# 1069         VTHacks 12                           GrocerAi
# 1070         VTHacks 12                      internot.blog
#
#                                            project_link  winner  \
# 0          https://devpost.com/software/resumate-bwk81m    True
# 1     https://devpost.com/software/courage-the-not-s...    True
# ...

# %%
for data in df2.external_links.dropna():
    if "youtube" in data:
        print(data)
# Out:
# https://youtube.com/shorts/yPCBirqc_z8, https://github.com/Lukas-2288/TalkTech
# https://codeberg.org/reality-hack-2024/TABLE_60#connectionvialanguage, https://www.youtube.com/watch?v=mSSdxio3Rvk, https://www.youtube.com/watch?v=mSSdxio3Rvk
# https://eigensurance.vercel.app/, https://eigensurance.replit.app/, https://www.youtube.com/watch?v=pKcpF_wBnoM, https://github.com/andrewgcodes/eigen, https://github.com/andrewgcodes/eigensurance_agent, https://github.com/andrewgcodes/ai-trading-agent
