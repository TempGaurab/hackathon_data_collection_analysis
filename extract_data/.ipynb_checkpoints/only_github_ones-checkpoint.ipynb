# %%
import pandas as pd

# Clean column names
columns = [
    "hackathon_name",
    "project_name",
    "project_link",
    "is_winner",
    "inspiration",
    "what_it_does",
    "how_we_built_it",
    "challenges",
    "accomplishments",
    "what_we_learned",
    "tech_stack",
    "external_links",
    "github_links",
    "github_summary"
]

# Load CSV
df = pd.read_csv("repo_analysis_results.csv", header=0, names=columns,index_col=False)

# Optional: reset index just for neatness
#df.reset_index(drop=True, inplace=True)

# --- Clean up ---
# Drop rows missing key info (as before)
df
# Out:
# /var/folders/s_/bxp81vj13c5dtth3g555hb6h0000gn/T/ipykernel_44113/4176860475.py:22: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv("repo_analysis_results.csv", header=0, names=columns,index_col=False)
#         hackathon_name                       project_name  \
# 0       Cal Hacks 10.0                         Audiogroph
# 1       Cal Hacks 10.0                         Let It Out
# 2       Cal Hacks 10.0                      Mood Theremin
# 3       Cal Hacks 10.0  Bay Area Safer Housing (B.A.S.H.)
# 4       Cal Hacks 10.0                            PawPals
# ...                ...                                ...
# 1833  HackRice 14 2024                      Degree Map AI
# 1834  HackRice 14 2024                        Money Mania
# 1835  HackRice 14 2024                       AudioAnalyze
# 1836  HackRice 14 2024                          RestoreIO
# 1837  HackRice 14 2024                            MedSure
#
#                                            project_link  is_winner  \
# 0               https://devpost.com/software/audiogroph      False
# 1        https://devpost.com/software/let-it-out-b2xp8u      False
# 2            https://devpost.com/software/mood-theremin      False
# 3     https://devpost.com/software/bay-area-safer-ho...      False
# 4           https://devpost.com/software/pawpals-bd8njs      False
# ...                                                 ...        ...
# 1833     https://devpost.com/software/degree-planner-ai      False
# 1834           https://devpost.com/software/money-mania      False
# 1835   https://devpost.com/software/audioanalyze-muw9zk      False
# 1836            https://devpost.com/software/tbd-ir3qd5      False
# 1837            https://devpost.com/software/tbd-72iomb      False
#
#                                             inspiration  \
# 0     With covid ending and people finding new music...
# 1     Understanding and expressing emotions can be a...
# 2     The theremin, an electronic musical instrument...
# 3     The inspiration initially stems from one membe...
# 4     As college students, we both agreed that fun t...
# ...                                                 ...
# 1833  As current undergraduate students trying to na...
# 1834  Our inspiration for this project was this book...
# 1835  The inspiration behind this project came from ...
# 1836  RestoreIO was created in response to the deman...
# 1837  As young college students, we are often poorly...
#
#                                            what_it_does  \
# 0     The project shows events, creators and any NFT...
# 1     The user is first prompted to record a vocal b...
# 2     Mood Theremin translates your facial expressio...
# 3     B.A.S.H. searches for affordable housing optio...
# 4     Based on a list of criteria, we prompt OpenAI'...
# ...                                                 ...
# 1833  Degree Map AI includes a React front-end and a...
# 1834  This game teaches people about personal financ...
# 1835                                                NaN
# 1836                                                NaN
# 1837  Our key features: 1) Simplify the insurance hu...
#
#                                         how_we_built_it  \
# 0     We used react to build it in vscode and collab...
# 1     Let It Out is a full stack web app. The front ...
# 2     Our project integrates facial expression analy...
# 3     Our website's foundation was built on next.js ...
# 4     On the front-end, we utilized Figma to develop...
# ...                                                 ...
# 1833  We first started by working on the scraper, fr...
# 1834  We built this in Python using PyGame. We split...
# 1835                                                NaN
# 1836                                                NaN
# 1837  Since we wanted to implement a machine learnin...
#
#                                              challenges  \
# 0     We had to learn react and navigate through git...
# 1     The main challenges we ran into came in our fi...
# 2                                                   NaN
# 3     Our difficulties lay in our inexperience with ...
# 4     Some challenges we ran into were the lack of e...
# ...                                                 ...
# 1833  One challenge we faced was figuring out the be...
# 1834  None of us have ever participated in a hackath...
# 1835                                                NaN
# 1836                                                NaN
# 1837                                                NaN
#
#                                         accomplishments  \
# 0     We have successfully built the frontend of the...
# 1                                                   NaN
# 2                                                   NaN
# 3     Conceptually, we believe that our project is m...
# 4     As a team of two, we were very proud of our fi...
# ...                                                 ...
# 1833  We're proud to have successfully connected the...
# 1834  We are proud of the fact we have a finished pr...
# 1835                                                NaN
# 1836                                                NaN
# 1837                                                NaN
#
#                                         what_we_learned  \
# 0     Start planning earlier and commit to branches ...
# 1     We learned how to integrate modern technologie...
# 2                                                   NaN
# 3     We've learned most importantly how to better a...
# 4     We learned the value of coming up with a plan ...
# ...                                                 ...
# 1833  We learned to set up OpenAI's ChatGPT, scrape ...
# 1834  We learned that creating a layout in PyGame is...
# 1835                                                NaN
# 1836                                                NaN
# 1837                                                NaN
#
#                                              tech_stack  \
# 0                     We need a backend to our project.
# 1                                                   NaN
# 2                                                   NaN
# 3     We are serious in our project and are intent o...
# 4     We hope to deploy the site on Vercel and devel...
# ...                                                 ...
# 1833  Given the limited amount of time, we were only...
# 1834  Money Mania will have expansions in the invest...
# 1835                                                NaN
# 1836                                                NaN
# 1837                                                NaN
#
#                                          external_links  \
# 0                        css3, html5, javascript, react
# 1     chakra, flask, hume, mongodb, node.js, openai,...
# 2     css, flask, html, hume, javascript, json, pyth...
# 3     catalog.data.gov, data.sfgov.org, google-maps,...
# 4      fastapi, figma, openai, python, react.js, sqlite
# ...                                                 ...
# 1833    c++, javascript, openai, pyflask, python, react
# 1834                                     pygame, python
# 1835  ai, generative, lambda-(for-serverless-process...
# 1836  ai, computer, computervision, love, mediapipe,...
# 1837                   mapbox, python, typescript, vite
#
#                                            github_links  \
# 0      ['https://github.com/RyanGertz/CalHacksproject']
# 1     ['https://github.com/apolyeti/calhacks10.0,', ...
# 2         ['https://github.com/Sepulchre49/CalHacks23']
# 3           ['https://github.com/matthewaol/b.a.s.h.,']
# 4                  ['https://github.com/Yatsz/PawPals']
# ...                                                 ...
# 1833      ['https://github.com/april2546/HackRice2024']
# 1834      ['https://github.com/ashwinrao1/Hackathon24']
# 1835  ['https://github.com/Ayush374/Ai_Audio_Analysis']
# 1836  ['https://github.com/OfficialCodeVoyage/HackRi...
# 1837        ['https://github.com/leon934/hackrice2425']
#
#                                          github_summary
# 0      ['https://github.com/RyanGertz/CalHacksproject']
# 1          ['https://github.com/apolyeti/calhacks10.0']
# 2         ['https://github.com/Sepulchre49/CalHacks23']
# 3            ['https://github.com/matthewaol/b.a.s.h.']
# 4                  ['https://github.com/Yatsz/PawPals']
# ...                                                 ...
# 1833      ['https://github.com/april2546/HackRice2024']
# 1834      ['https://github.com/ashwinrao1/Hackathon24']
# 1835  ['https://github.com/Ayush374/Ai_Audio_Analysis']
# 1836  ['https://github.com/OfficialCodeVoyage/HackRi...
# 1837        ['https://github.com/leon934/hackrice2425']
#
# [1838 rows x 14 columns]

# %%
df.hackathon_name.unique()
# Out:
# array(['Cal Hacks 10.0', 'TreeHacks 2023', 'HackGT X',
#        'Hack the Valley 8', 'HackDuke 2023', 'HackIllinois 2023',
#        'ShellHacks 2024', 'HackHarvard 2024', 'TreeHacks 2024',
#        'HackNJIT 2024', 'LAHacks 2024', 'HackIllinois 2024',
#        'PennApps XXV 2024', 'VTHacks 12 2024', 'TAMUhack X 2024',
#        'HackRice 14 2024'], dtype=object)

# %%
df.isna().sum()
# Out:
# hackathon_name       0
# project_name         0
# project_link         0
# is_winner            0
# inspiration          0
# what_it_does       362
# how_we_built_it    449
# challenges         507
# accomplishments    551
# what_we_learned    557
# tech_stack         520
# external_links       0
# github_links         0
# github_summary       0
# dtype: int64

# %%
before = len(df)
df = df.dropna(subset=["inspiration", "github_summary"])
after = len(df)

print(f"Removed {before - after} rows (kept {after})")
# Out:
# Removed 0 rows (kept 1838)

# %%
df
# Out:
#         hackathon_name                       project_name  \
# 0       Cal Hacks 10.0                         Audiogroph
# 1       Cal Hacks 10.0                         Let It Out
# 2       Cal Hacks 10.0                      Mood Theremin
# 3       Cal Hacks 10.0  Bay Area Safer Housing (B.A.S.H.)
# 4       Cal Hacks 10.0                            PawPals
# ...                ...                                ...
# 1833  HackRice 14 2024                      Degree Map AI
# 1834  HackRice 14 2024                        Money Mania
# 1835  HackRice 14 2024                       AudioAnalyze
# 1836  HackRice 14 2024                          RestoreIO
# 1837  HackRice 14 2024                            MedSure
#
#                                            project_link  is_winner  \
# 0               https://devpost.com/software/audiogroph      False
# 1        https://devpost.com/software/let-it-out-b2xp8u      False
# 2            https://devpost.com/software/mood-theremin      False
# 3     https://devpost.com/software/bay-area-safer-ho...      False
# 4           https://devpost.com/software/pawpals-bd8njs      False
# ...                                                 ...        ...
# 1833     https://devpost.com/software/degree-planner-ai      False
# 1834           https://devpost.com/software/money-mania      False
# 1835   https://devpost.com/software/audioanalyze-muw9zk      False
# 1836            https://devpost.com/software/tbd-ir3qd5      False
# 1837            https://devpost.com/software/tbd-72iomb      False
#
#                                             inspiration  \
# 0     With covid ending and people finding new music...
# 1     Understanding and expressing emotions can be a...
# 2     The theremin, an electronic musical instrument...
# 3     The inspiration initially stems from one membe...
# 4     As college students, we both agreed that fun t...
# ...                                                 ...
# 1833  As current undergraduate students trying to na...
# 1834  Our inspiration for this project was this book...
# 1835  The inspiration behind this project came from ...
# 1836  RestoreIO was created in response to the deman...
# 1837  As young college students, we are often poorly...
#
#                                            what_it_does  \
# 0     The project shows events, creators and any NFT...
# 1     The user is first prompted to record a vocal b...
# 2     Mood Theremin translates your facial expressio...
# 3     B.A.S.H. searches for affordable housing optio...
# 4     Based on a list of criteria, we prompt OpenAI'...
# ...                                                 ...
# 1833  Degree Map AI includes a React front-end and a...
# 1834  This game teaches people about personal financ...
# 1835                                                NaN
# 1836                                                NaN
# 1837  Our key features: 1) Simplify the insurance hu...
#
#                                         how_we_built_it  \
# 0     We used react to build it in vscode and collab...
# 1     Let It Out is a full stack web app. The front ...
# 2     Our project integrates facial expression analy...
# 3     Our website's foundation was built on next.js ...
# 4     On the front-end, we utilized Figma to develop...
# ...                                                 ...
# 1833  We first started by working on the scraper, fr...
# 1834  We built this in Python using PyGame. We split...
# 1835                                                NaN
# 1836                                                NaN
# 1837  Since we wanted to implement a machine learnin...
#
#                                              challenges  \
# 0     We had to learn react and navigate through git...
# 1     The main challenges we ran into came in our fi...
# 2                                                   NaN
# 3     Our difficulties lay in our inexperience with ...
# 4     Some challenges we ran into were the lack of e...
# ...                                                 ...
# 1833  One challenge we faced was figuring out the be...
# 1834  None of us have ever participated in a hackath...
# 1835                                                NaN
# 1836                                                NaN
# 1837                                                NaN
#
#                                         accomplishments  \
# 0     We have successfully built the frontend of the...
# 1                                                   NaN
# 2                                                   NaN
# 3     Conceptually, we believe that our project is m...
# 4     As a team of two, we were very proud of our fi...
# ...                                                 ...
# 1833  We're proud to have successfully connected the...
# 1834  We are proud of the fact we have a finished pr...
# 1835                                                NaN
# 1836                                                NaN
# 1837                                                NaN
#
#                                         what_we_learned  \
# 0     Start planning earlier and commit to branches ...
# 1     We learned how to integrate modern technologie...
# 2                                                   NaN
# 3     We've learned most importantly how to better a...
# 4     We learned the value of coming up with a plan ...
# ...                                                 ...
# 1833  We learned to set up OpenAI's ChatGPT, scrape ...
# 1834  We learned that creating a layout in PyGame is...
# 1835                                                NaN
# 1836                                                NaN
# 1837                                                NaN
#
#                                              tech_stack  \
# 0                     We need a backend to our project.
# 1                                                   NaN
# 2                                                   NaN
# 3     We are serious in our project and are intent o...
# 4     We hope to deploy the site on Vercel and devel...
# ...                                                 ...
# 1833  Given the limited amount of time, we were only...
# 1834  Money Mania will have expansions in the invest...
# 1835                                                NaN
# 1836                                                NaN
# 1837                                                NaN
#
#                                          external_links  \
# 0                        css3, html5, javascript, react
# 1     chakra, flask, hume, mongodb, node.js, openai,...
# 2     css, flask, html, hume, javascript, json, pyth...
# 3     catalog.data.gov, data.sfgov.org, google-maps,...
# 4      fastapi, figma, openai, python, react.js, sqlite
# ...                                                 ...
# 1833    c++, javascript, openai, pyflask, python, react
# 1834                                     pygame, python
# 1835  ai, generative, lambda-(for-serverless-process...
# 1836  ai, computer, computervision, love, mediapipe,...
# 1837                   mapbox, python, typescript, vite
#
#                                            github_links  \
# 0      ['https://github.com/RyanGertz/CalHacksproject']
# 1     ['https://github.com/apolyeti/calhacks10.0,', ...
# 2         ['https://github.com/Sepulchre49/CalHacks23']
# 3           ['https://github.com/matthewaol/b.a.s.h.,']
# 4                  ['https://github.com/Yatsz/PawPals']
# ...                                                 ...
# 1833      ['https://github.com/april2546/HackRice2024']
# 1834      ['https://github.com/ashwinrao1/Hackathon24']
# 1835  ['https://github.com/Ayush374/Ai_Audio_Analysis']
# 1836  ['https://github.com/OfficialCodeVoyage/HackRi...
# 1837        ['https://github.com/leon934/hackrice2425']
#
#                                          github_summary
# 0      ['https://github.com/RyanGertz/CalHacksproject']
# 1          ['https://github.com/apolyeti/calhacks10.0']
# 2         ['https://github.com/Sepulchre49/CalHacks23']
# 3            ['https://github.com/matthewaol/b.a.s.h.']
# 4                  ['https://github.com/Yatsz/PawPals']
# ...                                                 ...
# 1833      ['https://github.com/april2546/HackRice2024']
# 1834      ['https://github.com/ashwinrao1/Hackathon24']
# 1835  ['https://github.com/Ayush374/Ai_Audio_Analysis']
# 1836  ['https://github.com/OfficialCodeVoyage/HackRi...
# 1837        ['https://github.com/leon934/hackrice2425']
#
# [1838 rows x 14 columns]

# %%
df2 = pd.read_csv("zhou_tst.csv", header=0, names=columns,index_col=False)
df2
# Out:
# /var/folders/s_/bxp81vj13c5dtth3g555hb6h0000gn/T/ipykernel_44113/2775658771.py:1: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df2 = pd.read_csv("zhou_tst.csv", header=0, names=columns,index_col=False)
#         hackathon_name                       project_name  \
# 0    Auburn Hacks 2024  Courage The Not-so Cowardly Rover
# 1    Auburn Hacks 2024                    Orbital Sandbox
# 2    Auburn Hacks 2024                         OrbitQuest
# 3    Auburn Hacks 2024                             Pseduo
# 4    Auburn Hacks 2024                       Auburn Quest
# ..                 ...                                ...
# 800         VTHacks 12                Organic Food FInder
# 801         VTHacks 12                           SquatMap
# 802         VTHacks 12                          OriGaming
# 803         VTHacks 12                          Ask Hokie
# 804         VTHacks 12                      internot.blog
#
#                                           project_link  is_winner  \
# 0    https://devpost.com/software/courage-the-not-s...       True
# 1         https://devpost.com/software/orbital-sandbox       True
# 2              https://devpost.com/software/orbitquest       True
# 3                  https://devpost.com/software/pseduo       True
# 4            https://devpost.com/software/auburn-quest       True
# ..                                                 ...        ...
# 800   https://devpost.com/software/organic-food-finder      False
# 801              https://devpost.com/software/squatmap      False
# 802             https://devpost.com/software/origaming      False
# 803       https://devpost.com/software/hokie-plus-plus      False
# 804         https://devpost.com/software/internot-blog      False
#
#                                            inspiration  \
# 0    Our inspiration came from the resources NASA p...
# 1    Interplanetary space exploration is becoming a...
# 2    The theme this year is space travel. So why no...
# 3    The lack of ability to ask questions to trustw...
# 4    We, the project developers, are international ...
# ..                                                 ...
# 800  I am into health and neuroscience. \nUS has an...
# 801   Our project, "SquatDown," has goal to assist ...
# 802  Since high school, we have had an interest in ...
# 803  Ask HOKIE Problem Statement Technical Framewor...
# 804  Inspired by the concept of the 'dead internet ...
#
#                                           what_it_does  \
# 0    In this Mars Rover educational game, players e...
# 1    The simulator allows you to fly a spacecraft a...
# 2    OrbitQuesttracks the ISS as it travels around ...
# 3    It allows people with minimal coding experienc...
# 4    Auburn Quest is a web-based application that h...
# ..                                                 ...
# 800  AI powered search of organic foods based on us...
# 801                                                NaN
# 802  0rigAmIng is a "paper-folding simulator" that ...
# 803                                                NaN
# 804  Internot.blog is a blog website where every po...
#
#                                        how_we_built_it  \
# 0                                                  NaN
# 1    The app was built in the Unity game-engine, wh...
# 2    We usedthree.jsfor the 3-D graphics portion of...
# 3    We used T3 stack (React, TypeScript, NextJs, T...
# 4            Our tech stack consists of the following:
# ..                                                 ...
# 800                                                NaN
# 801                                                NaN
# 802       We built 0rigAmIng fully in Godot Engine 3D.
# 803                                                NaN
# 804  We set up and used a locally hosted instance o...
#
#                                             challenges  \
# 0                                                  NaN
# 1    The primary challenge for the design was build...
# 2    One significant challenge we faced was maintai...
# 3    Auth0 struggled to work with TypeScript and we...
# 4    Identifying the most important features to be ...
# ..                                                 ...
# 800                                       Getting APIs
# 801                                                NaN
# 802  Where do we even begin? To start, none of us h...
# 803                                                NaN
# 804  Generating images that don't look like complet...
#
#                                        accomplishments  \
# 0                                                  NaN
# 1    We are very proud of the real-time simulation ...
# 2    We are extremely proud of the appearance of ou...
# 3    Fully functional API, some pretty good UI for ...
# 4    We are extremely proud of building the followi...
# ..                                                 ...
# 800                                       It's working
# 801                                                NaN
# 802  Our first big strides in the project were when...
# 803                                                NaN
# 804  The system is able to operate entirely autonom...
#
#                                        what_we_learned  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4    This is the first time we were able to use Mon...
# ..                                                 ...
# 800                                 Web app deployment
# 801                                                NaN
# 802  Well, we learned that hackathons are crazy! Bu...
# 803                                                NaN
# 804  AI is really good at making up stories about e...
#
#                                             tech_stack  \
# 0                                                  NaN
# 1    Hopefully, after the completion of AuburnHACKS...
# 2    In the future, we want to implement real-time ...
# 3                                                  NaN
# 4    We intend to demo this application to the Aubu...
# ..                                                 ...
# 800                             Include Map interface.
# 801                                                NaN
# 802                                                NaN
# 803                                                NaN
# 804  We will let it run and generate new content fo...
#
#                                         external_links  \
# 0      blendr, c#, mixtral, nasa, nginx, ollama, unity
# 1                                            c#, unity
# 2    css, debian, digitalocean, django, git, github...
# 3    auth0, express.js, javascript, mongodb, nextjs...
# 4    auth0, bootstrap, cloudflare, express.js, mong...
# ..                                                 ...
# 800                     beautiful-soup, openai, python
# 801  css, google-maps, html, javascript, node.js, r...
# 802                                              godot
# 803    css3, gpt, llm, mlh, mongodb, propelauth, react
# 804  css3, go, html5, hugo, llama3.1, rust, stable-...
#
#                                           github_links  \
# 0    ['https://github.com/abearinatrap/auburnhack20...
# 1    ['https://github.com/EirikMulder/HackEpicUnity...
# 2          ['https://github.com/TheSlabby/OrbitQuest']
# 3         ['https://github.com/TrevorAupperle/pseudo']
# 4    ['https://github.com/lmedury/auburn-hacks-back...
# ..                                                 ...
# 800     ['https://github.com/danpartigiano/VTHAX2024']
# 801    ['https://github.com/harshalarakala/squatdown']
# 802             ['https://github.com/vaaar/OriGaming']
# 803        ['https://github.com/mahatokunal/askHokie']
# 804               ['https://github.com/internot-blog']
#
#                                         github_summary
# 0    ['https://github.com/abearinatrap/auburnhack20...
# 1    ['https://github.com/EirikMulder/HackEpicUnity...
# 2          ['https://github.com/TheSlabby/OrbitQuest']
# 3         ['https://github.com/TrevorAupperle/pseudo']
# 4    ['https://github.com/lmedury/auburn-hacks-back...
# ..                                                 ...
# 800     ['https://github.com/danpartigiano/VTHAX2024']
# 801    ['https://github.com/harshalarakala/squatdown']
# 802             ['https://github.com/vaaar/OriGaming']
# 803        ['https://github.com/mahatokunal/askHokie']
# 804               ['https://github.com/internot-blog']
#
# [805 rows x 14 columns]

# %%
df2.is_winner.value_counts()
# Out:
# is_winner
# False    636
# True     169
# Name: count, dtype: int64

# %%
before = len(df2)
df2 = df2.dropna(subset=["inspiration", "github_summary"])
after = len(df2)

print(f"Removed {before - after} rows (kept {after})")
# Out:
# Removed 0 rows (kept 805)

# %%
df2
# Out:
#         hackathon_name                       project_name  \
# 0    Auburn Hacks 2024  Courage The Not-so Cowardly Rover
# 1    Auburn Hacks 2024                    Orbital Sandbox
# 2    Auburn Hacks 2024                         OrbitQuest
# 3    Auburn Hacks 2024                             Pseduo
# 4    Auburn Hacks 2024                       Auburn Quest
# ..                 ...                                ...
# 800         VTHacks 12                Organic Food FInder
# 801         VTHacks 12                           SquatMap
# 802         VTHacks 12                          OriGaming
# 803         VTHacks 12                          Ask Hokie
# 804         VTHacks 12                      internot.blog
#
#                                           project_link  is_winner  \
# 0    https://devpost.com/software/courage-the-not-s...       True
# 1         https://devpost.com/software/orbital-sandbox       True
# 2              https://devpost.com/software/orbitquest       True
# 3                  https://devpost.com/software/pseduo       True
# 4            https://devpost.com/software/auburn-quest       True
# ..                                                 ...        ...
# 800   https://devpost.com/software/organic-food-finder      False
# 801              https://devpost.com/software/squatmap      False
# 802             https://devpost.com/software/origaming      False
# 803       https://devpost.com/software/hokie-plus-plus      False
# 804         https://devpost.com/software/internot-blog      False
#
#                                            inspiration  \
# 0    Our inspiration came from the resources NASA p...
# 1    Interplanetary space exploration is becoming a...
# 2    The theme this year is space travel. So why no...
# 3    The lack of ability to ask questions to trustw...
# 4    We, the project developers, are international ...
# ..                                                 ...
# 800  I am into health and neuroscience. \nUS has an...
# 801   Our project, "SquatDown," has goal to assist ...
# 802  Since high school, we have had an interest in ...
# 803  Ask HOKIE Problem Statement Technical Framewor...
# 804  Inspired by the concept of the 'dead internet ...
#
#                                           what_it_does  \
# 0    In this Mars Rover educational game, players e...
# 1    The simulator allows you to fly a spacecraft a...
# 2    OrbitQuesttracks the ISS as it travels around ...
# 3    It allows people with minimal coding experienc...
# 4    Auburn Quest is a web-based application that h...
# ..                                                 ...
# 800  AI powered search of organic foods based on us...
# 801                                                NaN
# 802  0rigAmIng is a "paper-folding simulator" that ...
# 803                                                NaN
# 804  Internot.blog is a blog website where every po...
#
#                                        how_we_built_it  \
# 0                                                  NaN
# 1    The app was built in the Unity game-engine, wh...
# 2    We usedthree.jsfor the 3-D graphics portion of...
# 3    We used T3 stack (React, TypeScript, NextJs, T...
# 4            Our tech stack consists of the following:
# ..                                                 ...
# 800                                                NaN
# 801                                                NaN
# 802       We built 0rigAmIng fully in Godot Engine 3D.
# 803                                                NaN
# 804  We set up and used a locally hosted instance o...
#
#                                             challenges  \
# 0                                                  NaN
# 1    The primary challenge for the design was build...
# 2    One significant challenge we faced was maintai...
# 3    Auth0 struggled to work with TypeScript and we...
# 4    Identifying the most important features to be ...
# ..                                                 ...
# 800                                       Getting APIs
# 801                                                NaN
# 802  Where do we even begin? To start, none of us h...
# 803                                                NaN
# 804  Generating images that don't look like complet...
#
#                                        accomplishments  \
# 0                                                  NaN
# 1    We are very proud of the real-time simulation ...
# 2    We are extremely proud of the appearance of ou...
# 3    Fully functional API, some pretty good UI for ...
# 4    We are extremely proud of building the followi...
# ..                                                 ...
# 800                                       It's working
# 801                                                NaN
# 802  Our first big strides in the project were when...
# 803                                                NaN
# 804  The system is able to operate entirely autonom...
#
#                                        what_we_learned  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4    This is the first time we were able to use Mon...
# ..                                                 ...
# 800                                 Web app deployment
# 801                                                NaN
# 802  Well, we learned that hackathons are crazy! Bu...
# 803                                                NaN
# 804  AI is really good at making up stories about e...
#
#                                             tech_stack  \
# 0                                                  NaN
# 1    Hopefully, after the completion of AuburnHACKS...
# 2    In the future, we want to implement real-time ...
# 3                                                  NaN
# 4    We intend to demo this application to the Aubu...
# ..                                                 ...
# 800                             Include Map interface.
# 801                                                NaN
# 802                                                NaN
# 803                                                NaN
# 804  We will let it run and generate new content fo...
#
#                                         external_links  \
# 0      blendr, c#, mixtral, nasa, nginx, ollama, unity
# 1                                            c#, unity
# 2    css, debian, digitalocean, django, git, github...
# 3    auth0, express.js, javascript, mongodb, nextjs...
# 4    auth0, bootstrap, cloudflare, express.js, mong...
# ..                                                 ...
# 800                     beautiful-soup, openai, python
# 801  css, google-maps, html, javascript, node.js, r...
# 802                                              godot
# 803    css3, gpt, llm, mlh, mongodb, propelauth, react
# 804  css3, go, html5, hugo, llama3.1, rust, stable-...
#
#                                           github_links  \
# 0    ['https://github.com/abearinatrap/auburnhack20...
# 1    ['https://github.com/EirikMulder/HackEpicUnity...
# 2          ['https://github.com/TheSlabby/OrbitQuest']
# 3         ['https://github.com/TrevorAupperle/pseudo']
# 4    ['https://github.com/lmedury/auburn-hacks-back...
# ..                                                 ...
# 800     ['https://github.com/danpartigiano/VTHAX2024']
# 801    ['https://github.com/harshalarakala/squatdown']
# 802             ['https://github.com/vaaar/OriGaming']
# 803        ['https://github.com/mahatokunal/askHokie']
# 804               ['https://github.com/internot-blog']
#
#                                         github_summary
# 0    ['https://github.com/abearinatrap/auburnhack20...
# 1    ['https://github.com/EirikMulder/HackEpicUnity...
# 2          ['https://github.com/TheSlabby/OrbitQuest']
# 3         ['https://github.com/TrevorAupperle/pseudo']
# 4    ['https://github.com/lmedury/auburn-hacks-back...
# ..                                                 ...
# 800     ['https://github.com/danpartigiano/VTHAX2024']
# 801    ['https://github.com/harshalarakala/squatdown']
# 802             ['https://github.com/vaaar/OriGaming']
# 803        ['https://github.com/mahatokunal/askHokie']
# 804               ['https://github.com/internot-blog']
#
# [805 rows x 14 columns]

# %%
df_new = pd.concat([df, df2], ignore_index=True)
df_new
# Out:
#       hackathon_name                       project_name  \
# 0     Cal Hacks 10.0                         Audiogroph
# 1     Cal Hacks 10.0                         Let It Out
# 2     Cal Hacks 10.0                      Mood Theremin
# 3     Cal Hacks 10.0  Bay Area Safer Housing (B.A.S.H.)
# 4     Cal Hacks 10.0                            PawPals
# ...              ...                                ...
# 2638      VTHacks 12                Organic Food FInder
# 2639      VTHacks 12                           SquatMap
# 2640      VTHacks 12                          OriGaming
# 2641      VTHacks 12                          Ask Hokie
# 2642      VTHacks 12                      internot.blog
#
#                                            project_link  is_winner  \
# 0               https://devpost.com/software/audiogroph      False
# 1        https://devpost.com/software/let-it-out-b2xp8u      False
# 2            https://devpost.com/software/mood-theremin      False
# 3     https://devpost.com/software/bay-area-safer-ho...      False
# 4           https://devpost.com/software/pawpals-bd8njs      False
# ...                                                 ...        ...
# 2638   https://devpost.com/software/organic-food-finder      False
# 2639              https://devpost.com/software/squatmap      False
# 2640             https://devpost.com/software/origaming      False
# 2641       https://devpost.com/software/hokie-plus-plus      False
# 2642         https://devpost.com/software/internot-blog      False
#
#                                             inspiration  \
# 0     With covid ending and people finding new music...
# 1     Understanding and expressing emotions can be a...
# 2     The theremin, an electronic musical instrument...
# 3     The inspiration initially stems from one membe...
# 4     As college students, we both agreed that fun t...
# ...                                                 ...
# 2638  I am into health and neuroscience. \nUS has an...
# 2639   Our project, "SquatDown," has goal to assist ...
# 2640  Since high school, we have had an interest in ...
# 2641  Ask HOKIE Problem Statement Technical Framewor...
# 2642  Inspired by the concept of the 'dead internet ...
#
#                                            what_it_does  \
# 0     The project shows events, creators and any NFT...
# 1     The user is first prompted to record a vocal b...
# 2     Mood Theremin translates your facial expressio...
# 3     B.A.S.H. searches for affordable housing optio...
# 4     Based on a list of criteria, we prompt OpenAI'...
# ...                                                 ...
# 2638  AI powered search of organic foods based on us...
# 2639                                                NaN
# 2640  0rigAmIng is a "paper-folding simulator" that ...
# 2641                                                NaN
# 2642  Internot.blog is a blog website where every po...
#
#                                         how_we_built_it  \
# 0     We used react to build it in vscode and collab...
# 1     Let It Out is a full stack web app. The front ...
# 2     Our project integrates facial expression analy...
# 3     Our website's foundation was built on next.js ...
# 4     On the front-end, we utilized Figma to develop...
# ...                                                 ...
# 2638                                                NaN
# 2639                                                NaN
# 2640       We built 0rigAmIng fully in Godot Engine 3D.
# 2641                                                NaN
# 2642  We set up and used a locally hosted instance o...
#
#                                              challenges  \
# 0     We had to learn react and navigate through git...
# 1     The main challenges we ran into came in our fi...
# 2                                                   NaN
# 3     Our difficulties lay in our inexperience with ...
# 4     Some challenges we ran into were the lack of e...
# ...                                                 ...
# 2638                                       Getting APIs
# 2639                                                NaN
# 2640  Where do we even begin? To start, none of us h...
# 2641                                                NaN
# 2642  Generating images that don't look like complet...
#
#                                         accomplishments  \
# 0     We have successfully built the frontend of the...
# 1                                                   NaN
# 2                                                   NaN
# 3     Conceptually, we believe that our project is m...
# 4     As a team of two, we were very proud of our fi...
# ...                                                 ...
# 2638                                       It's working
# 2639                                                NaN
# 2640  Our first big strides in the project were when...
# 2641                                                NaN
# 2642  The system is able to operate entirely autonom...
#
#                                         what_we_learned  \
# 0     Start planning earlier and commit to branches ...
# 1     We learned how to integrate modern technologie...
# 2                                                   NaN
# 3     We've learned most importantly how to better a...
# 4     We learned the value of coming up with a plan ...
# ...                                                 ...
# 2638                                 Web app deployment
# 2639                                                NaN
# 2640  Well, we learned that hackathons are crazy! Bu...
# 2641                                                NaN
# 2642  AI is really good at making up stories about e...
#
#                                              tech_stack  \
# 0                     We need a backend to our project.
# 1                                                   NaN
# 2                                                   NaN
# 3     We are serious in our project and are intent o...
# 4     We hope to deploy the site on Vercel and devel...
# ...                                                 ...
# 2638                             Include Map interface.
# 2639                                                NaN
# 2640                                                NaN
# 2641                                                NaN
# 2642  We will let it run and generate new content fo...
#
#                                          external_links  \
# 0                        css3, html5, javascript, react
# 1     chakra, flask, hume, mongodb, node.js, openai,...
# 2     css, flask, html, hume, javascript, json, pyth...
# 3     catalog.data.gov, data.sfgov.org, google-maps,...
# 4      fastapi, figma, openai, python, react.js, sqlite
# ...                                                 ...
# 2638                     beautiful-soup, openai, python
# 2639  css, google-maps, html, javascript, node.js, r...
# 2640                                              godot
# 2641    css3, gpt, llm, mlh, mongodb, propelauth, react
# 2642  css3, go, html5, hugo, llama3.1, rust, stable-...
#
#                                            github_links  \
# 0      ['https://github.com/RyanGertz/CalHacksproject']
# 1     ['https://github.com/apolyeti/calhacks10.0,', ...
# 2         ['https://github.com/Sepulchre49/CalHacks23']
# 3           ['https://github.com/matthewaol/b.a.s.h.,']
# 4                  ['https://github.com/Yatsz/PawPals']
# ...                                                 ...
# 2638     ['https://github.com/danpartigiano/VTHAX2024']
# 2639    ['https://github.com/harshalarakala/squatdown']
# 2640             ['https://github.com/vaaar/OriGaming']
# 2641        ['https://github.com/mahatokunal/askHokie']
# 2642               ['https://github.com/internot-blog']
#
#                                         github_summary
# 0     ['https://github.com/RyanGertz/CalHacksproject']
# 1         ['https://github.com/apolyeti/calhacks10.0']
# 2        ['https://github.com/Sepulchre49/CalHacks23']
# 3           ['https://github.com/matthewaol/b.a.s.h.']
# 4                 ['https://github.com/Yatsz/PawPals']
# ...                                                ...
# 2638    ['https://github.com/danpartigiano/VTHAX2024']
# 2639   ['https://github.com/harshalarakala/squatdown']
# 2640            ['https://github.com/vaaar/OriGaming']
# 2641       ['https://github.com/mahatokunal/askHokie']
# 2642              ['https://github.com/internot-blog']
#
# [2643 rows x 14 columns]

# %%
df_new.is_winner.value_counts()
# Out:
# is_winner
# False    2173
# True      470
# Name: count, dtype: int64

# %%
df_new.to_csv("analysis_dataset.csv")
