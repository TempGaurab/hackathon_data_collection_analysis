# %%
import pandas as pd
import numpy as np
import requests as req
from bs4 import BeautifulSoup
import math
from tqdm import tqdm

# %%
import pandas as pd
import requests as req
from bs4 import BeautifulSoup

def link_to_csv_detailed(df_original, hackathon_name):
    """
    Scrape detailed project information and combine with original DataFrame
    
    Args:
        df_original: Original DataFrame with columns: hackathon_name, project_name, project_link, winner
        hackathon_name: Name of the hackathon for output file naming
    """
    count = 0
    detailed_data = []

    for index, row in df_original.iterrows():
        url = row['project_link']
        project_name = row['project_name']
        
        try:
            response = req.get(url)
            response.raise_for_status()  # Raise an exception for bad status codes
            soup = BeautifulSoup(response.text, "html.parser")
            soup = soup.find("div", class_="large-9 columns")
            
            # Initialize section columns with dynamic "What's next" section
            sections = {
                "Inspiration": "",
                "What it does": "",
                "How we built it": "",
                "Challenges we ran into": "",
                "Accomplishments that we're proud of": "",
                "What we learned": "",
                "What's next": ""  # Will be filled dynamically
            }

            # Extract content for each section
            h2 = soup.find_all("h2")
            length_h2 = len(h2)
             #if less than 5 then put all the <p> tag on the inspiration section
            
            # Check if we have the standard project description sections
            standard_sections = ["Inspiration", "What it does", "How we built it", "Challenges we ran into", 
                                "Accomplishments that we're proud of", "What we learned"]
            has_standard_sections = any(header.get_text(strip=True) in standard_sections for header in h2)
            
            if not has_standard_sections:
                # No standard sections found, put all p tags in inspiration section
                all_p_tags = soup.find_all("p")
                inspiration_content = []
                for p in all_p_tags:
                    inspiration_content.append(p.get_text(strip=True))
                sections["Inspiration"] = " ".join(inspiration_content)
            else:
                # Normal processing when standard sections are found
                for header in soup.find_all("h2"):
                    section_name = header.get_text(strip=True)
                    
                    # Handle the dynamic "What's next" section
                    if section_name.startswith("What's next"):
                        sections["What's next"] = extract_section_content(header)
                    elif section_name in sections:
                        sections[section_name] = extract_section_content(header)

            # Built With
            built_with = []
            built_with_section = soup.find("div", id="built-with")
            if built_with_section:
                for tech in built_with_section.find_all("span", class_="cp-tag"):
                    built_with.append(tech.get_text(strip=True))

            # GitHub / external links
            links_list = []
            links_section = soup.find("ul", {"data-role": "software-urls"})
            if links_section:
                for a in links_section.find_all("a", href=True):
                    links_list.append(a["href"])

            # Combine original data with scraped details
            detailed_row = {
                # Original columns
                "hackathon_name": row['hackathon_name'],
                "project_name": row['project_name'],
                "project_link": row['project_link'],
                "winner": row['winner'],
                # New detailed columns
                "inspiration": sections["Inspiration"],
                "what_it_does": sections["What it does"],
                "how_we_built_it": sections["How we built it"],
                "challenges": sections["Challenges we ran into"],
                "accomplishments": sections["Accomplishments that we're proud of"],
                "what_we_learned": sections["What we learned"],
                "next_steps": sections["What's next"],
                "built_with": ", ".join(built_with),
                "external_links": ", ".join(links_list)
            }
            
            detailed_data.append(detailed_row)
            print(f"✅ Processed: {project_name} ({count + 1}/{len(df_original)})")
            
        except Exception as e:
            print(f"❌ Error processing {project_name}: {str(e)}")
            # Add row with original data and empty detailed fields
            detailed_row = {
                "hackathon_name": row['hackathon_name'],
                "project_name": row['project_name'],
                "project_link": row['project_link'],
                "winner": row['winner'],
                "inspiration": "",
                "what_it_does": "",
                "how_we_built_it": "",
                "challenges": "",
                "accomplishments": "",
                "what_we_learned": "",
                "next_steps": "",
                "built_with": "",
                "external_links": ""
            }
            detailed_data.append(detailed_row)
        
        count += 1

    # Save to CSV
    df_out = pd.DataFrame(detailed_data)
    output_filename = f"{hackathon_name}_detailed.csv"
    df_out.to_csv(output_filename, index=False)
    print(f"✅ Saved {len(detailed_data)} detailed projects from {hackathon_name} to {output_filename}")
    
    return df_out

def extract_section_content(header):
    """Helper function to extract content from a section"""
    content = []
    sibling = header.find_next_sibling()
    while sibling and sibling.name != "h2":
        if sibling.name == "p":
            content.append(sibling.get_text(strip=True))
        sibling = sibling.find_next_sibling()
    return " ".join(content)

def extract_section_content_with_tracking(header):
    """Helper function to extract content from a section and track which p tags were used"""
    content = []
    p_tags_used = []
    sibling = header.find_next_sibling()
    while sibling and sibling.name != "h2":
        if sibling.name == "p":
            content.append(sibling.get_text(strip=True))
            p_tags_used.append(sibling)
        sibling = sibling.find_next_sibling()
    return " ".join(content), p_tags_used

# Example usage:
# df_original = pd.read_csv("your_original_file.csv")
# df_detailed = link_to_csv_detailed(df_original, "Auburn Hacks 2024")

# %%
# Read the CSV
df_original = pd.read_csv("all_projects.csv")
df_detailed = link_to_csv_detailed(df_original, "All_projects_with_Details")
df_detailed
# Out:
# ✅ Processed: QuaranTime (1/7495)
# ✅ Processed: FridgeSpace (2/7495)
# ✅ Processed: helppier (3/7495)
# ✅ Processed: mashme (4/7495)
# ✅ Processed: Mall Monitor (5/7495)
# ✅ Processed: CAST3D - Scanner for Medicinal Casts (6/7495)
# ✅ Processed: Legist (7/7495)
# ✅ Processed: Jump! (8/7495)
# ✅ Processed: Temporal Rift (9/7495)
# ✅ Processed: Ctrl+Air+Space (10/7495)
# ✅ Processed: Karaoke Party (11/7495)
# ✅ Processed: trytobreak.me (12/7495)
# ✅ Processed: Recipe2Go (13/7495)
# ✅ Processed: CopyCat (14/7495)
# ✅ Processed: Merge CountFlicts (15/7495)
# ✅ Processed: Desky bot (16/7495)
# ✅ Processed: FitBuddy (17/7495)
# ✅ Processed: QuickMark (18/7495)
# ✅ Processed: Tabular (19/7495)
# ✅ Processed: Corona Escape (20/7495)
# ✅ Processed: ClinicConnect (21/7495)
# ✅ Processed: Subspace (22/7495)
# ✅ Processed: groupShot (23/7495)
# ✅ Processed: flock (24/7495)
# ✅ Processed: PriceEasy (25/7495)
# ✅ Processed: Sofia: The No-Internet-Needed Personal Assistant (26/7495)
# ✅ Processed: Paint Pong (27/7495)
# ✅ Processed: VacAlert (28/7495)
# ✅ Processed: PrioVax (29/7495)
# ✅ Processed: Fineract (30/7495)
# ✅ Processed: Omakase (31/7495)
# ✅ Processed: Fitmotiv (32/7495)
# ✅ Processed: can you survive in space? (33/7495)
# ✅ Processed: Launch (34/7495)
# ✅ Processed: LOOKALIKE (35/7495)
# ✅ Processed: HealthTech (36/7495)
# ✅ Processed: Giftbox (37/7495)
# ✅ Processed: Nutrition-Tracker (38/7495)
# ✅ Processed: #StopFoodWaste (39/7495)
# ✅ Processed: Analyst Alexa (40/7495)
# ✅ Processed: MConnect (41/7495)
# ✅ Processed: Salvare Financial (42/7495)
# ✅ Processed: sevopi-security (43/7495)
# ✅ Processed: Fomodoro Extension (44/7495)
# ✅ Processed: Hourly Wage and More (45/7495)
# ✅ Processed: Exeunt (46/7495)
# ✅ Processed: LazyDay (47/7495)
# ✅ Processed: Rexxa (48/7495)
# ✅ Processed: CovidTracker (49/7495)
# ✅ Processed: Case Closed (50/7495)
# ✅ Processed: EduTracker (51/7495)
# ✅ Processed: Auricular.ai (52/7495)
# ✅ Processed: Lingo (53/7495)
# ✅ Processed: Kindling (54/7495)
# ✅ Processed: No Laughing Matter (55/7495)
# ✅ Processed: systemaa.tech (56/7495)
# ✅ Processed: LiveCap (57/7495)
# ✅ Processed: Blob Bounce (58/7495)
# ✅ Processed: MHeart (59/7495)
# ✅ Processed: Gaggle (60/7495)
# ✅ Processed: Time Logging Task List ((TL)^2) (61/7495)
# ✅ Processed: Scheduflex (62/7495)
# ✅ Processed: mntr.tech (63/7495)
# ✅ Processed: Your Very Own Quarantine Buddy (64/7495)
# ✅ Processed: DiscovAR (65/7495)
# ✅ Processed: Escape (66/7495)
# ✅ Processed: Car Impact Associator (CIA) (67/7495)
# ✅ Processed: COVIDgo (68/7495)
# ✅ Processed: Linked&Chat (69/7495)
# ✅ Processed: Cloud Castle (70/7495)
# ✅ Processed: Hive (71/7495)
# ✅ Processed: UW Study Buddy (72/7495)
# ✅ Processed: ProTrack (73/7495)
# ✅ Processed: MoniMango (74/7495)
# ✅ Processed: Potato Panic (75/7495)
# ✅ Processed: OrderMaid (76/7495)
# ✅ Processed: Community Camel (77/7495)
# ✅ Processed: M(L)ove (78/7495)
# ✅ Processed: Vino (79/7495)
# ✅ Processed: C0D3L8R (80/7495)
# ✅ Processed: Break Bank (81/7495)
# ✅ Processed: Story++ (82/7495)
# ✅ Processed: Desktop-Poro (83/7495)
# ✅ Processed: Reconnect (84/7495)
# ✅ Processed: WritHub (85/7495)
# ✅ Processed: Word. (86/7495)
# ✅ Processed: Stock statistics and AI projection (87/7495)
# ✅ Processed: VocalAnalyzer (88/7495)
# ✅ Processed: SitDown (89/7495)
# ✅ Processed: TuneIn (90/7495)
# ✅ Processed: de-densified (91/7495)
# ✅ Processed: SIZR. (92/7495)
# ✅ Processed: Xperiment.3d (93/7495)
# ✅ Processed: PostureML (94/7495)
# ✅ Processed: Expenditure Manager (95/7495)
# ✅ Processed: EZ Speak (96/7495)
# ✅ Processed: PicYourWord (97/7495)
# ✅ Processed: Flashnote (98/7495)
# ✅ Processed: Dataforest (99/7495)
# ✅ Processed: Sign (100/7495)
# ✅ Processed: smoot (101/7495)
# ✅ Processed: Conductor (102/7495)
# ✅ Processed: Fakecation (103/7495)
# ✅ Processed: Instructions+ (104/7495)
# ✅ Processed: Northern Hackers (105/7495)
# ✅ Processed: RenTogether (106/7495)
# ✅ Processed: No More Noodles (107/7495)
# ✅ Processed: curbshop.online (108/7495)
# ✅ Processed: Onion Notetaking (109/7495)
# ✅ Processed: iMedApp (110/7495)
# ✅ Processed: driftr (111/7495)
# ✅ Processed: Internview (112/7495)
# ✅ Processed: Dynamic Image (113/7495)
# ✅ Processed: MovEZ (114/7495)
# ✅ Processed: COVIDATA (115/7495)
# ✅ Processed: Foodizzy (116/7495)
# ✅ Processed: mudring (117/7495)
# ✅ Processed: SmileSnap! (118/7495)
# ✅ Processed: Joboverflow (119/7495)
# ✅ Processed: Smart lecture (120/7495)
# ✅ Processed: Productivity Fishing (121/7495)
# ✅ Processed: Re-Mind (122/7495)
# ✅ Processed: Somebody Call 911 (123/7495)
# ✅ Processed: Safe Space (124/7495)
# ✅ Processed: The Vaccine Labyrinth (125/7495)
# ✅ Processed: FinBay (126/7495)
# ✅ Processed: OpenUp! (127/7495)
# ✅ Processed: Connect2 (128/7495)
# ✅ Processed: FB.Wordcloud (129/7495)
# ✅ Processed: Video Context Search (130/7495)
# ✅ Processed: voice2Notes (131/7495)
# ✅ Processed: WheresMyBus? (132/7495)
# ✅ Processed: EzIntern (133/7495)
# ✅ Processed: Warrior Bot (134/7495)
# ✅ Processed: Parago (135/7495)
# ✅ Processed: COVOID (136/7495)
# ✅ Processed: COVID-19 Worldwide (137/7495)
# ✅ Processed: Stockroach (138/7495)
# ✅ Processed: VoiceArt (139/7495)
# ✅ Processed: MathHacks (140/7495)
# ✅ Processed: Meter One (141/7495)
# ✅ Processed: OneBook (142/7495)
# ✅ Processed: Covid-19 Visualizer (143/7495)
# ✅ Processed: What2Cook (144/7495)
# ✅ Processed: Feather (145/7495)
# ✅ Processed: TaDo (146/7495)
# ✅ Processed: Friendly Organizer (147/7495)
# ✅ Processed: Streaminar - Time Sensitive Video Notes (148/7495)
# ✅ Processed: CovidConsultant (149/7495)
# ✅ Processed: A (150/7495)
# ✅ Processed: Virtual Grounds (151/7495)
# ✅ Processed: studify.com (152/7495)
# ✅ Processed: Pudge Pong (153/7495)
# ✅ Processed: LINK (154/7495)
# ✅ Processed: Color Vibe (155/7495)
# ✅ Processed: FireDash (156/7495)
# ✅ Processed: Reverse-Pong (157/7495)
# ✅ Processed: ToxicityCheck (158/7495)
# ✅ Processed: Recommendations (159/7495)
# ✅ Processed: RecipeGO (160/7495)
# ✅ Processed: QuikSlide (161/7495)
# ✅ Processed: Quarantine Companion (162/7495)
# ✅ Processed: You. (163/7495)
# ✅ Processed: HireMe! (164/7495)
# ✅ Processed: Bright Focus (165/7495)
# ✅ Processed: #43 Speakable (166/7495)
# ✅ Processed: Caloreye: Nutrition Facts Scanner and Calorie Calculator (167/7495)
# ✅ Processed: Notebooks + (168/7495)
# ✅ Processed: pit-stach.io (169/7495)
# ✅ Processed: Healthaholic (170/7495)
# ✅ Processed: resu.me (171/7495)
# ✅ Processed: tasq (172/7495)
# ✅ Processed: Minute Aid (173/7495)
# ✅ Processed: WEE FIT (174/7495)
# ✅ Processed: Tutti (175/7495)
# ✅ Processed: Shopiva - Grocery Shopping for the Visually Impaired (176/7495)
# ✅ Processed: WikiMe (177/7495)
# ✅ Processed: Clarity (178/7495)
# ✅ Processed: Game of the year (179/7495)
# ✅ Processed: Gratitude (180/7495)
# ✅ Processed: PlayItBack (181/7495)
# ✅ Processed: Parrot (182/7495)
# ✅ Processed: Journal Away With Me (183/7495)
# ✅ Processed: Racepedia (184/7495)
# ✅ Processed: Songbird (185/7495)
# ✅ Processed: Coffee Pot (186/7495)
# ✅ Processed: CryptBox (187/7495)
# ✅ Processed: course match (188/7495)
# ✅ Processed: Stocks Only Go Up (189/7495)
# ✅ Processed: whyVoice (190/7495)
# ✅ Processed: Klip - The Mental Health App (191/7495)
# ✅ Processed: BrainPong (192/7495)
# ✅ Processed: Wildfire (193/7495)
# ✅ Processed: Mark Track (194/7495)
# ✅ Processed: Encryptacit (195/7495)
# ✅ Processed: Dual Axis Webcam (196/7495)
# ✅ Processed: ohmi (197/7495)
# ✅ Processed: Face Mask Notifier (198/7495)
# ✅ Processed: GrocerBase (199/7495)
# ✅ Processed: Premier League Sports Predictor (200/7495)
# ✅ Processed: Sibil - The Touchless Mouse (201/7495)
# ✅ Processed: Hello Roomie! (202/7495)
# ✅ Processed: StudyApp (203/7495)
# ✅ Processed: Steganographia (204/7495)
# ✅ Processed: The Ghost Blew Out The Light (205/7495)
# ✅ Processed: EasyAccess (206/7495)
# ✅ Processed: Dojo (207/7495)
# ✅ Processed: What Should I Do Today? (208/7495)
# ✅ Processed: emoba (209/7495)
# ✅ Processed: Dance Pose (210/7495)
# ✅ Processed: Omnia (211/7495)
# ✅ Processed: LibCheck (212/7495)
# ✅ Processed: leya. (213/7495)
# ✅ Processed: Picturesk (214/7495)
# ✅ Processed: Study Group (215/7495)
# ✅ Processed: Di|Vision (216/7495)
# ✅ Processed: Working Together (217/7495)
# ✅ Processed: sous-chef (218/7495)
# ✅ Processed: Kill Switch (219/7495)
# ✅ Processed: Gateway (220/7495)
# ✅ Processed: CloudBaby (221/7495)
# ✅ Processed: VStudent (222/7495)
# ✅ Processed: Hack the North 2021 (223/7495)
# ✅ Processed: Arcus (224/7495)
# ✅ Processed: Deep Learning RPS (225/7495)
# ✅ Processed: Borz (226/7495)
# ✅ Processed: Fact Checker (227/7495)
# ✅ Processed: CovidChecker (228/7495)
# ✅ Processed: Sensity (229/7495)
# ✅ Processed: Neutrify (230/7495)
# ✅ Processed: Form AI (231/7495)
# ✅ Processed: BFine (232/7495)
# ✅ Processed: HackTheNorthProject (233/7495)
# ✅ Processed: Where's my stuff?? (234/7495)
# ✅ Processed: LegiTrack (235/7495)
# ✅ Processed: OnliClass [Online Classroom] (236/7495)
# ✅ Processed: Planti (237/7495)
# ✅ Processed: Dexify (238/7495)
# ✅ Processed: ShopLazy (239/7495)
# ✅ Processed: Circle Pong (240/7495)
# ✅ Processed: Marketeer (241/7495)
# ✅ Processed: Gravity Skimmer (242/7495)
# ✅ Processed: VS Arcade Game (243/7495)
# ✅ Processed: AZ 2: Electric Boogaloo (244/7495)
# ✅ Processed: Hurricane Damage Detection (245/7495)
# ✅ Processed: Meet and greet (246/7495)
# ✅ Processed: Nijugo: The Modern Pomodoro Tracker (247/7495)
# ✅ Processed: RESTO BOT (248/7495)
# ✅ Processed: MusicAI (249/7495)
# ✅ Processed: wellness.ai (250/7495)
# ✅ Processed: Connect 4 (251/7495)
# ✅ Processed: Lumidate (252/7495)
# ✅ Processed: CourseCatchr (253/7495)
# ✅ Processed: Refocus (254/7495)
# ✅ Processed: Fall Safe (255/7495)
# ✅ Processed: Movie Night Dilemma (256/7495)
# ✅ Processed: Asany (257/7495)
# ✅ Processed: Resonance (258/7495)
# ✅ Processed: vibecheck (259/7495)
# ✅ Processed: Dr. Goose (260/7495)
# ✅ Processed: Roar of the Raccoon (261/7495)
# ✅ Processed: CareBot (262/7495)
# ✅ Processed: Havalion Castle Rescue (263/7495)
# ✅ Processed: Sleep Cycle Calculator (264/7495)
# ✅ Processed: Social Distance Simulator (265/7495)
# ✅ Processed: Magic Mouse (266/7495)
# ✅ Processed: Popcorn Comments (267/7495)
# ✅ Processed: Grocery Go Go (268/7495)
# ✅ Processed: UniFinder (269/7495)
# ✅ Processed: monolog (270/7495)
# ✅ Processed: Potativity (271/7495)
# ✅ Processed: DasAMood (272/7495)
# ✅ Processed: Incepere (273/7495)
# ✅ Processed: COGNIFLEX (274/7495)
# ✅ Processed: Gregor (275/7495)
# ✅ Processed: RewardsPlanner (276/7495)
# ✅ Processed: Command line help bot (277/7495)
# ✅ Processed: Speak Up! (278/7495)
# ✅ Processed: Inferno Oracle 1 (279/7495)
# ✅ Processed: Simon Says (280/7495)
# ✅ Processed: Poser! (281/7495)
# ✅ Processed: Union Interviewer (282/7495)
# ✅ Processed: VidSpace (283/7495)
# ✅ Processed: SafeArrival (284/7495)
# ✅ Processed: VideoGym (285/7495)
# ✅ Processed: Pitch Perfect (286/7495)
# ✅ Processed: Pushup Battle (287/7495)
# ✅ Processed: Music Match (288/7495)
# ✅ Processed: Concisify (289/7495)
# ✅ Processed: MedHub (290/7495)
# ✅ Processed: illuminote (291/7495)
# ✅ Processed: Techadvisor (292/7495)
# ✅ Processed: Carp and Cabbage (293/7495)
# ✅ Processed: Registration-System (294/7495)
# ✅ Processed: ProfitProphet (295/7495)
# ✅ Processed: DataX (296/7495)
# ✅ Processed: rally (297/7495)
# ✅ Processed: Test Submission (298/7495)
# ✅ Processed: Aiso (299/7495)
# ✅ Processed: Wish a Dish (300/7495)
# ✅ Processed: HackerAPI v3 (301/7495)
# ✅ Processed: Fugazi (302/7495)
# ✅ Processed: Outline (303/7495)
# ✅ Processed: Highlight Truth - False Info Detector (304/7495)
# ✅ Processed: Class-Reminder-Extension (305/7495)
# ✅ Processed: Eyebotics Vision (306/7495)
# ✅ Processed: Halcyon (307/7495)
# ✅ Processed: Covid Security w/ Facial Recognition (308/7495)
# ✅ Processed: Aortta (309/7495)
# ✅ Processed: MyType (310/7495)
# ✅ Processed: WakeAndQuake (311/7495)
# ✅ Processed: Bento (312/7495)
# ✅ Processed: Tabify (313/7495)
# ✅ Processed: FineTuned (314/7495)
# ✅ Processed: Streamline - Optimized Flow for Your Presentations (315/7495)
# ✅ Processed: Moodi (316/7495)
# ✅ Processed: SpikeWorld (317/7495)
# ✅ Processed: PhysiBot (318/7495)
# ✅ Processed: MapChat (319/7495)
# ✅ Processed: VADA (320/7495)
# ✅ Processed: quickVax (321/7495)
# ✅ Processed: Oversight (322/7495)
# ✅ Processed: Tracademic (323/7495)
# ✅ Processed: [DELETED] Shareclass (324/7495)
# ✅ Processed: Reco (325/7495)
# ✅ Processed: COVID-19 Voice-Aided Contact Tracing (326/7495)
# ✅ Processed: Budgy (327/7495)
# ✅ Processed: QuickRecipez (328/7495)
# ✅ Processed: Bunny in Space (329/7495)
# ✅ Processed: notify (330/7495)
# ✅ Processed: productivity.space (331/7495)
# ✅ Processed: Scrumptiousroll (332/7495)
# ✅ Processed: Harmonyy (333/7495)
# ✅ Processed: ScoliNosis (334/7495)
# ✅ Processed: You First (335/7495)
# ✅ Processed: Community Camel (336/7495)
# ✅ Processed: Student_Loan_Calculator (337/7495)
# ✅ Processed: LiftOff (338/7495)
# ✅ Processed: OneTwoFix (339/7495)
# ✅ Processed: Apollo: Your Virtual Nurse (340/7495)
# ✅ Processed: Fitopia (341/7495)
# ✅ Processed: min.it (342/7495)
# ✅ Processed: PlumP Savings (343/7495)
# ✅ Processed: Hive - Streamlined ML Data Collection (344/7495)
# ✅ Processed: JournAll (345/7495)
# ✅ Processed: NoteWordy (346/7495)
# ✅ Processed: MeetBetween (RBC Prize Winner) (347/7495)
# ✅ Processed: FoodFïnder (348/7495)
# ✅ Processed: Scavenger (349/7495)
# ✅ Processed: OmegaLearn (350/7495)
# ✅ Processed: Slime Escape (351/7495)
# ✅ Processed: groupifier (352/7495)
# ✅ Processed: Vonage Video Call (353/7495)
# ✅ Processed: Vaccine-19 (354/7495)
# ✅ Processed: Angel's Tale (355/7495)
# ✅ Processed: FormForum (356/7495)
# ✅ Processed: Bye Bye Bias (357/7495)
# ✅ Processed: ChemARstry (358/7495)
# ✅ Processed: Pokédoro (359/7495)
# ✅ Processed: North Arcadia (360/7495)
# ✅ Processed: DropStats (361/7495)
# ✅ Processed: Finance Manager (362/7495)
# ✅ Processed: PongButEpic (363/7495)
# ✅ Processed: sidekick (364/7495)
# ✅ Processed: WardTO (365/7495)
# ✅ Processed: traffa (366/7495)
# ✅ Processed: project-interque (367/7495)
# ✅ Processed: crowd.data (368/7495)
# ✅ Processed: Git it Right (369/7495)
# ✅ Processed: The Food Bank (370/7495)
# ✅ Processed: SoluBrew (371/7495)
# ✅ Processed: Daily Chess Pro (372/7495)
# ✅ Processed: SheetScrape (373/7495)
# ✅ Processed: Git Voice (374/7495)
# ✅ Processed: A Brisk Walk in a Forest (375/7495)
# ✅ Processed: Isolde (376/7495)
# ✅ Processed: Feed Me (377/7495)
# ✅ Processed: Hack-a-Team (378/7495)
# ✅ Processed: Suit Up! (379/7495)
# ✅ Processed: Raven (380/7495)
# ✅ Processed: GoosDaR (381/7495)
# ✅ Processed: IntegriTweet (382/7495)
# ✅ Processed: BulletTime (383/7495)
# ✅ Processed: Gitalk (384/7495)
# ✅ Processed: Recyc-AI (385/7495)
# ✅ Processed: Bridge (386/7495)
# ✅ Processed: ToDo.it (387/7495)
# ✅ Processed: Re:Meet (388/7495)
# ✅ Processed: a (389/7495)
# ✅ Processed: When should I go? (390/7495)
# ✅ Processed: reviewr (391/7495)
# ✅ Processed: GymBuddies.Online (392/7495)
# ✅ Processed: accima (393/7495)
# ✅ Processed: AuditApp (394/7495)
# ✅ Processed: Demeter (395/7495)
# ✅ Processed: MoodBot (396/7495)
# ✅ Processed: unsplash for food (397/7495)
# ✅ Processed: Cool-facts-about-space (398/7495)
# ✅ Processed: Sh.a.i.kspear: AI As Art (399/7495)
# ✅ Processed: Code Prez (400/7495)
# ✅ Processed: Mr. Doctor  (an IBM Watson project) (401/7495)
# ✅ Processed: MeLanie (402/7495)
# ✅ Processed: Productify.online (403/7495)
# ✅ Processed: If Only (404/7495)
# ✅ Processed: GRADEX (405/7495)
# ✅ Processed: Tutor Tinder (406/7495)
# ✅ Processed: Spoil-er Alert! (407/7495)
# ✅ Processed: Recipely (408/7495)
# ✅ Processed: Study Buddies (409/7495)
# ✅ Processed: PogChat (410/7495)
# ✅ Processed: Hungry Helper (411/7495)
# ✅ Processed: Aang (412/7495)
# ✅ Processed: PolarNize (413/7495)
# ✅ Processed: Knit (414/7495)
# ✅ Processed: Lucify (415/7495)
# ✅ Processed: COVID-19 Reviews (416/7495)
# ✅ Processed: AImatch: A Word Embedding Game (417/7495)
# ✅ Processed: HoverFlow Navigation (418/7495)
# ✅ Processed: Sketchy (419/7495)
# ✅ Processed: PodBot (420/7495)
# ✅ Processed: DisGraph (421/7495)
# ✅ Processed: Project Pangaea (422/7495)
# ✅ Processed: CodeCombat (423/7495)
# ✅ Processed: skatein.space (424/7495)
# ✅ Processed: Bees (425/7495)
# ✅ Processed: Currency Converter (426/7495)
# ✅ Processed: IntAI (427/7495)
# ✅ Processed: Netflix and Chat (428/7495)
# ✅ Processed: PostItUp (429/7495)
# ✅ Processed: smüth (430/7495)
# ✅ Processed: Talk Money. (431/7495)
# ✅ Processed: CrewsControl (432/7495)
# ✅ Processed: Fleurish (433/7495)
# ✅ Processed: offline (434/7495)
# ✅ Processed: Moodify Player (435/7495)
# ✅ Processed: Comp.are (436/7495)
# ✅ Processed: Linkify (437/7495)
# ✅ Processed: eCaring (438/7495)
# ✅ Processed: VBook - Facebook Messenger Extension (439/7495)
# ✅ Processed: Balanced (440/7495)
# ✅ Processed: Simmer (441/7495)
# ✅ Processed: Kamakshi (442/7495)
# ✅ Processed: Study Buddy (443/7495)
# ✅ Processed: YouSpeak (444/7495)
# ✅ Processed: TimeIsMoney-HTN (445/7495)
# ✅ Processed: Weathervibe (446/7495)
# ✅ Processed: What's in my food? (447/7495)
# ✅ Processed: Circle Pong (448/7495)
# ✅ Processed: CoviData (449/7495)
# ✅ Processed: HeyFind - A Computer Vision Powered Game (450/7495)
# ✅ Processed: You Are Elevated (451/7495)
# ✅ Processed: Drop-Shop (452/7495)
# ✅ Processed: cointrade (453/7495)
# ✅ Processed: Epidemic Simulator (454/7495)
# ✅ Processed: Another man's recycling (455/7495)
# ✅ Processed: Mask Detector (456/7495)
# ✅ Processed: SteamStats (457/7495)
# ✅ Processed: ShelfLife (458/7495)
# ✅ Processed: Mask Detector (459/7495)
# ✅ Processed: PatchTO (460/7495)
# ✅ Processed: Mask Detector (461/7495)
# ✅ Processed: To the Moon (?) (462/7495)
# ✅ Processed: Curated (463/7495)
# ✅ Processed: Wingbot (464/7495)
# ✅ Processed: Card Casino Royale (465/7495)
# ✅ Processed: Covid-19 Google Home Assistant (466/7495)
# ✅ Processed: The Vaccine (467/7495)
# ✅ Processed: ambrosia (468/7495)
# ✅ Processed: BubbleBuy (469/7495)
# ✅ Processed: Renshu (470/7495)
# ✅ Processed: LarryBarry (471/7495)
# ✅ Processed: Watchdog (472/7495)
# ✅ Processed: ENERGi (473/7495)
# ✅ Processed: Mood on Repeat (474/7495)
# ✅ Processed: LinkUP (475/7495)
# ✅ Processed: Weathered (476/7495)
# ✅ Processed: Tack (477/7495)
# ✅ Processed: Cash Flow Management App (478/7495)
# ✅ Processed: CourseAid (479/7495)
# ✅ Processed: Mutuoso (480/7495)
# ✅ Processed: Reconstruct (481/7495)
# ✅ Processed: Textualize (482/7495)
# ✅ Processed: Am I Cancelled? (483/7495)
# ✅ Processed: u-rally (484/7495)
# ✅ Processed: TensorCalc (485/7495)
# ✅ Processed: Doctor Bot (486/7495)
# ✅ Processed: Helping Hand (487/7495)
# ✅ Processed: SpotiNet (488/7495)
# ✅ Processed: covid19_canada_htn (489/7495)
# ✅ Processed: OpenCheck (490/7495)
# ✅ Processed: Hangman Deluxe (491/7495)
# ✅ Processed: Neighbourgoods (492/7495)
# ✅ Processed: TDAR 1 (493/7495)
# ✅ Processed: Cooky (494/7495)
# ✅ Processed: SpotifyParty (495/7495)
# ✅ Processed: Purity (496/7495)
# ✅ Processed: SpotiFind (497/7495)
# ✅ Processed: Recipe.io (498/7495)
# ✅ Processed: ding! (499/7495)
# ✅ Processed: Entangled in Plastic (500/7495)
# ✅ Processed: Exactum (501/7495)
# ✅ Processed: HayStats (502/7495)
# ✅ Processed: StayAwayFromMe (503/7495)
# ✅ Processed: SpeechQ (504/7495)
# ✅ Processed: HobbyHub (505/7495)
# ✅ Processed: Chill Pill (506/7495)
# ✅ Processed: Masked Captions (507/7495)
# ✅ Processed: Hydronizer (508/7495)
# ✅ Processed: Insta Recipe (509/7495)
# ✅ Processed: GoodDay (510/7495)
# ✅ Processed: Friend Zones (511/7495)
# ✅ Processed: In the Stars (512/7495)
# ✅ Processed: Spectrum (513/7495)
# ✅ Processed: Herbert (514/7495)
# ✅ Processed: TO the 6ix (515/7495)
# ✅ Processed: Superlist! (516/7495)
# ✅ Processed: SuperPose (517/7495)
# ✅ Processed: Motive (518/7495)
# ✅ Processed: Move 'n Groove (519/7495)
# ✅ Processed: GeoTrace (520/7495)
# ✅ Processed: Safety Watch (521/7495)
# ✅ Processed: Calendar Creator (522/7495)
# ✅ Processed: The Dash Man (523/7495)
# ✅ Processed: Airborne (524/7495)
# ✅ Processed: Sentimetre (525/7495)
# ✅ Processed: Rubber Duck (526/7495)
# ✅ Processed: Friendly Fire (527/7495)
# ✅ Processed: Slackoff (528/7495)
# ✅ Processed: Spine Saver (529/7495)
# ✅ Processed: NutriBuddy (530/7495)
# ✅ Processed: CaptionCaptain (531/7495)
# ✅ Processed: Covid-19-Vaccine-Tracker (532/7495)
# ✅ Processed: TourAll (533/7495)
# ✅ Processed: Petrol Pal (534/7495)
# ✅ Processed: Digicard (535/7495)
# ✅ Processed: Among Us Expansion (536/7495)
# ✅ Processed: When Vaccine? (537/7495)
# ✅ Processed: positweets || ~ no sad vibes allowed ~ (538/7495)
# ✅ Processed: Homies (539/7495)
# ✅ Processed: Adventure Game (540/7495)
# ✅ Processed: KEYBored (541/7495)
# ✅ Processed: Rx-Connect (542/7495)
# ✅ Processed: ClockBlockr (543/7495)
# ✅ Processed: Breaking Down COVID-19 (544/7495)
# ✅ Processed: Dodge the Virus (545/7495)
# ✅ Processed: prepear (546/7495)
# ✅ Processed: LaundryBOT (547/7495)
# ✅ Processed: TimeFlow: Your attention manager (548/7495)
# ✅ Processed: Papertition (549/7495)
# ✅ Processed: The Games that Connect (550/7495)
# ✅ Processed: COVID-19 Vaccine Queue (551/7495)
# ✅ Processed: "To The Moon" (552/7495)
# ✅ Processed: Squat Squad (553/7495)
# ✅ Processed: meet.up (554/7495)
# ✅ Processed: VERSA (555/7495)
# ✅ Processed: HackTheNorth Dr. Steph's Hippocampus Repair Stop (556/7495)
# ✅ Processed: Polygraph (557/7495)
# ✅ Processed: Nom. (558/7495)
# ✅ Processed: MyPersonalDoctor (559/7495)
# ✅ Processed: Joya (560/7495)
# ✅ Processed: PicPerfect (561/7495)
# ✅ Processed: ShareFood (562/7495)
# ✅ Processed: oh, to be a seacow... (563/7495)
# ✅ Processed: FolloWaldo (564/7495)
# ✅ Processed: Match 3 Duel (565/7495)
# ✅ Processed: myBoard.space (566/7495)
# ✅ Processed: MY_well-being (567/7495)
# ✅ Processed: Emotion.NET (568/7495)
# ✅ Processed: Actor Tracker (569/7495)
# ✅ Processed: AnonSMS-HTN-2021 (570/7495)
# ✅ Processed: Sigmage (571/7495)
# ✅ Processed: JTrack (572/7495)
# ✅ Processed: Hair-Me-Out (573/7495)
# ✅ Processed: Hand Me Down (574/7495)
# ✅ Processed: House AI (575/7495)
# ✅ Processed: Hang Bot -- Featuring Words (576/7495)
# ✅ Processed: MyCheeksHurt (577/7495)
# ✅ Processed: Infotext (578/7495)
# ✅ Processed: Bias Buddy (579/7495)
# ✅ Processed: Space Image Bot (580/7495)
# ✅ Processed: Can we hit 100 likes? (581/7495)
# ✅ Processed: freeflo.io (582/7495)
# ✅ Processed: Workout Buddies (583/7495)
# ✅ Processed: NoteSus (584/7495)
# ✅ Processed: Social Media Web App (585/7495)
# ✅ Processed: KaraokeBot (586/7495)
# ✅ Processed: . (587/7495)
# ✅ Processed: Git 3D (588/7495)
# ✅ Processed: navicourse (589/7495)
# ✅ Processed: Secure ATM (590/7495)
# ✅ Processed: TreeCosystem (591/7495)
# ✅ Processed: Cite Safe (592/7495)
# ✅ Processed: DocDash (593/7495)
# ✅ Processed: DocuSite (594/7495)
# ✅ Processed: Biz-Commerce (595/7495)
# ✅ Processed: CAN SUM CAM (596/7495)
# ✅ Processed: DoxMy.Tech (597/7495)
# ✅ Processed: draft360 (598/7495)
# ✅ Processed: Accessibility Toolkit For Unity (599/7495)
# ✅ Processed: #³ (600/7495)
# ✅ Processed: NutriMonster (601/7495)
# ✅ Processed: Voice of One (602/7495)
# ✅ Processed: Rising Tide (603/7495)
# ✅ Processed: TalkAI (Team 035) (604/7495)
# ✅ Processed: VSiBL (605/7495)
# ✅ Processed: Spell Bound (606/7495)
# ✅ Processed: GhostBustXR (607/7495)
# ✅ Processed: SpaceAR (608/7495)
# ✅ Processed: AirSpace (609/7495)
# ✅ Processed: Brain Drain-The Academic Adventure to Save the World! (610/7495)
# ✅ Processed: The Mind's Eye (611/7495)
# ✅ Processed: AR Community Garden (612/7495)
# ✅ Processed: ARpet (613/7495)
# ✅ Processed: Virtuoso XR: Immersive Music Education (614/7495)
# ✅ Processed: The Focus Field (615/7495)
# ✅ Processed: AREdge (616/7495)
# ✅ Processed: EducationalXR (617/7495)
# ✅ Processed: CLEAR - AR Biopsy Guidance System (618/7495)
# ✅ Processed: ARehab (619/7495)
# ✅ Processed: Magic Dots (620/7495)
# ✅ Processed: SledAR (621/7495)
# ✅ Processed: MiXR - Spatial Synthesizer (622/7495)
# ✅ Processed: Blinkenlights (623/7495)
# ✅ Processed: ProgressivelyEnhancedIndoorNavigationWebXR (624/7495)
# ✅ Processed: flockAR (625/7495)
# ✅ Processed: Pan Gu (626/7495)
# ✅ Processed: Catch Me If You Can (627/7495)
# ✅ Processed: Climate Control (628/7495)
# ✅ Processed: Ecstasis (629/7495)
# ✅ Processed: Words (630/7495)
# ✅ Processed: Spatial Universal Interaction System (631/7495)
# ✅ Processed: Down Payment on the Dream: The True Story of Frank Legree (632/7495)
# ✅ Processed: Detective Trainar (633/7495)
# ✅ Processed: Curiouser (634/7495)
# ✅ Processed: Dungeon of Elements: Perilous Journey of the Avatar (635/7495)
# ✅ Processed: When I Was Little (636/7495)
# ✅ Processed: YOUtopia (637/7495)
# ✅ Processed: Mixalise (638/7495)
# ✅ Processed: Life (639/7495)
# ✅ Processed: To-Gather (640/7495)
# ✅ Processed: Icarus (641/7495)
# ✅ Processed: SeniAR (642/7495)
# ✅ Processed: Shaken - MIT Reality Hack (643/7495)
# ✅ Processed: Liberty City VR (644/7495)
# ✅ Processed: PANOPTICON (645/7495)
# ✅ Processed: Duet (646/7495)
# ✅ Processed: SpaceChanger (647/7495)
# ✅ Processed: The FlowJo (648/7495)
# ✅ Processed: Planet Protector (649/7495)
# ✅ Processed: journalAR (650/7495)
# ✅ Processed: ControlAR (651/7495)
# ✅ Processed: Bird (652/7495)
# ✅ Processed: AR Community Garden (653/7495)
# ✅ Processed: uTooth (654/7495)
# ✅ Processed: Ide Træ (655/7495)
# ✅ Processed: X-Waves (656/7495)
# ✅ Processed: HyperViz (657/7495)
# ✅ Processed: TASK TRANSFER (658/7495)
# ✅ Processed: One Billion Lost: Australia's Wildfires VR Experience (659/7495)
# ✅ Processed: Mixed Reality Sign Language Learning Studio (660/7495)
# ✅ Processed: DONO: Giving Tree (661/7495)
# ✅ Processed: SignAR (662/7495)
# ✅ Processed: Grocery Grab (663/7495)
# ✅ Processed: Write Noise (664/7495)
# ✅ Processed: Crust (665/7495)
# ✅ Processed: MaskOn (666/7495)
# ✅ Processed: A (667/7495)
# ✅ Processed: HelpTag (Team Ohana) (668/7495)
# ✅ Processed: BizViz (669/7495)
# ✅ Processed: HemoHelper (670/7495)
# ✅ Processed: Draw Your Way (671/7495)
# ✅ Processed: Deploy (672/7495)
# ✅ Processed: Fresca (673/7495)
# ✅ Processed: Excessible (674/7495)
# ✅ Processed: Foodie Buddie (675/7495)
# ✅ Processed: NewsQ Challenge: Optimizing News Recommendation Algorithms (676/7495)
# ✅ Processed: Bob Was A Rectangle (677/7495)
# ✅ Processed: SALON (678/7495)
# ✅ Processed: Fizz - Your Personal Financial Consultant (679/7495)
# ✅ Processed: Abu (680/7495)
# ✅ Processed: BuzzBasket (681/7495)
# ✅ Processed: Omnicart (682/7495)
# ✅ Processed: Bloom (683/7495)
# ✅ Processed: Junction (684/7495)
# ✅ Processed: Scrubs | Helping Nurses Help Us (685/7495)
# ✅ Processed: Hospital Buddiez (686/7495)
# ✅ Processed: Anytime Healthcare (687/7495)
# ✅ Processed: Heimdallr (688/7495)
# ✅ Processed: PicselAR (689/7495)
# ✅ Processed: "SOAPBOX" World Effect (690/7495)
# ✅ Processed: Spark Ar Filter for Concert Experiences (691/7495)
# ✅ Processed: That's so Local (692/7495)
# ✅ Processed: NewsReel (693/7495)
# ✅ Processed: WonderLab (694/7495)
# ✅ Processed: Canvas Board (695/7495)
# ✅ Processed: HackNews (696/7495)
# ✅ Processed: got bias? (697/7495)
# ✅ Processed: Newsly (698/7495)
# ✅ Processed: Duv-Duv Gap (699/7495)
# ✅ Processed: Newsworthy (700/7495)
# ✅ Processed: CanadaRank (701/7495)
# ✅ Processed: cleannews (702/7495)
# ✅ Processed: Military Graph Database (703/7495)
# ✅ Processed: Health Port (704/7495)
# ✅ Processed: TestMe (705/7495)
# ✅ Processed: ClassroomOCR (706/7495)
# ✅ Processed: PiPlane (707/7495)
# ✅ Processed: Unbias.ly (708/7495)
# ✅ Processed: 3D point cloud mapping vSLAM (709/7495)
# ✅ Processed: Recycler (710/7495)
# ✅ Processed: COVID-19 Sentiment Analysis Dashboard (711/7495)
# ✅ Processed: NiteLite (712/7495)
# ✅ Processed: fairycomm (713/7495)
# ✅ Processed: AggregationStation (714/7495)
# ✅ Processed: Taidl - Everyday Payment with xDai Blockchain (715/7495)
# ✅ Processed: I-Sight (716/7495)
# ✅ Processed: Pokt (717/7495)
# ✅ Processed: Educe (718/7495)
# ✅ Processed: Youber (719/7495)
# ✅ Processed: FaceBlindHelper (720/7495)
# ✅ Processed: Famly (721/7495)
# ✅ Processed: wable (722/7495)
# ✅ Processed: TreeGuard (723/7495)
# ✅ Processed: FaceCOVmonitor (724/7495)
# ✅ Processed: BroadCraft (725/7495)
# ✅ Processed: KovidTrafik (726/7495)
# ✅ Processed: dino (727/7495)
# ✅ Processed: MOTION: SMART INVENTORY (728/7495)
# ✅ Processed: NomNom (729/7495)
# ✅ Processed: CONNECTR (730/7495)
# ✅ Processed: Automatic Store Deployer (731/7495)
# ✅ Processed: Vehicle IoT Security System (732/7495)
# ✅ Processed: PriorityNews (733/7495)
# ✅ Processed: Alexandria (734/7495)
# ✅ Processed: Local Lenz (735/7495)
# ✅ Processed: What Are You Wearing Today? (WAYWT) (736/7495)
# ✅ Processed: Clean Eats (737/7495)
# ✅ Processed: Room Counter (738/7495)
# ✅ Processed: Schedaddle (739/7495)
# ✅ Processed: Medentifier (740/7495)
# ✅ Processed: Multiplayer VR Chess (741/7495)
# ✅ Processed: Pizza Hot - Get your Pizza while it's still hot! (742/7495)
# ✅ Processed: myFoodprint (743/7495)
# ✅ Processed: Produce Pal (Ctrl Alt Elite) (744/7495)
# ✅ Processed: Newsable (745/7495)
# ✅ Processed: Ceres (746/7495)
# ✅ Processed: Among Buzz (747/7495)
# ✅ Processed: Virtual Appointment and Testing Suite - VATS (748/7495)
# ✅ Processed: Retail Insight (749/7495)
# ✅ Processed: GBF (750/7495)
# ✅ Processed: Day Flow (751/7495)
# ✅ Processed: Customer-Arrival-Time Order Fulfillment (752/7495)
# ✅ Processed: Fred (753/7495)
# ✅ Processed: MoPay (754/7495)
# ✅ Processed: Mom&Pop (755/7495)
# ✅ Processed: Remote Partner (756/7495)
# ✅ Processed: Energy Consumption Analysis (757/7495)
# ✅ Processed: ByDesign (758/7495)
# ✅ Processed: Road to Radiant (759/7495)
# ✅ Processed: Self Checkout (760/7495)
# ✅ Processed: Small Business Insights Dashboard (761/7495)
# ✅ Processed: Integrated Mobile Order Picking (762/7495)
# ✅ Processed: Squiggle (763/7495)
# ✅ Processed: MeDelivery (764/7495)
# ✅ Processed: SwiftServe (765/7495)
# ✅ Processed: Foliox (766/7495)
# ✅ Processed: Canal (767/7495)
# ✅ Processed: Only飯s (768/7495)
# ✅ Processed: Memopet (769/7495)
# ✅ Processed: Don't Spoil on Me (770/7495)
# ✅ Processed: SpotiChat (771/7495)
# ✅ Processed: FoodLocker (772/7495)
# ✅ Processed: Med Viewer (773/7495)
# ✅ Processed: Norenue News (774/7495)
# ✅ Processed: UFCData (775/7495)
# ✅ Processed: SearchLight (776/7495)
# ✅ Processed: Try & Buy (777/7495)
# ✅ Processed: V-Assist (778/7495)
# ✅ Processed: Vitalizer (779/7495)
# ✅ Processed: Scheduler (780/7495)
# ✅ Processed: Shape Our Space (781/7495)
# ✅ Processed: Sparky (782/7495)
# ✅ Processed: Listify (783/7495)
# ✅ Processed: Smart Calendar (784/7495)
# ✅ Processed: CoviCare (785/7495)
# ✅ Processed: Suggestify (786/7495)
# ✅ Processed: Sanitizer (787/7495)
# ✅ Processed: CoMed (788/7495)
# ✅ Processed: Boba Map (789/7495)
# ✅ Processed: Ask Buzz (790/7495)
# ✅ Processed: rad(ish) (791/7495)
# ✅ Processed: replaylist (792/7495)
# ✅ Processed: Tweets for President (793/7495)
# ✅ Processed: KPOP Community App (794/7495)
# ✅ Processed: Super Notes (795/7495)
# ✅ Processed: Sentiment Trader (796/7495)
# ✅ Processed: Grocery List Application (797/7495)
# ✅ Processed: NOVID (798/7495)
# ✅ Processed: Sus Highlight (799/7495)
# ✅ Processed: Rendezvous (800/7495)
# ✅ Processed: space tech online (801/7495)
# ✅ Processed: Musi.Cloud (802/7495)
# ✅ Processed: Exercise Form Evaluator (803/7495)
# ✅ Processed: FiCal (804/7495)
# ✅ Processed: EngPredict (805/7495)
# ✅ Processed: Lack_of_Facts (806/7495)
# ✅ Processed: Blogging Site (807/7495)
# ✅ Processed: CartClerk (808/7495)
# ✅ Processed: Minirobot waiter (809/7495)
# ✅ Processed: Find + Create (810/7495)
# ✅ Processed: Project Backbone (811/7495)
# ✅ Processed: MOODEMIC-20 (812/7495)
# ✅ Processed: Timely Tables (813/7495)
# ✅ Processed: FactCheck (814/7495)
# ✅ Processed: Kids-Learn-Math-Website (815/7495)
# ✅ Processed: Fellini (816/7495)
# ✅ Processed: Doodle Theatre (817/7495)
# ✅ Processed: Sumex (818/7495)
# ✅ Processed: LoCart: Helping Local Grocers and Restaurants Thrive (819/7495)
# ✅ Processed: SMS-Bot (820/7495)
# ✅ Processed: grocery-app (821/7495)
# ✅ Processed: Viralventure (822/7495)
# ✅ Processed: JumPig (823/7495)
# ✅ Processed: LiveStock (824/7495)
# ✅ Processed: JobChamp (825/7495)
# ✅ Processed: SoundsAwful - Image to Music Cryptography (826/7495)
# ✅ Processed: Spooktober Summoner (827/7495)
# ✅ Processed: Smart Masks (828/7495)
# ✅ Processed: Color_the_Sky (829/7495)
# ✅ Processed: Gaps In History (830/7495)
# ✅ Processed: Zoomie the Self Care Bot (831/7495)
# ✅ Processed: Rocket Code (832/7495)
# ✅ Processed: Mood Movie Machine (833/7495)
# ✅ Processed: Crumbs (834/7495)
# ✅ Processed: CTRL + F (835/7495)
# ✅ Processed: HackGT 2020 - hackergurls (836/7495)
# ✅ Processed: Claudia's Test Project (837/7495)
# ✅ Processed: ToDo Stack (838/7495)
# ✅ Processed: The Aural Card (839/7495)
# ✅ Processed: Neon Face (840/7495)
# ✅ Processed: Archiscape (841/7495)
# ✅ Processed: Mood for Zoom (842/7495)
# ✅ Processed: CheaterBeater (843/7495)
# ✅ Processed: The Musick Space (844/7495)
# ✅ Processed: DevSpace (845/7495)
# ✅ Processed: Group Greenery (846/7495)
# ✅ Processed: SideTrack (847/7495)
# ✅ Processed: place.it (848/7495)
# ✅ Processed: QRantine (849/7495)
# ✅ Processed: clsrm - GClassroom via SMS (850/7495)
# ✅ Processed: Sonar - Helping the Visually Impaired See (851/7495)
# ✅ Processed: CoolSpace (852/7495)
# ✅ Processed: NOVID-19 (853/7495)
# ✅ Processed: Socialsense.ai (854/7495)
# ✅ Processed: GetFit (855/7495)
# ✅ Processed: GoFarm (856/7495)
# ✅ Processed: Boba Watch 2.0 (857/7495)
# ✅ Processed: Fluent (858/7495)
# ✅ Processed: StemSigns (859/7495)
# ✅ Processed: PandaGO (860/7495)
# ✅ Processed: P.A.T.I.E.N.T.S. (861/7495)
# ✅ Processed: deepvariant-challenge (862/7495)
# ✅ Processed: Patient Match (863/7495)
# ✅ Processed: stayinside (864/7495)
# ✅ Processed: Specto (865/7495)
# ✅ Processed: QuarenTime (866/7495)
# ✅ Processed: Impatient Records (867/7495)
# ✅ Processed: learning-extension (868/7495)
# ✅ Processed: Let's Match! (869/7495)
# ✅ Processed: Munchies - LA HACKS 2020 (870/7495)
# ✅ Processed: COVcall (871/7495)
# ✅ Processed: AR archery (872/7495)
# ✅ Processed: Mapwards (873/7495)
# ✅ Processed: Asparagus (874/7495)
# ✅ Processed: Synesthesia Model (875/7495)
# ✅ Processed: Varantine (876/7495)
# ✅ Processed: Radar trial (877/7495)
# ✅ Processed: Life over Life (878/7495)
# ✅ Processed: COVID-19 Tracker (879/7495)
# ✅ Processed: flexible-radio (880/7495)
# ✅ Processed: Nudge (881/7495)
# ✅ Processed: BeeSafe (882/7495)
# ✅ Processed: Class Chat (883/7495)
# ✅ Processed: Hibiscus (884/7495)
# ✅ Processed: Constructable (885/7495)
# ✅ Processed: Trashification (886/7495)
# ✅ Processed: Drive-Safe (887/7495)
# ✅ Processed: ShopperAlert (888/7495)
# ✅ Processed: CoroNow (889/7495)
# ✅ Processed: Covid-19 Growth Trend Matching (890/7495)
# ✅ Processed: RetroSwitch (891/7495)
# ✅ Processed: Capture The Flag (Alpha) (892/7495)
# ✅ Processed: Healthcare Agency Budgeting Simulator (893/7495)
# ✅ Processed: Hype Man (894/7495)
# ✅ Processed: HomeMadeEditor (895/7495)
# ✅ Processed: SuperCart (896/7495)
# ✅ Processed: LocalLy (897/7495)
# ✅ Processed: Pebble (898/7495)
# ✅ Processed: Safely (899/7495)
# ✅ Processed: #CodeVsCOVID19 - Minimal Distance (900/7495)
# ✅ Processed: Dr. Fauci World (901/7495)
# ✅ Processed: (C)arbon (902/7495)
# ✅ Processed: ReEmpower (903/7495)
# ✅ Processed: Equilibrate (904/7495)
# ✅ Processed: GenStats (905/7495)
# ✅ Processed: Ingredible (906/7495)
# ✅ Processed: MediLA (907/7495)
# ✅ Processed: Binge Time (908/7495)
# ✅ Processed: Data Arena (909/7495)
# ✅ Processed: A Social.M News World Covid Scrapper & Utility Web.App (910/7495)
# ✅ Processed: Vmeet (911/7495)
# ✅ Processed: IsolationLearning (912/7495)
# ✅ Processed: Deep Pocket (913/7495)
# ✅ Processed: COVID-19 Hub (914/7495)
# ✅ Processed: CoronInfo (915/7495)
# ✅ Processed: Miri (916/7495)
# ✅ Processed: Light the Sky (917/7495)
# ✅ Processed: Un1fy (918/7495)
# ✅ Processed: gyde (919/7495)
# ✅ Processed: Left, Right, and Center (920/7495)
# ✅ Processed: TP.FLOW (921/7495)
# ✅ Processed: Evergreen (922/7495)
# ✅ Processed: patientMatching (923/7495)
# ✅ Processed: Carbon Cutters (924/7495)
# ✅ Processed: Ship It (925/7495)
# ✅ Processed: QUARANTIME (926/7495)
# ✅ Processed: Hobbyist (927/7495)
# ✅ Processed: Livemoji (928/7495)
# ✅ Processed: Coronavirus Contagion Campaign (929/7495)
# ✅ Processed: Recap This Vid (930/7495)
# ✅ Processed: Go Eat (931/7495)
# ✅ Processed: VROOM (932/7495)
# ✅ Processed: Stay Home (933/7495)
# ✅ Processed: Mutare (934/7495)
# ✅ Processed: chumbot (935/7495)
# ✅ Processed: Activity Space (936/7495)
# ✅ Processed: Trashemon Go (937/7495)
# ✅ Processed: Covid-19 Counter (938/7495)
# ✅ Processed: Corona Proximity (939/7495)
# ✅ Processed: Covid-Safe Shopping (940/7495)
# ✅ Processed: Cronos (941/7495)
# ✅ Processed: Minutes++ (942/7495)
# ✅ Processed: Recyclify (943/7495)
# ✅ Processed: ReadShip (944/7495)
# ✅ Processed: Quarantivity (945/7495)
# ✅ Processed: CovidFreeSpace (946/7495)
# ✅ Processed: Coronav (947/7495)
# ✅ Processed: SOAPI - The Interactive Soap Dispenser (948/7495)
# ✅ Processed: Delve (949/7495)
# ✅ Processed: Hymn (950/7495)
# ✅ Processed: Foner (951/7495)
# ✅ Processed: Quarantinder (952/7495)
# ✅ Processed: Point Photo Mapping (953/7495)
# ✅ Processed: QuaranTwilio (954/7495)
# ✅ Processed: COVID-19 Testing Site Feature to Maps App (955/7495)
# ✅ Processed: COVID-19 Survey (956/7495)
# ✅ Processed: # (957/7495)
# ✅ Processed: Free The World (958/7495)
# ✅ Processed: Predictions for Future COVID 19 cases in Los Angeles (959/7495)
# ✅ Processed: LAHacks Patient Matching (960/7495)
# ✅ Processed: LA-Hacks-COVID-19 (961/7495)
# ✅ Processed: COVID-19-Detector (962/7495)
# ✅ Processed: LAHacks Challenge 1 - Patient Matching (963/7495)
# ✅ Processed: Music To My Eyes (964/7495)
# ✅ Processed: Covid Classroom (965/7495)
# ✅ Processed: Retroactive Location Tracking for Contact Tracing (966/7495)
# ✅ Processed: sixfeetof.space (967/7495)
# ✅ Processed: Engage (968/7495)
# ✅ Processed: HackUWU Owols (969/7495)
# ✅ Processed: FRAME (970/7495)
# ✅ Processed: Coronavirus Model (971/7495)
# ✅ Processed: Caption Capture (972/7495)
# ✅ Processed: Social Digger (973/7495)
# ✅ Processed: GridCast (974/7495)
# ✅ Processed: DisturbMeMaybe (975/7495)
# ✅ Processed: CoronaCare (976/7495)
# ✅ Processed: Cowovid-19 (977/7495)
# ✅ Processed: Map Mania! (978/7495)
# ✅ Processed: Corona Watch (979/7495)
# ✅ Processed: dr(ai)ke (980/7495)
# ✅ Processed: Park-O-Meter (981/7495)
# ✅ Processed: HandVirusScanner (982/7495)
# ✅ Processed: Food & Stuff (983/7495)
# ✅ Processed: Med3D (984/7495)
# ✅ Processed: COVID-19 screening using Deep Learning (985/7495)
# ✅ Processed: Patient Matching Challenge (986/7495)
# ✅ Processed: QuaranTIME (987/7495)
# ✅ Processed: The Bored Button (988/7495)
# ✅ Processed: GermImmobilizer V1 (989/7495)
# ✅ Processed: 95Defender (990/7495)
# ✅ Processed: StemSigns (991/7495)
# ✅ Processed: PoliBot (992/7495)
# ✅ Processed: After The Storm (993/7495)
# ✅ Processed: Phoenix - Pandemic Community Spread Tracker & Visualizer (994/7495)
# ✅ Processed: Ok Zoomer (995/7495)
# ✅ Processed: Cuarantine (996/7495)
# ✅ Processed: dindle (997/7495)
# ✅ Processed: Quarantivities (998/7495)
# ✅ Processed: P!ng: What's Happening? (999/7495)
# ✅ Processed: ZoomGroups (1000/7495)
# ✅ Processed: Mystic.io (1001/7495)
# ✅ Processed: shelfAlert+ (1002/7495)
# ✅ Processed: LA Hacks (1003/7495)
# ✅ Processed: Virtual Shelf (1004/7495)
# ✅ Processed: Cobridge (1005/7495)
# ✅ Processed: How Squegg Deals with Quarantine (1006/7495)
# ✅ Processed: COVID-19 Tracker (1007/7495)
# ✅ Processed: GAMIFY (1008/7495)
# ✅ Processed: Patient Identifier (1009/7495)
# ✅ Processed: homely (1010/7495)
# ✅ Processed: In Your View (1011/7495)
# ✅ Processed: Isolation Station (1012/7495)
# ✅ Processed: Patiently Matching (1013/7495)
# ✅ Processed: r u safe, buddy? (1014/7495)
# ✅ Processed: DONT CONSIDER THIS ONE (1015/7495)
# ✅ Processed: TRAK COVID-19 (1016/7495)
# ✅ Processed: Scene (1017/7495)
# ✅ Processed: Patient Matching (1018/7495)
# ✅ Processed: Appointment Maker (1019/7495)
# ✅ Processed: Covid IQ (1020/7495)
# ✅ Processed: easyBay (1021/7495)
# ✅ Processed: TrackCovid- Track the Coronavirus! (1022/7495)
# ✅ Processed: Covid-19 Patient/Non-Patient Risk Prediction using AI (1023/7495)
# ✅ Processed: Patiently (1024/7495)
# ✅ Processed: Income Calculator (1025/7495)
# ✅ Processed: Paraphrase (1026/7495)
# ✅ Processed: Open Ventilator Project (1027/7495)
# ✅ Processed: Ambulance Crowd Avoidance Simulator in Covid-19 Pandemic (1028/7495)
# ✅ Processed: NewsDeck (1029/7495)
# ✅ Processed: Stamper (1030/7495)
# ✅ Processed: Neutral (1031/7495)
# ✅ Processed: Lucid Drums (1032/7495)
# ✅ Processed: SafeCup (1033/7495)
# ✅ Processed: PocketPT (1034/7495)
# ✅ Processed: Reading Glasses (1035/7495)
# ✅ Processed: EduVoicer (1036/7495)
# ✅ Processed: Crowd Insights (1037/7495)
# ✅ Processed: Medley (1038/7495)
# ✅ Processed: MusicBlox: Tangible Programming Education in Mixed Reality (1039/7495)
# ✅ Processed: The LevelSet Suite: EquiBox, EquiTalk, and EquiTrack (1040/7495)
# ✅ Processed: Waitless - Stanford TreeHacks (1041/7495)
# ✅ Processed: ReadAR (1042/7495)
# ✅ Processed: Promise (1043/7495)
# ✅ Processed: aidn (1044/7495)
# ✅ Processed: FireNet: Wildfire Risk Forecaster for Social Equality (1045/7495)
# ✅ Processed: Inspo | An exploration tool for kids (1046/7495)
# ✅ Processed: Soteria (1047/7495)
# ✅ Processed: Dronations (1048/7495)
# ✅ Processed: Sybilline (1049/7495)
# ✅ Processed: Prevent (1050/7495)
# ✅ Processed: Super Smart Board (1051/7495)
# ✅ Processed: ClassiFly (1052/7495)
# ✅ Processed: GAiN a Friend (1053/7495)
# ✅ Processed: Eloquent — Learn Out Loud (1054/7495)
# ✅ Processed: ML Algorithm Visualizer (1055/7495)
# ✅ Processed: Talk to the Hand (1056/7495)
# ✅ Processed: Glucose Guardian (1057/7495)
# ✅ Processed: MedReader (1058/7495)
# ✅ Processed: HackerSat (1059/7495)
# ✅ Processed: health.ai (1060/7495)
# ✅ Processed: seedHacks (1061/7495)
# ✅ Processed: SaferSolo - Virtual Voice Directed Copilot (1062/7495)
# ✅ Processed: Questions? (1063/7495)
# ✅ Processed: Be Heard (1064/7495)
# ✅ Processed: Preggy (1065/7495)
# ✅ Processed: PacketBook (1066/7495)
# ✅ Processed: Infinite Sustain: a New Electric Piano (1067/7495)
# ✅ Processed: CirCreate (1068/7495)
# ✅ Processed: Artemis (1069/7495)
# ✅ Processed: Data in Depth (1070/7495)
# ✅ Processed: Guardian (1071/7495)
# ✅ Processed: hackATeam (1072/7495)
# ✅ Processed: VideoChat (1073/7495)
# ✅ Processed: SimplyReading (1074/7495)
# ✅ Processed: EarlyDeTech (1075/7495)
# ✅ Processed: Morning (1076/7495)
# ✅ Processed: Valence (1077/7495)
# ✅ Processed: Alc-Calc (1078/7495)
# ✅ Processed: Jourme (1079/7495)
# ✅ Processed: Trashier (1080/7495)
# ✅ Processed: Sonder (1081/7495)
# ✅ Processed: Food Locator (1082/7495)
# ✅ Processed: Medlingo (1083/7495)
# ✅ Processed: Cipher Breaker (1084/7495)
# ✅ Processed: Snippt (1085/7495)
# ✅ Processed: Fire Drones! (1086/7495)
# ✅ Processed: IPA+ (1087/7495)
# ✅ Processed: WorkoutBud (1088/7495)
# ✅ Processed: melanoma model (1089/7495)
# ✅ Processed: Skedula (1090/7495)
# ✅ Processed: MedKeep (1091/7495)
# ✅ Processed: Alexa MD (1092/7495)
# ✅ Processed: BlockEd - Student Academic Record System based on Blockchain (1093/7495)
# ✅ Processed: On-D-Go (1094/7495)
# ✅ Processed: uMaps (1095/7495)
# ✅ Processed: Wackipedia (1096/7495)
# ✅ Processed: VoiceMD (1097/7495)
# ✅ Processed: AvoidLinks (1098/7495)
# ✅ Processed: IEve (1099/7495)
# ✅ Processed: NeuroLearn (1100/7495)
# ✅ Processed: Traffic-Light-Switching-using-Reinforcement-Learning (1101/7495)
# ✅ Processed: Knock (1102/7495)
# ✅ Processed: Climate Change Game (1103/7495)
# ✅ Processed: Landmark (1104/7495)
# ✅ Processed: Split-It (1105/7495)
# ✅ Processed: Housing Hound (1106/7495)
# ✅ Processed: dr.ai (1107/7495)
# ✅ Processed: EDUMEDIA (1108/7495)
# ✅ Processed: Predicting forward revenues of high growth software stocks (1109/7495)
# ✅ Processed: Sustainable Shopping (1110/7495)
# ✅ Processed: Sound Therapy (1111/7495)
# ✅ Processed: No Doze! (1112/7495)
# ✅ Processed: MenoPositivity (1113/7495)
# ✅ Processed: seekAR (1114/7495)
# ✅ Processed: Do we care about bats? (1115/7495)
# ✅ Processed: pianoEd (1116/7495)
# ✅ Processed: Fallen Warrior Jefferey (1117/7495)
# ✅ Processed: Stingo (1118/7495)
# ✅ Processed: Equitas (1119/7495)
# ✅ Processed: Open Book (1120/7495)
# ✅ Processed: E-Donna (1121/7495)
# ✅ Processed: RouteSafe (1122/7495)
# ✅ Processed: Fifteen (1123/7495)
# ✅ Processed: Ember Alerts (1124/7495)
# ✅ Processed: Excel Beyond (1125/7495)
# ✅ Processed: recap (1126/7495)
# ✅ Processed: AQV (1127/7495)
# ✅ Processed: MUSEVUE (1128/7495)
# ✅ Processed: Particip8 (1129/7495)
# ✅ Processed: Recogvision (1130/7495)
# ✅ Processed: Language Like You (1131/7495)
# ✅ Processed: Health AI (1132/7495)
# ✅ Processed: openDV (1133/7495)
# ✅ Processed: jot (1134/7495)
# ✅ Processed: AAVA (1135/7495)
# ✅ Processed: handless learning (1136/7495)
# ✅ Processed: ARET (AR Environment Tagger) (1137/7495)
# ✅ Processed: FreshNet (1138/7495)
# ✅ Processed: HoloHacks (1139/7495)
# ✅ Processed: 2020 Democratic Candidate Quiz (1140/7495)
# ✅ Processed: Learn Baby Learn (1141/7495)
# ✅ Processed: Detecting Ground-Level Natural Disaster Images "In The Wild" (1142/7495)
# ✅ Processed: SafeDrinks (1143/7495)
# ✅ Processed: Asymmetry: Towards finding the next big thing like Bitcoin (1144/7495)
# ✅ Processed: Chroma (1145/7495)
# ✅ Processed: GitVis (1146/7495)
# ✅ Processed: CreScEntS (1147/7495)
# ✅ Processed: Babel: Unlimited Languages, in a Box (1148/7495)
# ✅ Processed: Who's that Meme? (1149/7495)
# ✅ Processed: Bitfo (1150/7495)
# ✅ Processed: ARrehab (1151/7495)
# ✅ Processed: Cardinal Direction (1152/7495)
# ✅ Processed: Stroke Saver (1153/7495)
# ✅ Processed: Bloqi: Academic credential verification (1154/7495)
# ✅ Processed: Woven: SMARTIFY DEVICES! (1155/7495)
# ✅ Processed: BlueSpot (1156/7495)
# ✅ Processed: Easy-garden (1157/7495)
# ✅ Processed: SportCam (1158/7495)
# ✅ Processed: Flython (1159/7495)
# ✅ Processed: The Politics of Reddit in Sentiment (1160/7495)
# ✅ Processed: Government Simulator (1161/7495)
# ✅ Processed: Sex Education: The Game (1162/7495)
# ✅ Processed: The More You Snow (1163/7495)
# ✅ Processed: SnapClass (check out: https://snap.c-lass.com) (1164/7495)
# ✅ Processed: Auto Referee (1165/7495)
# ✅ Processed: MAXTHRU (1166/7495)
# ✅ Processed: Termify (1167/7495)
# ✅ Processed: TrailGait (1168/7495)
# ✅ Processed: MediText (1169/7495)
# ✅ Processed: flixster (1170/7495)
# ✅ Processed: Facial Detection (1171/7495)
# ✅ Processed: Degree Payoff (1172/7495)
# ✅ Processed: NavHack (1173/7495)
# ✅ Processed: Weekly (1174/7495)
# ✅ Processed: Words of the World (1175/7495)
# ✅ Processed: SkillEd (1176/7495)
# ✅ Processed: Sparks: sparking kids' curiosity (1177/7495)
# ✅ Processed: snaccbot (1178/7495)
# ✅ Processed: 3D-ify (1179/7495)
# ✅ Processed: Stanford Open Data Portal (1180/7495)
# ✅ Processed: DoctorUp (1181/7495)
# ✅ Processed: remembAR (1182/7495)
# ✅ Processed: Spotify API Exploration (1183/7495)
# ✅ Processed: Pseu-Chef (1184/7495)
# ✅ Processed: Yoink (1185/7495)
# ✅ Processed: Twitter Dioxide (1186/7495)
# ✅ Processed: MAPLE (1187/7495)
# ✅ Processed: A Novel Monte Carlo Simulation of the Spread of Coronavirus (1188/7495)
# ✅ Processed: MeeToo (1189/7495)
# ✅ Processed: Programmatically Unaided Conversational Companion (PUCC) (1190/7495)
# ✅ Processed: TourgEYEd (1191/7495)
# ✅ Processed: Heroine Addiction Predictor (1192/7495)
# ✅ Processed: Travelio (1193/7495)
# ✅ Processed: Poetic_Dream (1194/7495)
# ✅ Processed: Senioritis (1195/7495)
# ✅ Processed: HOSPITALity (1196/7495)
# ✅ Processed: tryp (1197/7495)
# ✅ Processed: myHealthCentra (1198/7495)
# ✅ Processed: SMH: Smart Monitor for Homes (1199/7495)
# ✅ Processed: DFA for AES (1200/7495)
# ✅ Processed: Loop: Accessible & Customized Automatic Insulin Delivery (1201/7495)
# ✅ Processed: Morphvism (1202/7495)
# ✅ Processed: EdVisor (1203/7495)
# ✅ Processed: Roomie (1204/7495)
# ✅ Processed: D. W. I. (1205/7495)
# ✅ Processed: caregiVR (1206/7495)
# ✅ Processed: Press Open (1207/7495)
# ✅ Processed: Discover Artist Betting (1208/7495)
# ✅ Processed: Magician (1209/7495)
# ✅ Processed: Node MCU Heartbeat (1210/7495)
# ✅ Processed: Code Overdose (1211/7495)
# ✅ Processed: Study Buddy (1212/7495)
# ✅ Processed: Convo (1213/7495)
# ✅ Processed: Sigfigs: Automatically Solving P vs NP for CSPs (1214/7495)
# ✅ Processed: AngelLink (1215/7495)
# ✅ Processed: seEmotion (1216/7495)
# ✅ Processed: coursestamp (1217/7495)
# ✅ Processed: HealthAccess (1218/7495)
# ✅ Processed: Diagnosing Disease with Human Microbiome Data (1219/7495)
# ✅ Processed: Boba Generator (1220/7495)
# ✅ Processed: ignore this project (1221/7495)
# ✅ Processed: geo-vis (1222/7495)
# ✅ Processed: Foster Connect (1223/7495)
# ✅ Processed: StockBot (1224/7495)
# ✅ Processed: Memory Lane (1225/7495)
# ✅ Processed: Bear Bones Storage (1226/7495)
# ✅ Processed: yestrashCAN! (1227/7495)
# ✅ Processed: Summaread (1228/7495)
# ✅ Processed: EduLabs (1229/7495)
# ✅ Processed: Talking Piano (1230/7495)
# ✅ Processed: Day.ly (1231/7495)
# ✅ Processed: CalGuard (1232/7495)
# ✅ Processed: Searchin (1233/7495)
# ✅ Processed: Leftoverz (1234/7495)
# ✅ Processed: Pog Concert Extension (1235/7495)
# ✅ Processed: KidU (1236/7495)
# ✅ Processed: FixingBad (1237/7495)
# ✅ Processed: Ingredient (1238/7495)
# ✅ Processed: My Swag Space (1239/7495)
# ✅ Processed: Quarantine Buddies (1240/7495)
# ✅ Processed: COVID-19 FlowCheck (1241/7495)
# ✅ Processed: Zinteract (1242/7495)
# ✅ Processed: Clarity (1243/7495)
# ✅ Processed: OurNET (1244/7495)
# ✅ Processed: CheckMe-In (1245/7495)
# ✅ Processed: IT IS PHISHY (1246/7495)
# ✅ Processed: Chinatown Eats (1247/7495)
# ✅ Processed: COVAID (1248/7495)
# ✅ Processed: What Happened Today (1249/7495)
# ✅ Processed: Sahayak (1250/7495)
# ✅ Processed: EcoFire (1251/7495)
# ✅ Processed: YuTab (1252/7495)
# ✅ Processed: CovidTracker2020 (1253/7495)
# ✅ Processed: ParkingSpotter (1254/7495)
# ✅ Processed: Therapeasy (1255/7495)
# ✅ Processed: Solo No Covid (1256/7495)
# ✅ Processed: I-Fit Application (1257/7495)
# ✅ Processed: HopGuide (1258/7495)
# ...
# ✅ Processed: STEMverse - TamuHackx (7283/7495)
# ✅ Processed: In a Nutshell - Intro to Credit Card (7284/7495)
# ✅ Processed: MoneyBuddy (7285/7495)
# ✅ Processed: STEM4stems (7286/7495)
# ✅ Processed: Aggie Xplore (7287/7495)
# ✅ Processed: coolSTEM (7288/7495)
# ✅ Processed: Bloom - Financial Literacy Tool (7289/7495)
# ✅ Processed: TravelExpo (7290/7495)
# ✅ Processed: PhishingRod (7291/7495)
# ✅ Processed: Infinity For Kids (7292/7495)
# ✅ Processed: ethiCart (7293/7495)
# ✅ Processed: WE HAVE ANOTHER SUBMISSION ***NOT THIS ONE SAME PEOPLE*** (7294/7495)
# ✅ Processed: PHISHing Trip (7295/7495)
# ✅ Processed: Safe Search (7296/7495)
# ✅ Processed: In-Flight Services (7297/7495)
# ✅ Processed: StemPlayer (7298/7495)
# ✅ Processed: AAnomaly (7299/7495)
# ✅ Processed: Overbooked flight API (7300/7495)
# ✅ Processed: GuardianMotion (7301/7495)
# ✅ Processed: The Console Corner (7302/7495)
# ✅ Processed: Life as STEM (7303/7495)
# ✅ Processed: Stock Vibes (7304/7495)
# ✅ Processed: Wild minds (7305/7495)
# ✅ Processed: Viva Stemedu (7306/7495)
# ✅ Processed: AAlgoNavigators (7307/7495)
# ✅ Processed: American Airlines - Attraction Finder in Cities (7308/7495)
# ✅ Processed: Sunrise Photosensor Development (7309/7495)
# ✅ Processed: JobJet (7310/7495)
# ✅ Processed: TechTots (7311/7495)
# ✅ Processed: T-soding (7312/7495)
# ✅ Processed: RFID Reader (7313/7495)
# ✅ Processed: Germination Station (7314/7495)
# ✅ Processed: FinQuest (7315/7495)
# ✅ Processed: Wingman (7316/7495)
# ✅ Processed: Capturing Phishing Scams with GCN (7317/7495)
# ✅ Processed: Financial Goal Tracker (7318/7495)
# ✅ Processed: SkyStream (7319/7495)
# ✅ Processed: PhishAlert (7320/7495)
# ✅ Processed: FinScore Financial Solution (7321/7495)
# ✅ Processed: DCAcademy (7322/7495)
# ✅ Processed: ComfortCuff (7323/7495)
# ✅ Processed: AAir Buddy (7324/7495)
# ✅ Processed: Recall GPT (7325/7495)
# ✅ Processed: Lumos: A light for all voices (7326/7495)
# ✅ Processed: Muney Jr. (7327/7495)
# ✅ Processed: SafeSurf (7328/7495)
# ✅ Processed: Meili (7329/7495)
# ✅ Processed: Bot Paper Scissors (7330/7495)
# ✅ Processed: Lyrykss - Free Music Streaming Application (7331/7495)
# ✅ Processed: Attendr (7332/7495)
# ✅ Processed: Nutriscan (7333/7495)
# ✅ Processed: Finnow (7334/7495)
# ✅ Processed: CVC (7335/7495)
# ✅ Processed: Carue (7336/7495)
# ✅ Processed: Temperature/Humidity Displayer (7337/7495)
# ✅ Processed: SkyHigh (7338/7495)
# ✅ Processed: brainARcade (7339/7495)
# ✅ Processed: Roam (7340/7495)
# ✅ Processed: BrainBlast (7341/7495)
# ✅ Processed: GOAT (7342/7495)
# ✅ Processed: BOBA-Real (7343/7495)
# ✅ Processed: StandbySorcerer (7344/7495)
# ✅ Processed: FantaStock (7345/7495)
# ✅ Processed: Fintelligent (7346/7495)
# ✅ Processed: project (7347/7495)
# ✅ Processed: Codehoot (7348/7495)
# ✅ Processed: Financy (7349/7495)
# ✅ Processed: Flight Forecaster (7350/7495)
# ✅ Processed: Phish Net (7351/7495)
# ✅ Processed: nan (7352/7495)
# ✅ Processed: Reveille Chatbot (7353/7495)
# ✅ Processed: splitt (7354/7495)
# ✅ Processed: temp (7355/7495)
# ✅ Processed: project (7356/7495)
# ✅ Processed: Restaurant (7357/7495)
# ✅ Processed: RetailWise (7358/7495)
# ✅ Processed: Mexl Harmyny (7359/7495)
# ✅ Processed: Hover Buddy (7360/7495)
# ✅ Processed: vggdn (7361/7495)
# ✅ Processed: InvestrGuessr (7362/7495)
# ✅ Processed: T-soding (7363/7495)
# ✅ Processed: boba (7364/7495)
# ✅ Processed: DigiBank (7365/7495)
# ✅ Processed: ok (7366/7495)
# ✅ Processed: AASE (7367/7495)
# ✅ Processed: stemlings (7368/7495)
# ✅ Processed: Sons of Garmadon (7369/7495)
# ✅ Processed: EarQ (7370/7495)
# ✅ Processed: STEM Explorers (7371/7495)
# ✅ Processed: Advisify. (7372/7495)
# ✅ Processed: Flamigo (7373/7495)
# ✅ Processed: FlyOnTime (7374/7495)
# ✅ Processed: The American Airlines Employee Travel Buddy (7375/7495)
# ✅ Processed: FutureForU (7376/7495)
# ✅ Processed: PrivacyNow (7377/7495)
# ✅ Processed: Groupthink (7378/7495)
# ✅ Processed: AeroAdvice (7379/7495)
# ✅ Processed: Echo Finance (7380/7495)
# ✅ Processed: Reveille Reserve (7381/7495)
# ✅ Processed: AirControl (7382/7495)
# ✅ Processed: ToddAI (7383/7495)
# ✅ Processed: GROVER (Grass-Rover) (7384/7495)
# ✅ Processed: MedBox (7385/7495)
# ✅ Processed: Stock Sense (7386/7495)
# ✅ Processed: Ticket Translator (7387/7495)
# ✅ Processed: SubSync (7388/7495)
# ✅ Processed: proDuck (7389/7495)
# ✅ Processed: Student Financial Advisory (7390/7495)
# ✅ Processed: STEAM Island (7391/7495)
# ✅ Processed: GateReady (7392/7495)
# ✅ Processed: Bipolar Pacemaker (7393/7495)
# ✅ Processed: Mytinerary (7394/7495)
# ✅ Processed: SkillSwap (7395/7495)
# ✅ Processed: Project (7396/7495)
# ✅ Processed: Wifi Shield (7397/7495)
# ✅ Processed: AirBud (7398/7495)
# ✅ Processed: No Fish (7399/7495)
# ✅ Processed: AggieBot (7400/7495)
# ✅ Processed: Dollar Sim (7401/7495)
# ✅ Processed: SkyScore (7402/7495)
# ✅ Processed: FloSTEM (7403/7495)
# ✅ Processed: Snack/Drink Workflow App (7404/7495)
# ✅ Processed: Stitch (7405/7495)
# ✅ Processed: Redacted (7406/7495)
# ✅ Processed: EcoExplorer (7407/7495)
# ✅ Processed: Lara Entertainment (7408/7495)
# ✅ Processed: PhishNet (7409/7495)
# ✅ Processed: Waddle Into STEM (7410/7495)
# ✅ Processed: bAckup plAn (7411/7495)
# ✅ Processed: I want boba pls (7412/7495)
# ✅ Processed: Color Sorter (7413/7495)
# ✅ Processed: SeatWise.tech (7414/7495)
# ✅ Processed: Bount-E (7415/7495)
# ✅ Processed: Larry the Light-Following Lizard (7416/7495)
# ✅ Processed: Electrolysis Rocket (7417/7495)
# ✅ Processed: Warvis (7418/7495)
# ✅ Processed: SwipeTern (7419/7495)
# ✅ Processed: Pioneer (7420/7495)
# ✅ Processed: D1 Laksh (7421/7495)
# ✅ Processed: kitchen_watch (7422/7495)
# ✅ Processed: A Youngster's Guide to Finance (7423/7495)
# ✅ Processed: Temp (7424/7495)
# ✅ Processed: Go Phish (7425/7495)
# ✅ Processed: taskademic (7426/7495)
# ✅ Processed: Red Light Green Light (7427/7495)
# ✅ Processed: Meal Saver (7428/7495)
# ✅ Processed: lol (7429/7495)
# ✅ Processed: LearnWithMelvin (7430/7495)
# ✅ Processed: RealAIs (7431/7495)
# ✅ Processed: Math Mania (7432/7495)
# ✅ Processed: EDUQuest (7433/7495)
# ✅ Processed: AirFair (7434/7495)
# ✅ Processed: DermaSkan (7435/7495)
# ✅ Processed: AeroTrade (American Airlines) (7436/7495)
# ✅ Processed: WealthWise (7437/7495)
# ✅ Processed: Turbulence Predictor (7438/7495)
# ✅ Processed: Fair Fares (7439/7495)
# ✅ Processed: STEM saga (7440/7495)
# ✅ Processed: Away: Air Assistant (7441/7495)
# ✅ Processed: Credit Confidence (7442/7495)
# ✅ Processed: HootPlanner (7443/7495)
# ✅ Processed: KimBOPChronicles (7444/7495)
# ✅ Processed: StudySync (7445/7495)
# ✅ Processed: Pillora (7446/7495)
# ✅ Processed: CodeWithJess.ai (7447/7495)
# ✅ Processed: Shadows of Lumina (7448/7495)
# ✅ Processed: OwlTrack (7449/7495)
# ✅ Processed: Protégé (7450/7495)
# ✅ Processed: Learnix (7451/7495)
# ✅ Processed: NewScribe (7452/7495)
# ✅ Processed: Market Madness (7453/7495)
# ✅ Processed: Capital Connect (7454/7495)
# ✅ Processed: Cybernet Overrun (7455/7495)
# ✅ Processed: Shouternity (7456/7495)
# ✅ Processed: HealthView - Personal Health Record System (7457/7495)
# ✅ Processed: Visi Code (7458/7495)
# ✅ Processed: Moti-vibes (7459/7495)
# ✅ Processed: Market Mentor (7460/7495)
# ✅ Processed: LearnScapes (7461/7495)
# ✅ Processed: Maja (7462/7495)
# ✅ Processed: classbridge (7463/7495)
# ✅ Processed: Easy Finance (7464/7495)
# ✅ Processed: SettleSmart (7465/7495)
# ✅ Processed: HospiTalk (7466/7495)
# ✅ Processed: TutorTap (7467/7495)
# ✅ Processed: OweMe (7468/7495)
# ✅ Processed: :P (7469/7495)
# ✅ Processed: Schedulize (7470/7495)
# ✅ Processed: Melody (7471/7495)
# ✅ Processed: RADish BEETS 'em up (7472/7495)
# ✅ Processed: Cyberswift (7473/7495)
# ✅ Processed: PixelPath (7474/7495)
# ✅ Processed: YouCanReallyDance (7475/7495)
# ✅ Processed: Breefly (7476/7495)
# ✅ Processed: LinkTune (7477/7495)
# ✅ Processed: Owl Health Portal (7478/7495)
# ✅ Processed: VanaAI (7479/7495)
# ✅ Processed: NaviGlance (7480/7495)
# ✅ Processed: AstraRun (7481/7495)
# ✅ Processed: SkinGuard AI (7482/7495)
# ✅ Processed: Feynman Jr (7483/7495)
# ✅ Processed: TaskMatch (7484/7495)
# ✅ Processed: CityQuest (7485/7495)
# ✅ Processed: $pace Tycoon (7486/7495)
# ✅ Processed: EmTag - if you fall (7487/7495)
# ✅ Processed: MindScape (7488/7495)
# ✅ Processed: Blob Rush (7489/7495)
# ✅ Processed: WiseCare (7490/7495)
# ✅ Processed: Degree Map AI (7491/7495)
# ✅ Processed: Money Mania (7492/7495)
# ✅ Processed: AudioAnalyze (7493/7495)
# ✅ Processed: RestoreIO (7494/7495)
# ✅ Processed: MedSure (7495/7495)
# ✅ Saved 7495 detailed projects from All_projects_with_Details to All_projects_with_Details_detailed.csv
#            hackathon_name   project_name  \
# 0     Hack The North 2020     QuaranTime
# 1     Hack The North 2020    FridgeSpace
# 2     Hack The North 2020       helppier
# 3     Hack The North 2020         mashme
# 4     Hack The North 2020   Mall Monitor
# ...                   ...            ...
# 7490     HackRice 14 2024  Degree Map AI
# 7491     HackRice 14 2024    Money Mania
# 7492     HackRice 14 2024   AudioAnalyze
# 7493     HackRice 14 2024      RestoreIO
# 7494     HackRice 14 2024        MedSure
#
#                                            project_link  winner  \
# 0     https://devpost.com/software/boredombuster-hnimzc    True
# 1              https://devpost.com/software/fridgespace    True
# 2          https://devpost.com/software/helppier-k5lbru    True
# 3                   https://devpost.com/software/mashme    True
# 4             https://devpost.com/software/mall-monitor    True
# ...                                                 ...     ...
# 7490     https://devpost.com/software/degree-planner-ai   False
# 7491           https://devpost.com/software/money-mania   False
# 7492   https://devpost.com/software/audioanalyze-muw9zk   False
# 7493            https://devpost.com/software/tbd-ir3qd5   False
# 7494            https://devpost.com/software/tbd-72iomb   False
#
#                                             inspiration  \
# 0     Due to being stuck at home during Quarantine s...
# 1     Based on the observation that most household w...
# 2     Inspired by the newly born solidarity within t...
# 3     We're a team of 'music people' who are in a ba...
# 4     Covid-19 has ravaged the World since early 202...
# ...                                                 ...
# 7490  As current undergraduate students trying to na...
# 7491  Our inspiration for this project was this book...
# 7492  The inspiration behind this project came from ...
# 7493  RestoreIO was created in response to the deman...
# 7494  As young college students, we are often poorly...
#
#                                            what_it_does  \
# 0     QuaranTime is an app where a schedule is gener...
# 1     FridgeSpace allows household users to locate a...
# 2     Helppier's goal is to encourage a new social n...
# 3     mashme allows the user to select two songs, an...
# 4     Mall Monitor allows owners and guests to monit...
# ...                                                 ...
# 7490  Degree Map AI includes a React front-end and a...
# 7491  This game teaches people about personal financ...
# 7492
# 7493
# 7494  Our key features: 1) Simplify the insurance hu...
#
#                                         how_we_built_it  \
# 0     We decided to face a new challenge. Due to the...
# 1     We began by creating designs for our app using...
# 2     In order to build a decentralized network wher...
# 3
# 4
# ...                                                 ...
# 7490  We first started by working on the scraper, fr...
# 7491  We built this in Python using PyGame. We split...
# 7492
# 7493
# 7494  Since we wanted to implement a machine learnin...
#
#                                              challenges  \
# 0     There were many challenges that we faced. One ...
# 1     The biggest challenge we had to face was learn...
# 2     While the developers of the team have experien...
# 3
# 4
# ...                                                 ...
# 7490  One challenge we faced was figuring out the be...
# 7491  None of us have ever participated in a hackath...
# 7492
# 7493
# 7494
#
#                                         accomplishments  \
# 0     We are proud of the ability to use the Google ...
# 1
# 2     We are extremely proud to have been able to de...
# 3
# 4
# ...                                                 ...
# 7490  We're proud to have successfully connected the...
# 7491  We are proud of the fact we have a finished pr...
# 7492
# 7493
# 7494
#
#                                         what_we_learned  \
# 0     We were able to learn much more than expected ...
# 1     There were many new technologies we learned in...
# 2
# 3
# 4
# ...                                                 ...
# 7490  We learned to set up OpenAI's ChatGPT, scrape ...
# 7491  We learned that creating a layout in PyGame is...
# 7492
# 7493
# 7494
#
#                                              next_steps  \
# 0     If we had more time, we would add features suc...
# 1     Future Steps for our team include working with...
# 2
# 3     ML training for chorus and verse separation! C...
# 4     Actually deploying and consuming the REST API ...
# ...                                                 ...
# 7490  Given the limited amount of time, we were only...
# 7491  Money Mania will have expansions in the invest...
# 7492
# 7493
# 7494
#
#                                              built_with  \
# 0                             dart, flutter, googleapis
# 1     cockroachdb, flask, python, sqlalchemy, swift,...
# 2     azure, blockchain, cockroach.db, css3, express...
# 3     bootstrap, domain.com, flask, google-compute-e...
# 4     angular.js, azure, css, flask, html, javascrip...
# ...                                                 ...
# 7490    c++, javascript, openai, pyflask, python, react
# 7491                                     pygame, python
# 7492  ai, generative, lambda-(for-serverless-process...
# 7493  ai, computer, computervision, love, mediapipe,...
# 7494                   mapbox, python, typescript, vite
#
#                                          external_links
# 0     https://github.com/JackFrostDJ/HTN-App/tree/ma...
# 1               https://github.com/Harin329/FridgeSpace
# 2     https://github.com/aminecs/magic4, https://www...
# 3                                    http://mashme.tech
# 4     https://github.com/RemeAjayi/mall-monitor, htt...
# ...                                                 ...
# 7490          https://github.com/april2546/HackRice2024
# 7491          https://github.com/ashwinrao1/Hackathon24
# 7492      https://github.com/Ayush374/Ai_Audio_Analysis
# 7493  https://github.com/OfficialCodeVoyage/HackRice...
# 7494            https://github.com/leon934/hackrice2425
#
# [7495 rows x 13 columns]
