# %%
import pandas as pd
df = pd.read_csv("All_data.csv")
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df
# Out:
#         hackathon_name                       project_name  \
# 0       Cal Hacks 10.0                         Audiogroph
# 1       Cal Hacks 10.0                         Let It Out
# 2       Cal Hacks 10.0                      Mood Theremin
# 3       Cal Hacks 10.0  Bay Area Safer Housing (B.A.S.H.)
# 4       Cal Hacks 10.0                            PawPals
# ...                ...                                ...
# 6912  HackRice 14 2024                      Degree Map AI
# 6913  HackRice 14 2024                        Money Mania
# 6914  HackRice 14 2024                       AudioAnalyze
# 6915  HackRice 14 2024                          RestoreIO
# 6916  HackRice 14 2024                            MedSure
#
#                                            project_link  is_winner  \
# 0               https://devpost.com/software/audiogroph      False
# 1        https://devpost.com/software/let-it-out-b2xp8u      False
# 2            https://devpost.com/software/mood-theremin      False
# 3     https://devpost.com/software/bay-area-safer-ho...      False
# 4           https://devpost.com/software/pawpals-bd8njs      False
# ...                                                 ...        ...
# 6912     https://devpost.com/software/degree-planner-ai      False
# 6913           https://devpost.com/software/money-mania      False
# 6914   https://devpost.com/software/audioanalyze-muw9zk      False
# 6915            https://devpost.com/software/tbd-ir3qd5      False
# 6916            https://devpost.com/software/tbd-72iomb      False
#
#                                             inspiration  \
# 0     With covid ending and people finding new music...
# 1     Understanding and expressing emotions can be a...
# 2     The theremin, an electronic musical instrument...
# 3     The inspiration initially stems from one membe...
# 4     As college students, we both agreed that fun t...
# ...                                                 ...
# 6912  As current undergraduate students trying to na...
# 6913  Our inspiration for this project was this book...
# 6914  The inspiration behind this project came from ...
# 6915  RestoreIO was created in response to the deman...
# 6916  As young college students, we are often poorly...
#
#                                            what_it_does  \
# 0     The project shows events, creators and any NFT...
# 1     The user is first prompted to record a vocal b...
# 2     Mood Theremin translates your facial expressio...
# 3     B.A.S.H. searches for affordable housing optio...
# 4     Based on a list of criteria, we prompt OpenAI'...
# ...                                                 ...
# 6912  Degree Map AI includes a React front-end and a...
# 6913  This game teaches people about personal financ...
# 6914                                                NaN
# 6915                                                NaN
# 6916  Our key features: 1) Simplify the insurance hu...
#
#                                         how_we_built_it  \
# 0     We used react to build it in vscode and collab...
# 1     Let It Out is a full stack web app. The front ...
# 2     Our project integrates facial expression analy...
# 3     Our website's foundation was built on next.js ...
# 4     On the front-end, we utilized Figma to develop...
# ...                                                 ...
# 6912  We first started by working on the scraper, fr...
# 6913  We built this in Python using PyGame. We split...
# 6914                                                NaN
# 6915                                                NaN
# 6916  Since we wanted to implement a machine learnin...
#
#                                              challenges  \
# 0     We had to learn react and navigate through git...
# 1     The main challenges we ran into came in our fi...
# 2                                                   NaN
# 3     Our difficulties lay in our inexperience with ...
# 4     Some challenges we ran into were the lack of e...
# ...                                                 ...
# 6912  One challenge we faced was figuring out the be...
# 6913  None of us have ever participated in a hackath...
# 6914                                                NaN
# 6915                                                NaN
# 6916                                                NaN
#
#                                         accomplishments  \
# 0     We have successfully built the frontend of the...
# 1                                                   NaN
# 2                                                   NaN
# 3     Conceptually, we believe that our project is m...
# 4     As a team of two, we were very proud of our fi...
# ...                                                 ...
# 6912  We're proud to have successfully connected the...
# 6913  We are proud of the fact we have a finished pr...
# 6914                                                NaN
# 6915                                                NaN
# 6916                                                NaN
#
#                                         what_we_learned  \
# 0     Start planning earlier and commit to branches ...
# 1     We learned how to integrate modern technologie...
# 2                                                   NaN
# 3     We've learned most importantly how to better a...
# 4     We learned the value of coming up with a plan ...
# ...                                                 ...
# 6912  We learned to set up OpenAI's ChatGPT, scrape ...
# 6913  We learned that creating a layout in PyGame is...
# 6914                                                NaN
# 6915                                                NaN
# 6916                                                NaN
#
#                                              tech_stack  \
# 0                     We need a backend to our project.
# 1                                                   NaN
# 2                                                   NaN
# 3     We are serious in our project and are intent o...
# 4     We hope to deploy the site on Vercel and devel...
# ...                                                 ...
# 6912    c++, javascript, openai, pyflask, python, react
# 6913                                     pygame, python
# 6914  ai, generative, lambda-(for-serverless-process...
# 6915  ai, computer, computervision, love, mediapipe,...
# 6916                   mapbox, python, typescript, vite
#
#                                          external_links  \
# 0                        css3, html5, javascript, react
# 1     chakra, flask, hume, mongodb, node.js, openai,...
# 2     css, flask, html, hume, javascript, json, pyth...
# 3     catalog.data.gov, data.sfgov.org, google-maps,...
# 4      fastapi, figma, openai, python, react.js, sqlite
# ...                                                 ...
# 6912      ['https://github.com/april2546/HackRice2024']
# 6913      ['https://github.com/ashwinrao1/Hackathon24']
# 6914  ['https://github.com/Ayush374/Ai_Audio_Analysis']
# 6915  ['https://github.com/OfficialCodeVoyage/HackRi...
# 6916        ['https://github.com/leon934/hackrice2425']
#
#                                            github_links  \
# 0      ['https://github.com/RyanGertz/CalHacksproject']
# 1     ['https://github.com/apolyeti/calhacks10.0,', ...
# 2         ['https://github.com/Sepulchre49/CalHacks23']
# 3           ['https://github.com/matthewaol/b.a.s.h.,']
# 4                  ['https://github.com/Yatsz/PawPals']
# ...                                                 ...
# 6912      ['https://github.com/april2546/HackRice2024']
# 6913      ['https://github.com/ashwinrao1/Hackathon24']
# 6914  ['https://github.com/Ayush374/Ai_Audio_Analysis']
# 6915  ['https://github.com/OfficialCodeVoyage/HackRi...
# 6916        ['https://github.com/leon934/hackrice2425']
#
#                                          github_summary  \
# 0      ['https://github.com/RyanGertz/CalHacksproject']
# 1          ['https://github.com/apolyeti/calhacks10.0']
# 2         ['https://github.com/Sepulchre49/CalHacks23']
# 3            ['https://github.com/matthewaol/b.a.s.h.']
# 4                  ['https://github.com/Yatsz/PawPals']
# ...                                                 ...
# 6912  The HackRice2024-DegreeMapAI project is an inn...
# 6913  The Hackathon24 project is a "Personal Finance...
# 6914  The GitHub repository "Ai_Audio_Analysis" is d...
# 6915  The GitHub repository "HackRice14_RecoveryIO,"...
# 6916  The `hackrice2425` project, titled "Insurance ...
#
#                                            what_is_next
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6912  Given the limited amount of time, we were only...
# 6913  Money Mania will have expansions in the invest...
# 6914                                                NaN
# 6915                                                NaN
# 6916                                                NaN
#
# [6917 rows x 15 columns]

# %%
# Only these text columns should be merged
text_cols = [
    'inspiration', 
    'what_it_does', 
    'how_we_built_it', 
    'challenges', 
    'accomplishments', 
    'what_we_learned',
    'what_is_next',
    'tech_stack'
]

# Combine selected columns into one text column
df['all_text'] = df[text_cols].astype(str).apply(lambda x: ' '.join(x), axis=1)

# Clean up text (remove 'nan', brackets, double spaces)
df['all_text'] = (
    df['all_text']
    .str.replace(r"\bnan\b", "", regex=True)
    .str.replace(r"\s+", " ", regex=True)
    .str.strip()
)
df = df[['is_winner', 'github_summary', 'all_text']]
df
# Out:
#       is_winner                                     github_summary  \
# 0         False   ['https://github.com/RyanGertz/CalHacksproject']
# 1         False       ['https://github.com/apolyeti/calhacks10.0']
# 2         False      ['https://github.com/Sepulchre49/CalHacks23']
# 3         False         ['https://github.com/matthewaol/b.a.s.h.']
# 4         False               ['https://github.com/Yatsz/PawPals']
# ...         ...                                                ...
# 6912      False  The HackRice2024-DegreeMapAI project is an inn...
# 6913      False  The Hackathon24 project is a "Personal Finance...
# 6914      False  The GitHub repository "Ai_Audio_Analysis" is d...
# 6915      False  The GitHub repository "HackRice14_RecoveryIO,"...
# 6916      False  The `hackrice2425` project, titled "Insurance ...
#
#                                                all_text
# 0     With covid ending and people finding new music...
# 1     Understanding and expressing emotions can be a...
# 2     The theremin, an electronic musical instrument...
# 3     The inspiration initially stems from one membe...
# 4     As college students, we both agreed that fun t...
# ...                                                 ...
# 6912  As current undergraduate students trying to na...
# 6913  Our inspiration for this project was this book...
# 6914  The inspiration behind this project came from ...
# 6915  RestoreIO was created in response to the deman...
# 6916  As young college students, we are often poorly...
#
# [6917 rows x 3 columns]
