# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification, Trainer, TrainingArguments
from datasets import Dataset
import evaluate
import torch
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# W1103 08:46:09.312000 1430 site-packages/torch/distributed/elastic/multiprocessing/redirects.py:29] NOTE: Redirects are currently not supported in Windows or MacOs.

# %%
df = pd.read_csv("analysis_dataset.csv")
df = df.loc[:, ~df.columns.str.contains("^Unnamed")]
# Only these text columns should be merged
text_cols = [
    'inspiration', 
    'what_it_does', 
    'how_we_built_it', 
    'challenges', 
    'accomplishments', 
    'what_we_learned',
    'what_is_next',
    'tech_stack'
]

# Combine selected columns into one text column
df['all_text'] = df[text_cols].astype(str).apply(lambda x: ' '.join(x), axis=1)

# Clean up text (remove 'nan', brackets, double spaces)
df['all_text'] = (
    df['all_text']
    .str.replace(r"\bnan\b", "", regex=True)
    .str.replace(r"\s+", " ", regex=True)
    .str.strip()
)
# Drop rows with missing values (optional)
df_ml = df.dropna(subset=['github_summary', 'all_text'])
df_ml['text'] = df_ml['github_summary'] + ' ' + df_ml['all_text']
df_ml['label'] = df_ml['is_winner'].astype(int)
df_ml
# Out:
#         hackathon_name                       project_name  \
# 0       Cal Hacks 10.0                         Audiogroph
# 1       Cal Hacks 10.0                         Let It Out
# 2       Cal Hacks 10.0                      Mood Theremin
# 3       Cal Hacks 10.0  Bay Area Safer Housing (B.A.S.H.)
# 4       Cal Hacks 10.0                            PawPals
# ...                ...                                ...
# 6347  HackRice 14 2024                      Degree Map AI
# 6348  HackRice 14 2024                        Money Mania
# 6349  HackRice 14 2024                       AudioAnalyze
# 6350  HackRice 14 2024                          RestoreIO
# 6351  HackRice 14 2024                            MedSure
#
#                                            project_link  is_winner  \
# 0               https://devpost.com/software/audiogroph      False
# 1        https://devpost.com/software/let-it-out-b2xp8u      False
# 2            https://devpost.com/software/mood-theremin      False
# 3     https://devpost.com/software/bay-area-safer-ho...      False
# 4           https://devpost.com/software/pawpals-bd8njs      False
# ...                                                 ...        ...
# 6347     https://devpost.com/software/degree-planner-ai      False
# 6348           https://devpost.com/software/money-mania      False
# 6349   https://devpost.com/software/audioanalyze-muw9zk      False
# 6350            https://devpost.com/software/tbd-ir3qd5      False
# 6351            https://devpost.com/software/tbd-72iomb      False
#
#                                             inspiration  \
# 0     With covid ending and people finding new music...
# 1     Understanding and expressing emotions can be a...
# 2     The theremin, an electronic musical instrument...
# 3     The inspiration initially stems from one membe...
# 4     As college students, we both agreed that fun t...
# ...                                                 ...
# 6347  As current undergraduate students trying to na...
# 6348  Our inspiration for this project was this book...
# 6349  The inspiration behind this project came from ...
# 6350  RestoreIO was created in response to the deman...
# 6351  As young college students, we are often poorly...
#
#                                            what_it_does  \
# 0     The project shows events, creators and any NFT...
# 1     The user is first prompted to record a vocal b...
# 2     Mood Theremin translates your facial expressio...
# 3     B.A.S.H. searches for affordable housing optio...
# 4     Based on a list of criteria, we prompt OpenAI'...
# ...                                                 ...
# 6347  Degree Map AI includes a React front-end and a...
# 6348  This game teaches people about personal financ...
# 6349                                                NaN
# 6350                                                NaN
# 6351  Our key features: 1) Simplify the insurance hu...
#
#                                         how_we_built_it  \
# 0     We used react to build it in vscode and collab...
# 1     Let It Out is a full stack web app. The front ...
# 2     Our project integrates facial expression analy...
# 3     Our website's foundation was built on next.js ...
# 4     On the front-end, we utilized Figma to develop...
# ...                                                 ...
# 6347  We first started by working on the scraper, fr...
# 6348  We built this in Python using PyGame. We split...
# 6349                                                NaN
# 6350                                                NaN
# 6351  Since we wanted to implement a machine learnin...
#
#                                              challenges  \
# 0     We had to learn react and navigate through git...
# 1     The main challenges we ran into came in our fi...
# 2                                                   NaN
# 3     Our difficulties lay in our inexperience with ...
# 4     Some challenges we ran into were the lack of e...
# ...                                                 ...
# 6347  One challenge we faced was figuring out the be...
# 6348  None of us have ever participated in a hackath...
# 6349                                                NaN
# 6350                                                NaN
# 6351                                                NaN
#
#                                         accomplishments  \
# 0     We have successfully built the frontend of the...
# 1                                                   NaN
# 2                                                   NaN
# 3     Conceptually, we believe that our project is m...
# 4     As a team of two, we were very proud of our fi...
# ...                                                 ...
# 6347  We're proud to have successfully connected the...
# 6348  We are proud of the fact we have a finished pr...
# 6349                                                NaN
# 6350                                                NaN
# 6351                                                NaN
#
#                                         what_we_learned  \
# 0     Start planning earlier and commit to branches ...
# 1     We learned how to integrate modern technologie...
# 2                                                   NaN
# 3     We've learned most importantly how to better a...
# 4     We learned the value of coming up with a plan ...
# ...                                                 ...
# 6347  We learned to set up OpenAI's ChatGPT, scrape ...
# 6348  We learned that creating a layout in PyGame is...
# 6349                                                NaN
# 6350                                                NaN
# 6351                                                NaN
#
#                                            what_is_next  \
# 0                     We need a backend to our project.
# 1                                                   NaN
# 2                                                   NaN
# 3     We are serious in our project and are intent o...
# 4     We hope to deploy the site on Vercel and devel...
# ...                                                 ...
# 6347  Given the limited amount of time, we were only...
# 6348  Money Mania will have expansions in the invest...
# 6349                                                NaN
# 6350                                                NaN
# 6351                                                NaN
#
#                                              tech_stack  \
# 0                        css3, html5, javascript, react
# 1     chakra, flask, hume, mongodb, node.js, openai,...
# 2     css, flask, html, hume, javascript, json, pyth...
# 3     catalog.data.gov, data.sfgov.org, google-maps,...
# 4      fastapi, figma, openai, python, react.js, sqlite
# ...                                                 ...
# 6347    c++, javascript, openai, pyflask, python, react
# 6348                                     pygame, python
# 6349  ai, generative, lambda-(for-serverless-process...
# 6350  ai, computer, computervision, love, mediapipe,...
# 6351                   mapbox, python, typescript, vite
#
#                                          external_links  \
# 0      ['https://github.com/RyanGertz/CalHacksproject']
# 1     ['https://github.com/apolyeti/calhacks10.0,', ...
# 2         ['https://github.com/Sepulchre49/CalHacks23']
# 3           ['https://github.com/matthewaol/b.a.s.h.,']
# 4                  ['https://github.com/Yatsz/PawPals']
# ...                                                 ...
# 6347      ['https://github.com/april2546/HackRice2024']
# 6348      ['https://github.com/ashwinrao1/Hackathon24']
# 6349  ['https://github.com/Ayush374/Ai_Audio_Analysis']
# 6350  ['https://github.com/OfficialCodeVoyage/HackRi...
# 6351        ['https://github.com/leon934/hackrice2425']
#
#                                            github_links  \
# 0      ['https://github.com/RyanGertz/CalHacksproject']
# 1          ['https://github.com/apolyeti/calhacks10.0']
# 2         ['https://github.com/Sepulchre49/CalHacks23']
# 3            ['https://github.com/matthewaol/b.a.s.h.']
# 4                  ['https://github.com/Yatsz/PawPals']
# ...                                                 ...
# 6347      ['https://github.com/april2546/HackRice2024']
# 6348      ['https://github.com/ashwinrao1/Hackathon24']
# 6349  ['https://github.com/Ayush374/Ai_Audio_Analysis']
# 6350  ['https://github.com/OfficialCodeVoyage/HackRi...
# 6351        ['https://github.com/leon934/hackrice2425']
#
#                                          github_summary  \
# 0     The GitHub repository, "CalHacksproject," is a...
# 1     This repository, named `calhacks10.0`, serves ...
# 2     The Mood-Theremin repository details a CalHack...
# 3     b.a.s.h. (Bay Area Safer Housing) is a CalHack...
# 4     This analysis summarizes the GitHub repository...
# ...                                                 ...
# 6347  The HackRice2024-DegreeMapAI project is an inn...
# 6348  The Hackathon24 project is a "Personal Finance...
# 6349  The GitHub repository "Ai_Audio_Analysis" is d...
# 6350  The GitHub repository "HackRice14_RecoveryIO,"...
# 6351  The `hackrice2425` project, titled "Insurance ...
#
#                                                all_text  \
# 0     With covid ending and people finding new music...
# 1     Understanding and expressing emotions can be a...
# 2     The theremin, an electronic musical instrument...
# 3     The inspiration initially stems from one membe...
# 4     As college students, we both agreed that fun t...
# ...                                                 ...
# 6347  As current undergraduate students trying to na...
# 6348  Our inspiration for this project was this book...
# 6349  The inspiration behind this project came from ...
# 6350  RestoreIO was created in response to the deman...
# 6351  As young college students, we are often poorly...
#
#                                                    text  label
# 0     The GitHub repository, "CalHacksproject," is a...      0
# 1     This repository, named `calhacks10.0`, serves ...      0
# 2     The Mood-Theremin repository details a CalHack...      0
# 3     b.a.s.h. (Bay Area Safer Housing) is a CalHack...      0
# 4     This analysis summarizes the GitHub repository...      0
# ...                                                 ...    ...
# 6347  The HackRice2024-DegreeMapAI project is an inn...      0
# 6348  The Hackathon24 project is a "Personal Finance...      0
# 6349  The GitHub repository "Ai_Audio_Analysis" is d...      0
# 6350  The GitHub repository "HackRice14_RecoveryIO,"...      0
# 6351  The `hackrice2425` project, titled "Insurance ...      0
#
# [6352 rows x 18 columns]

# %%
# Sample 1000 True and 1000 False examples randomly
df_true = df_ml[df_ml['is_winner'] == True].sample(n=1000, random_state=42)
df_false = df_ml[df_ml['is_winner'] == False].sample(n=1000, random_state=42)
df_balanced = pd.concat([df_true, df_false]).sample(frac=1, random_state=42).reset_index(drop=True)
df_balanced['is_winner'].value_counts()
# Out:
# is_winner
# False    1000
# True     1000
# Name: count, dtype: int64

# %%
df_balanced
# Out:
#            hackathon_name            project_name  \
# 0     Hack The North 2020                 SitDown
# 1         ShellHacks 2024              Med-Memory
# 2                HackGT X              Songlation
# 3            HackPSU 2020  Crisis Management Tool
# 4     Hack The North 2021              Wanderlust
# ...                   ...                     ...
# 1995       Hack&Roll 2021                LuminDER
# 1996        HackNJIT 2024               QuickTeam
# 1997       TreeHacks 2024                  3dReal
# 1998      VTHacks 12 2024           Schedule Eatz
# 1999       TreeHacks 2023             Genie Tutor
#
#                                            project_link  is_winner  \
# 0           https://devpost.com/software/sitdown-hbjvmp      False
# 1               https://devpost.com/software/med-memory       True
# 2               https://devpost.com/software/songlation      False
# 3     https://devpost.com/software/medchain-response...       True
# 4        https://devpost.com/software/wanderlust-ityjl6      False
# ...                                                 ...        ...
# 1995              https://devpost.com/software/luminder      False
# 1996             https://devpost.com/software/quickteam      False
# 1997                https://devpost.com/software/3dreal       True
# 1998         https://devpost.com/software/schedule-eatz      False
# 1999           https://devpost.com/software/genie-tutor      False
#
#                                             inspiration  \
# 0     With the spread of COVID-19, remote work has b...
# 1     Introducing Med-Memory: your fast-track soluti...
# 2     Our group members all had different passions a...
# 3     Medical Health Organization is not adequately ...
# 4     Recently, 3 members of the Wanderlust team had...
# ...                                                 ...
# 1995  Inspired by VSinder, we combined elements of L...
# 1996  Finding team is a difficult process where dive...
# 1997  Metaverse, vision pro, spatial video. It’s no ...
# 1998     As college students, we bear a lot more respon
# 1999  Everyday students file into their classrooms w...
#
#                                            what_it_does  \
# 0     SitDown is a mobile app designed to make emplo...
# 1     Med-Memory transforms overwhelming medical rep...
# 2     The user can choose the language and genre of ...
# 3     So Med-Chain Crisis Management is a tool not j...
# 4     Wanderlust is an application where users can c...
# ...                                                 ...
# 1995  LuminDER is a dating app for NUS students that...
# 1996                                                NaN
# 1997  With just a few images, the AI powered Neural ...
# 1998  Recommends the best times to go and pick up fo...
# 1999  Genie Tutor collects individual student exam d...
#
#                                         how_we_built_it  \
# 0     We used Flutter and Dart for front end, and Fi...
# 1     We built Med-Memory with a Node.js (Express.js...
# 2     We built a full-stack software that uses React...
# 3                                        It has 3 parts
# 4     We built it using React JS, and for the UI com...
# ...                                                 ...
# 1995  We used the MERN stack (Mongo, Express, React,...
# 1996                                                NaN
# 1997                                                NaN
# 1998  We used a Google Maps API through APIfy to loc...
# 1999  Together, we developed an algorithm that analy...
#
#                                              challenges  \
# 0     Our team had a lot of trouble with Git version...
# 1     Training the Qwen 2.5 LLM to understand specif...
# 2     While each of us have our own individual stren...
# 3     Finding the proper dataset that will provide a...
# 4     The biggest challenge we ran into was being ab...
# ...                                                 ...
# 1995  Team was inexperienced with web development, u...
# 1996                                                NaN
# 1997  We lost our iOS developer team member right be...
# 1998  The biggest challenge we ran into was properly...
# 1999  It is important for us that the product is acc...
#
#                                         accomplishments  \
# 0     It was the first time for all our team members...
# 1     Successfully integrating the AI model into the...
# 2                                                   NaN
# 3     Decision Trees Model, Linear Regression Model,...
# 4     With the time given, we were able to get a ful...
# ...                                                 ...
# 1995  Setting up the entire project base from scratc...
# 1996                                                NaN
# 1997  Working final product and getting it done in t...
# 1998                                                NaN
# 1999  Genie Tutor highlights the rudimentary ideas b...
#
#                                         what_we_learned  \
# 0                                                   NaN
# 1     We gained experience working with Next.js, Fir...
# 2                                                   NaN
# 3     How is the current scenario of Pennsylvania St...
# 4     We all started off with little to no knowledge...
# ...                                                 ...
# 1995  Project setup and structuring, web development...
# 1996                                                NaN
# 1997  A LOT of things out of all our comfort zones -...
# 1998                                                NaN
# 1999  Throughout the process of building the project...
#
#                                            what_is_next  \
# 0     Going forward we’d love to incorporate more fe...
# 1     We plan to deploy the fine-tuned model at scal...
# 2     Songlation can easily add so many language-lea...
# 3     Not just limit is to one state but expand it c...
# 4     The next steps include potentially turning it ...
# ...                                                 ...
# 1995  Make the chat real-time using web sockets and ...
# 1996                                                NaN
# 1997  We would love to refine the user experience an...
# 1998                                                NaN
# 1999  In our future endeavors, we are looking to ref...
#
#                                              tech_stack  \
# 0                        dart, figma, firebase, flutter
# 1     express.js, firebase, next, node.js, ollama, r...
# 2     ai, flask, google, google-cloud, javascript, p...
# 3     covid-pa-counties.csv, decisiontreeregressor, ...
# 4     firebase, firestore, html/css/javascript, mate...
# ...                                                 ...
# 1995  bootstrap, css, express.js, firebase, html, ja...
# 1996                            dart, firebase, flutter
# 1997           ai, figma, firebase, nerf, nvidia, xcode
# 1998         css, html, java, javascript, maven, python
# 1999                                       gpt3, python
#
#                                          external_links  \
# 0             ['https://github.com/HTN-2020/repo-sit,']
# 1        ['https://github.com/ashendre1/med-memory-v2']
# 2             ['https://github.com/AnanyaKakaveti/GTX']
# 3        ['https://github.com/kalpP/MedChain_HackPSU,']
# 4     ['https://github.com/kavyaarun11/wanderlust-htn']
# ...                                                 ...
# 1995           ['https://github.com/Nanosync/luminder']
# 1996  ['https://github.com/DavidTraitz/QuickTeam/tre...
# 1997          ['https://github.com/alexkranias/3dReal']
# 1998       ['https://github.com/Shakyy-Hands/FoodPlan']
# 1999     ['https://github.com/Alhassan777/Genie-Tutor']
#
#                                            github_links  \
# 0              ['https://github.com/HTN-2020/repo-sit']
# 1        ['https://github.com/ashendre1/med-memory-v2']
# 2             ['https://github.com/AnanyaKakaveti/GTX']
# 3         ['https://github.com/kalpP/MedChain_HackPSU']
# 4     ['https://github.com/kavyaarun11/wanderlust-htn']
# ...                                                 ...
# 1995           ['https://github.com/Nanosync/luminder']
# 1996  ['https://github.com/DavidTraitz/QuickTeam/tre...
# 1997          ['https://github.com/alexkranias/3dReal']
# 1998       ['https://github.com/Shakyy-Hands/FoodPlan']
# 1999     ['https://github.com/Alhassan777/Genie-Tutor']
#
#                                          github_summary  \
# 0     The GitHub repository, `repo-sit`, hosts a cro...
# 1     This analysis provides a comprehensive overvie...
# 2     The GitHub repository, named GTX, presents as ...
# 3     This repository, named MedChain_HackPSU, detai...
# 4     The `wanderlust-htn` repository hosts Wanderlu...
# ...                                                 ...
# 1995  The `luminder` repository contains a dating ap...
# 1996  The GitHub repository "QuickTeam" presents its...
# 1997  The `3dReal` GitHub repository appears to be a...
# 1998  This analysis provides a comprehensive overvie...
# 1999  The Genie-Tutor project is an innovative Pytho...
#
#                                                all_text  \
# 0     With the spread of COVID-19, remote work has b...
# 1     Introducing Med-Memory: your fast-track soluti...
# 2     Our group members all had different passions a...
# 3     Medical Health Organization is not adequately ...
# 4     Recently, 3 members of the Wanderlust team had...
# ...                                                 ...
# 1995  Inspired by VSinder, we combined elements of L...
# 1996  Finding team is a difficult process where dive...
# 1997  Metaverse, vision pro, spatial video. It’s no ...
# 1998  As college students, we bear a lot more respon...
# 1999  Everyday students file into their classrooms w...
#
#                                                    text  label
# 0     The GitHub repository, `repo-sit`, hosts a cro...      0
# 1     This analysis provides a comprehensive overvie...      1
# 2     The GitHub repository, named GTX, presents as ...      0
# 3     This repository, named MedChain_HackPSU, detai...      1
# 4     The `wanderlust-htn` repository hosts Wanderlu...      0
# ...                                                 ...    ...
# 1995  The `luminder` repository contains a dating ap...      0
# 1996  The GitHub repository "QuickTeam" presents its...      0
# 1997  The `3dReal` GitHub repository appears to be a...      1
# 1998  This analysis provides a comprehensive overvie...      0
# 1999  The Genie-Tutor project is an innovative Pytho...      0
#
# [2000 rows x 18 columns]

# %%
from datasets import ClassLabel, Dataset

# Hugging Face Dataset
dataset = Dataset.from_pandas(df_balanced[['text', 'label']])
dataset = dataset.cast_column("label", ClassLabel(num_classes=2))
dataset
# Out:
# Casting the dataset:   0%|          | 0/2000 [00:00<?, ? examples/s]
# Dataset({
#     features: ['text', 'label'],
#     num_rows: 2000
# })

# %%
# Split into train/test (stratified)
dataset = dataset.train_test_split(test_size=0.2, stratify_by_column='label', seed=42)
train_dataset = dataset['train']
test_dataset = dataset['test']
train_dataset
# Out:
# Dataset({
#     features: ['text', 'label'],
#     num_rows: 1600
# })

# %%
test_dataset
# Out:
# Dataset({
#     features: ['text', 'label'],
#     num_rows: 400
# })

# %%
model_name = "distilbert-base-uncased"  # smaller, faster BERT variant
tokenizer = AutoTokenizer.from_pretrained(model_name)

def tokenize(batch):
    return tokenizer(batch['text'], padding='max_length', truncation=True, max_length=256)

train_dataset = train_dataset.map(tokenize, batched=True)
test_dataset = test_dataset.map(tokenize, batched=True)

# Tell HF which columns to use
train_dataset.set_format(type='torch', columns=['input_ids', 'attention_mask', 'label'])
test_dataset.set_format(type='torch', columns=['input_ids', 'attention_mask', 'label'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/huggingface_hub/file_download.py:945: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Map:   0%|          | 0/1600 [00:00<?, ? examples/s]
# Map:   0%|          | 0/400 [00:00<?, ? examples/s]

# %%
model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=2)
model
# Out:
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# DistilBertForSequenceClassification(
#   (distilbert): DistilBertModel(
#     (embeddings): Embeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (transformer): Transformer(
#       (layer): ModuleList(
#         (0-5): 6 x TransformerBlock(
#           (attention): MultiHeadSelfAttention(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (q_lin): Linear(in_features=768, out_features=768, bias=True)
#             (k_lin): Linear(in_features=768, out_features=768, bias=True)
#             (v_lin): Linear(in_features=768, out_features=768, bias=True)
#             (out_lin): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (sa_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (ffn): FFN(
#             (dropout): Dropout(p=0.1, inplace=False)
#             (lin1): Linear(in_features=768, out_features=3072, bias=True)
#             (lin2): Linear(in_features=3072, out_features=768, bias=True)
#             (activation): GELUActivation()
#           )
#           (output_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (pre_classifier): Linear(in_features=768, out_features=768, bias=True)
#   (classifier): Linear(in_features=768, out_features=2, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# )

# %%
#Model import success

# %%
accuracy = evaluate.load("accuracy")
accuracy
# Out:
# EvaluationModule(name: "accuracy", module_type: "metric", features: {'predictions': Value(dtype='int32', id=None), 'references': Value(dtype='int32', id=None)}, usage: """
# Args:
#     predictions (`list` of `int`): Predicted labels.
#     references (`list` of `int`): Ground truth labels.
#     normalize (`boolean`): If set to False, returns the number of correctly classified samples. Otherwise, returns the fraction of correctly classified samples. Defaults to True.
#     sample_weight (`list` of `float`): Sample weights Defaults to None.
#
# Returns:
#     accuracy (`float` or `int`): Accuracy score. Minimum possible value is 0. Maximum possible value is 1.0, or the number of examples input, if `normalize` is set to `True`.. A higher score means higher accuracy.
#
# Examples:
#
#     Example 1-A simple example
#         >>> accuracy_metric = evaluate.load("accuracy")
#         >>> results = accuracy_metric.compute(references=[0, 1, 2, 0, 1, 2], predictions=[0, 1, 1, 2, 1, 0])
#         >>> print(results)
#         {'accuracy': 0.5}
#
#     Example 2-The same as Example 1, except with `normalize` set to `False`.
#         >>> accuracy_metric = evaluate.load("accuracy")
#         >>> results = accuracy_metric.compute(references=[0, 1, 2, 0, 1, 2], predictions=[0, 1, 1, 2, 1, 0], normalize=False)
#         >>> print(results)
#         {'accuracy': 3.0}
#
#     Example 3-The same as Example 1, except with `sample_weight` set.
#         >>> accuracy_metric = evaluate.load("accuracy")
#         >>> results = accuracy_metric.compute(references=[0, 1, 2, 0, 1, 2], predictions=[0, 1, 1, 2, 1, 0], sample_weight=[0.5, 2, 0.7, 0.5, 9, 0.4])
#         >>> print(results)
#         {'accuracy': 0.8778625954198473}
# """, stored examples: 0)

# %%
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = torch.argmax(torch.tensor(logits), dim=-1)
    return accuracy.compute(predictions=predictions, references=labels)

# %%
training_args = TrainingArguments(
    output_dir="./bert_hackathon_model",
    evaluation_strategy="epoch",
    save_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    num_train_epochs=3,
    weight_decay=0.01,
    load_best_model_at_end=True,
    metric_for_best_model="recall",
    logging_dir="./logs",
    logging_steps=50,
)
training_args
# Out:
# TrainingArguments(
# _n_gpu=1,
# accelerator_config={'split_batches': False, 'dispatch_batches': None, 'even_batches': True, 'use_seedable_sampler': True, 'gradient_accumulation_kwargs': None},
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# auto_find_batch_size=False,
# bf16=False,
# bf16_full_eval=False,
# data_seed=None,
# dataloader_drop_last=False,
# dataloader_num_workers=0,
# dataloader_persistent_workers=False,
# dataloader_pin_memory=True,
# dataloader_prefetch_factor=None,
# ddp_backend=None,
# ddp_broadcast_buffers=None,
# ddp_bucket_cap_mb=None,
# ddp_find_unused_parameters=None,
# ddp_timeout=1800,
# debug=[],
# deepspeed=None,
# disable_tqdm=False,
# dispatch_batches=None,
# do_eval=True,
# do_predict=False,
# do_train=False,
# eval_accumulation_steps=None,
# eval_delay=0,
# eval_do_concat_batches=True,
# eval_steps=None,
# evaluation_strategy=IntervalStrategy.EPOCH,
# fp16=False,
# fp16_backend=auto,
# fp16_full_eval=False,
# fp16_opt_level=O1,
# fsdp=[],
# fsdp_config={'min_num_params': 0, 'xla': False, 'xla_fsdp_v2': False, 'xla_fsdp_grad_ckpt': False},
# fsdp_min_num_params=0,
# fsdp_transformer_layer_cls_to_wrap=None,
# full_determinism=False,
# gradient_accumulation_steps=1,
# gradient_checkpointing=False,
# gradient_checkpointing_kwargs=None,
# greater_is_better=True,
# group_by_length=False,
# half_precision_backend=auto,
# hub_always_push=False,
# hub_model_id=None,
# hub_private_repo=False,
# hub_strategy=HubStrategy.EVERY_SAVE,
# hub_token=<HUB_TOKEN>,
# ignore_data_skip=False,
# include_inputs_for_metrics=False,
# include_num_input_tokens_seen=False,
# include_tokens_per_second=False,
# jit_mode_eval=False,
# label_names=None,
# label_smoothing_factor=0.0,
# learning_rate=2e-05,
# length_column_name=length,
# load_best_model_at_end=True,
# local_rank=0,
# log_level=passive,
# log_level_replica=warning,
# log_on_each_node=True,
# logging_dir=./logs,
# logging_first_step=False,
# logging_nan_inf_filter=True,
# logging_steps=50,
# logging_strategy=IntervalStrategy.STEPS,
# lr_scheduler_kwargs={},
# lr_scheduler_type=SchedulerType.LINEAR,
# max_grad_norm=1.0,
# max_steps=-1,
# metric_for_best_model=recall,
# mp_parameters=,
# neftune_noise_alpha=None,
# no_cuda=False,
# num_train_epochs=3,
# optim=OptimizerNames.ADAMW_TORCH,
# optim_args=None,
# optim_target_modules=None,
# output_dir=./bert_hackathon_model,
# overwrite_output_dir=False,
# past_index=-1,
# per_device_eval_batch_size=8,
# per_device_train_batch_size=8,
# prediction_loss_only=False,
# push_to_hub=False,
# push_to_hub_model_id=None,
# push_to_hub_organization=None,
# push_to_hub_token=<PUSH_TO_HUB_TOKEN>,
# ray_scope=last,
# remove_unused_columns=True,
# report_to=['tensorboard'],
# resume_from_checkpoint=None,
# run_name=./bert_hackathon_model,
# save_on_each_node=False,
# save_only_model=False,
# save_safetensors=True,
# save_steps=500,
# save_strategy=IntervalStrategy.EPOCH,
# save_total_limit=None,
# seed=42,
# skip_memory_metrics=True,
# split_batches=None,
# tf32=None,
# torch_compile=False,
# torch_compile_backend=None,
# torch_compile_mode=None,
# torchdynamo=None,
# tpu_metrics_debug=False,
# tpu_num_cores=None,
# use_cpu=False,
# use_ipex=False,
# use_legacy_prediction_loop=False,
# use_mps_device=False,
# warmup_ratio=0.0,
# warmup_steps=0,
# weight_decay=0.01,
# )

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)
trainer

# %%
results = trainer.evaluate()
print("Test Accuracy:", results["eval_accuracy"])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/utils/data/dataloader.py:683: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Test Accuracy: 0.5

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

preds_output = trainer.predict(test_dataset)
preds = torch.argmax(torch.tensor(preds_output.predictions), axis=-1)
labels = preds_output.label_ids

print(classification_report(labels, preds))

cm = confusion_matrix(labels, preds)
plt.figure(figsize=(4,3))
sns.heatmap(cm, annot=True, fmt='d', cmap='Greens',
            xticklabels=["Not Winner", "Winner"],
            yticklabels=["Not Winner", "Winner"])
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title("BERT Confusion Matrix")
plt.show()
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 17
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/utils/data/dataloader.py:683: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67       200
#            1       0.00      0.00      0.00       200
#
#     accuracy                           0.50       400
#    macro avg       0.25      0.50      0.33       400
# weighted avg       0.25      0.50      0.33       400
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
