# %%
import pandas as pd
import numpy as np

# %%
#basic

# %%
df = pd.read_csv("Gemini_result_basic.csv")
df
# Out:
#       Unnamed: 0  is_winner  \
# 0              0      False
# 1              1       True
# 2              2      False
# 3              3       True
# 4              4      False
# ...          ...        ...
# 1995        1995      False
# 1996        1996      False
# 1997        1997       True
# 1998        1998      False
# 1999        1999      False
#
#                                          github_summary  \
# 0     The GitHub repository, `repo-sit`, hosts a cro...
# 1     This analysis provides a comprehensive overvie...
# 2     The GitHub repository, named GTX, presents as ...
# 3     This repository, named MedChain_HackPSU, detai...
# 4     The `wanderlust-htn` repository hosts Wanderlu...
# ...                                                 ...
# 1995  The `luminder` repository contains a dating ap...
# 1996  The GitHub repository "QuickTeam" presents its...
# 1997  The `3dReal` GitHub repository appears to be a...
# ...

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report

# %%
# Step 2: Remove rows where model_result == -1
df = df[df["model_result"] != -1]

# Step 3: Extract true and predicted labels
y_true = df["label"]
y_pred = df["model_result"]

# Step 4: Compute evaluation metrics
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred)
recall = recall_score(y_true, y_pred)
f1 = f1_score(y_true, y_pred)

# Step 5: Confusion Matrix
cm = confusion_matrix(y_true, y_pred)

# Step 6: Print results
print("✅ Evaluation Metrics")
print("---------------------")
print(f"Accuracy : {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall   : {recall:.4f}")
print(f"F1 Score : {f1:.4f}")

print("\n✅ Confusion Matrix")
print(cm)

print("\n✅ Detailed Classification Report")
print(classification_report(y_true, y_pred))
# Out:
# ✅ Evaluation Metrics
# ---------------------
# Accuracy : 0.5927
# Precision: 0.5719
# Recall   : 0.7375
# F1 Score : 0.6442
#
# ✅ Confusion Matrix
# [[447 551]
#  [262 736]]
#
# ✅ Detailed Classification Report
#               precision    recall  f1-score   support
#
#            0       0.63      0.45      0.52       998
#            1       0.57      0.74      0.64       998
#
#     accuracy                           0.59      1996
#    macro avg       0.60      0.59      0.58      1996
# weighted avg       0.60      0.59      0.58      1996

# %%
#advanced

# %%
df2 = pd.read_csv("gemini_advanced_results.csv")
df2
# Out:
#       Unnamed: 0       hackathon_name  is_winner  \
# 0              0  Hack The North 2020      False
# 1              1      ShellHacks 2024       True
# 2              2             HackGT X      False
# 3              3         HackPSU 2020       True
# 4              4  Hack The North 2021      False
# ...          ...                  ...        ...
# 1995        1995       Hack&Roll 2021      False
# 1996        1996        HackNJIT 2024      False
# 1997        1997       TreeHacks 2024       True
# 1998        1998      VTHacks 12 2024      False
# 1999        1999       TreeHacks 2023      False
#
#                                          github_summary  \
# 0     The GitHub repository, `repo-sit`, hosts a cro...
# 1     This analysis provides a comprehensive overvie...
# 2     The GitHub repository, named GTX, presents as ...
# 3     This repository, named MedChain_HackPSU, detai...
# 4     The `wanderlust-htn` repository hosts Wanderlu...
# ...

# %%
# Step 2: Remove rows where model_result == -1
df2 = df2[df2["model_result"] != -1]

# Step 3: Extract true and predicted labels
y_true = df2["label"]
y_pred = df2["model_result"]

# Step 4: Compute evaluation metrics
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred)
recall = recall_score(y_true, y_pred)
f1 = f1_score(y_true, y_pred)

# Step 5: Confusion Matrix
cm = confusion_matrix(y_true, y_pred)

# Step 6: Print results
print("✅ Evaluation Metrics")
print("---------------------")
print(f"Accuracy : {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall   : {recall:.4f}")
print(f"F1 Score : {f1:.4f}")

print("\n✅ Confusion Matrix")
print(cm)

print("\n✅ Detailed Classification Report")
print(classification_report(y_true, y_pred))
# Out:
# ✅ Evaluation Metrics
# ---------------------
# Accuracy : 0.6172
# Precision: 0.5899
# Recall   : 0.8442
# F1 Score : 0.6945
#
# ✅ Confusion Matrix
# [[254 422]
#  [112 607]]
#
# ✅ Detailed Classification Report
#               precision    recall  f1-score   support
#
#            0       0.69      0.38      0.49       676
#            1       0.59      0.84      0.69       719
#
#     accuracy                           0.62      1395
#    macro avg       0.64      0.61      0.59      1395
# weighted avg       0.64      0.62      0.59      1395
